# %%
# !pip install pyyaml
# !pip install tabulate
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)

# %%
# ## **Bloque 1: Instalación e importación de librerías**
import yaml
from google.colab import drive
import os
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# %%
# ## **Bloque 2: Montar Google Drive**
drive.mount('/content/drive')
print("\n¡Drive montado correctamente! 🚀\n")
# Out:
# Mounted at /content/drive
#
# ¡Drive montado correctamente! 🚀

# %%
# ## **Bloque 3: Configuración**
class Config:
    EXPECTED_SPLITS = ['train', 'val', 'test']
    IMAGE_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp'}
    REPORT_FILE = 'dataset_people_report.txt'
    PLOT_SIZE = (15, 8)
    CLASS_NAME = 'person'  # Clase esperada (clase 0)

# ## **Bloque 4: Función para cargar configuración YAML**
def load_yaml_config(base_path):
    yaml_path = base_path / 'data.yaml'
    if yaml_path.exists():
        with open(yaml_path) as f:
            return yaml.safe_load(f)
    return None

# ## **Bloque 5: Función de validación de estructura**
def validate_structure(base_path):
    missing = []
    required_dirs = ['images', 'labels']

    for dir in required_dirs:
        if not (base_path/dir).exists():
            missing.append(f"{dir}/")

    for split in Config.EXPECTED_SPLITS:
        if not (base_path/'images'/split).exists():
            missing.append(f"images/{split}/")
        if not (base_path/'labels'/split).exists():
            missing.append(f"labels/{split}/")

    if missing:
        print("\n⚠️ **Advertencia:** Directorios faltantes:")
        for item in missing:
            print(f"- {item}")
        print("\nEl análisis podría ser incompleto.\n")
        return False
    return True

# ## **Bloque 6: Función de validación de bounding boxes**
def validate_bbox(bbox):
    if len(bbox) != 5:
        return False, "Formato incorrecto (deben ser 5 valores)"

    try:
        class_id, x_center, y_center, width, height = map(float, bbox)
        if class_id != 0:
            return False, f"Class ID inválido: {class_id} (debe ser 0)"

        for val in [x_center, y_center, width, height]:
            if not (0 <= val <= 1):
                return False, f"Valor fuera de rango: {val} (debe estar entre 0-1)"

        return True, ""
    except ValueError:
        return False, "Valores no numéricos"

# ## **Bloque 7: Función de análisis del dataset**
def analyze_dataset(base_path):
    stats = {split: {
        'images': 0,
        'labels': 0,
        'missing_labels': [],
        'missing_images': [],
        'invalid_bboxes': [],
        'total_bboxes': 0,
        'class_distribution': defaultdict(int)
    } for split in Config.EXPECTED_SPLITS}

    for split in Config.EXPECTED_SPLITS:
        # Rutas de imágenes y labels
        img_dir = base_path / 'images' / split
        label_dir = base_path / 'labels' / split

        # Procesar imágenes
        images = list(img_dir.glob('*'))
        images = [f for f in images if f.suffix.lower() in Config.IMAGE_EXTENSIONS]
        stats[split]['images'] = len(images)

        # Procesar labels
        labels = list(label_dir.glob('*.txt'))
        stats[split]['labels'] = len(labels)

        # Verificar correspondencia
        for img in images:
            label_path = label_dir / (img.stem + '.txt')
            if not label_path.exists():
                stats[split]['missing_labels'].append(img.name)

        for lbl in labels:
            img_path = img_dir / (lbl.stem + '.jpg')
            if not img_path.exists():
                img_path = img_dir / (lbl.stem + '.png')
            if not img_path.exists():
                stats[split]['missing_images'].append(lbl.name)

        # Validar bounding boxes
        for lbl_file in tqdm(labels, desc=f"Validando {split}", unit="file"):
            try:
                with open(lbl_file) as f:
                    lines = f.readlines()

                for line_num, line in enumerate(lines, 1):
                    line = line.strip()
                    if not line:
                        continue

                    bbox = line.split()
                    is_valid, error = validate_bbox(bbox)
                    stats[split]['total_bboxes'] += 1
                    stats[split]['class_distribution'][int(bbox[0])] += 1

                    if not is_valid:
                        stats[split]['invalid_bboxes'].append({
                            'file': lbl_file.name,
                            'line': line_num,
                            'error': error,
                            'content': line
                        })
            except Exception as e:
                stats[split]['invalid_bboxes'].append({
                    'file': lbl_file.name,
                    'error': f"Error de lectura: {str(e)}"
                })

    return stats

# ## **Bloque 8: Función de generación de reporte**
def generate_report(stats, base_path):
    report = []
    report.append(f"# 📊 Reporte de Dataset de Detección de Personas\n")
    report.append(f"**Ruta del dataset:** `{base_path}`\n")

    # Resumen general
    report.append("## 📌 Resumen General")
    summary_data = []
    for split in Config.EXPECTED_SPLITS:
        summary_data.append({
            'Split': split.upper(),
            'Imágenes': stats[split]['images'],
            'Etiquetas': stats[split]['labels'],
            'BBoxes Válidos': stats[split]['total_bboxes'],
            'Labels Faltantes': len(stats[split]['missing_labels']),
            'Imágenes Faltantes': len(stats[split]['missing_images']),
            'BBoxes Inválidos': len(stats[split]['invalid_bboxes'])
        })

    df_summary = pd.DataFrame(summary_data)
    report.append(df_summary.to_markdown(index=False))

    # Problemas detectados
    report.append("\n## ❌ Problemas Detectados")
    for split in Config.EXPECTED_SPLITS:
        report.append(f"\n### {split.upper()}:")
        if stats[split]['missing_labels']:
            report.append(f"- Imágenes sin labels: {len(stats[split]['missing_labels'])}")
        if stats[split]['missing_images']:
            report.append(f"- Labels sin imágenes: {len(stats[split]['missing_images'])}")
        if stats[split]['invalid_bboxes']:
            report.append(f"- Bounding boxes inválidos: {len(stats[split]['invalid_bboxes'])}")

    # Ejemplos de errores
    report.append("\n## 🚨 Ejemplos de Errores")
    for split in Config.EXPECTED_SPLITS:
        if stats[split]['invalid_bboxes']:
            report.append(f"\n### {split.upper()} - Primeros 3 errores:")
            for error in stats[split]['invalid_bboxes'][:3]:
                report.append(f"- **{error['file']}** (Línea {error.get('line', '?')}):")
                report.append(f"  `{error.get('content', '')}`")
                report.append(f"  Error: {error['error']}")

    return '\n'.join(report)

# ## **Bloque 9: Visualización de datos**
def visualize_stats(stats):
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))

    # Gráfico 1: Distribución de imágenes
    splits = Config.EXPECTED_SPLITS
    image_counts = [stats[s]['images'] for s in splits]
    axes[0,0].bar(splits, image_counts)
    axes[0,0].set_title('Distribución de Imágenes por Split')

    # Gráfico 2: Bounding boxes por split
    bbox_counts = [stats[s]['total_bboxes'] for s in splits]
    axes[0,1].pie(bbox_counts, labels=splits, autopct='%1.1f%%')
    axes[0,1].set_title('Distribución de Bounding Boxes')

    # Gráfico 3: Distribución de clases
    class_counts = [stats[s]['class_distribution'].get(0, 0) for s in splits]
    axes[1,0].bar(splits, class_counts)
    axes[1,0].set_title('Detecciones de Personas (Clase 0)')

    # Gráfico 4: Problemas por split
    problems = {
        'Missing Labels': [len(stats[s]['missing_labels']) for s in splits],
        'Invalid BBoxes': [len(stats[s]['invalid_bboxes']) for s in splits]
    }
    df_problems = pd.DataFrame(problems, index=splits)
    df_problems.plot(kind='bar', ax=axes[1,1])
    axes[1,1].set_title('Problemas Detectados por Split')

    plt.tight_layout()
    plt.show()

# %%
# ## **Bloque 10: Ejecución principal**
# Obtener ruta del dataset
# base_path = Path('/content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people')
base_path = Path('/content/drive/MyDrive/dataset_people')

# Validar estructura
if not validate_structure(base_path):
    raise SystemExit("Error en la estructura del dataset")

# Analizar dataset
stats = analyze_dataset(base_path)

# Generar y mostrar reporte
report = generate_report(stats, base_path)
print("\n" + report)

# Visualización
visualize_stats(stats)

# Guardar reporte
with open(Config.REPORT_FILE, 'w') as f:
    f.write(report)
print(f"\n✅ Reporte guardado como: {Config.REPORT_FILE}")
# Out:
# Validando train: 100%|██████████| 5600/5600 [02:04<00:00, 44.96file/s]
# Validando val: 100%|██████████| 1600/1600 [00:27<00:00, 58.90file/s]
# Validando test: 100%|██████████| 800/800 [00:14<00:00, 54.70file/s]
# # 📊 Reporte de Dataset de Detección de Personas
#
# **Ruta del dataset:** `/content/drive/MyDrive/dataset_people`
#
# ## 📌 Resumen General
# | Split   |   Imágenes |   Etiquetas |   BBoxes Válidos |   Labels Faltantes |   Imágenes Faltantes |   BBoxes Inválidos |
# |:--------|-----------:|------------:|-----------------:|-------------------:|---------------------:|-------------------:|
# | TRAIN   |       5600 |        5600 |            14161 |                  0 |                    0 |                  0 |
# | VAL     |       1600 |        1600 |             4251 |                  0 |                    0 |                  0 |
# | TEST    |        800 |         800 |             2113 |                  0 |                    0 |                  0 |
#
# ## ❌ Problemas Detectados
#
# ### TRAIN:
#
# ### VAL:
#
# ### TEST:
#
# ## 🚨 Ejemplos de Errores
# ✅ Reporte guardado como: dataset_people_report.txt

# %%
# Ejemplo: Eliminar todos los .npy en val/
import os

# Define the full path to the directory
val_dir_path = "/content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people/images/val"

for file in os.listdir(val_dir_path):
    if file.endswith(".npy") or file.endswith(".nyx"):
        # Join the directory path with the filename to get the full file path
        file_path = os.path.join(val_dir_path, file)
        os.remove(file_path)

# %% [markdown]
# # **DATA AUMENTATIONS**

# %%
# !pip install pyyaml
# !pip install tabulate
# !pip install albumentations # Install albumentations
# !pip install opencv-python # Ensure opencv-python is installed for cv2
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Collecting albumentations
#   Downloading albumentations-2.0.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.15.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.11.4)
# Collecting albucore==0.0.24 (from albumentations)
#   Downloading albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.24->albumentations)
#   Downloading stringzilla-3.12.5-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.8 MB/s eta 0:00:00
# Collecting simsimd>=5.9.2 (from albucore==0.0.24->albumentations)
#   Downloading simsimd-6.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.0)
# Downloading albumentations-2.0.6-py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 14.1 MB/s eta 0:00:00
# Downloading albucore-0.0.24-py3-none-any.whl (15 kB)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 27.7 MB/s eta 0:00:00
# Downloading simsimd-6.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (632 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 41.2 MB/s eta 0:00:00
# Downloading stringzilla-3.12.5-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.8/307.8 kB 25.7 MB/s eta 0:00:00
# Installing collected packages: stringzilla, simsimd, opencv-python-headless, albucore, albumentations
# Successfully installed albucore-0.0.24 albumentations-2.0.6 opencv-python-headless-4.11.0.86 simsimd-6.2.1 stringzilla-3.12.5
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86

# %%
# ## **Bloque 1: Instalación e importación de librerías**
import yaml
from google.colab import drive
import os
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
import cv2
import albumentations as A
import glob
import shutil
import random

# %%
# Montar Google Drive si aún no está montado
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
    print("Google Drive montado correctamente.")
else:
    print("Google Drive ya está montado.")
# Out:
# Mounted at /content/drive
# Google Drive montado correctamente.

# %%
# Configuración de directorios para Google Colab con Drive
# DRIVE_BASE = "/content/drive/MyDrive/Proyecto IA-3/violence_school_project"
DRIVE_BASE = "/content/drive/MyDrive/Proyecto-IA3"
DATASET_ROOT = f"/content/drive/MyDrive/dataset_people"
OUTPUT_ROOT = f"{DRIVE_BASE}/dataset_people_augmented"  # Aquí se guardarán los datos aumentados

print(f"Ruta del dataset original: {DATASET_ROOT}")
print(f"Ruta donde se guardarán los datos aumentados: {OUTPUT_ROOT}")

# Crear directorios de salida si no existen
for split in ["train", "val", "test"]:
    for subdir in ["images", "labels"]:
        os.makedirs(os.path.join(OUTPUT_ROOT, subdir, split), exist_ok=True)

# Directorio para visualizaciones
VIZ_DIR = os.path.join(OUTPUT_ROOT, "visualizaciones")
os.makedirs(VIZ_DIR, exist_ok=True)


# Comprobar si las rutas existen
for split in ["train", "val", "test"]:
    img_dir = os.path.join(DATASET_ROOT, "images", split)
    label_dir = os.path.join(DATASET_ROOT, "labels", split)

    if os.path.exists(img_dir) and os.path.exists(label_dir):
        print(f"Directorios para {split} encontrados correctamente.")
    else:
        print(f"ADVERTENCIA: Los directorios para {split} no existen: {img_dir} o {label_dir}")
# Out:
# Ruta del dataset original: /content/drive/MyDrive/dataset_people
# Ruta donde se guardarán los datos aumentados: /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented
# Directorios para train encontrados correctamente.
# Directorios para val encontrados correctamente.
# Directorios para test encontrados correctamente.

# %%
# AJUSTES A LAS TRANSFORMACIONES: más realistas para personas

# Transformaciones para entrenamiento
train_transform = A.Compose([
    # Transformaciones geométricas realistas
    A.HorizontalFlip(p=0.5),  # Flip horizontal es realista

    # Eliminamos rotaciones extremas y solo permitimos pequeñas
    # inclinaciones que podrían ser naturales en cámaras
    A.Rotate(limit=5, p=0.3),  # Rotación muy limitada (solo 5 grados máximo)

    # Ajustamos el recorte para ser más realista
    A.OneOf([
        # Conservamos la relación de aspecto
        A.RandomSizedBBoxSafeCrop(height=640, width=640, p=0.3),
        A.Resize(height=640, width=640, p=0.7)
    ], p=1.0),

    # Transformaciones de color/iluminación (realistas para vigilancia)
    A.OneOf([
        A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.7),
        A.HueSaturationValue(hue_shift_limit=5, sat_shift_limit=10, val_shift_limit=10, p=0.3),
    ], p=0.7),

    # Transformaciones ambientales realistas para escenas de vigilancia
    A.OneOf([
        A.RandomShadow(p=0.3),
        A.RandomFog(fog_coef_lower=0.01, fog_coef_upper=0.1, p=0.1),  # Niebla muy sutil
    ], p=0.3),

    # Ruido realista para cámaras (común en vigilancia)
    A.OneOf([
        A.GaussNoise(var_limit=(5.0, 15.0), p=0.3),  # Ruido sutil
        A.CLAHE(clip_limit=2.0, p=0.3),  # Mejora de contraste realista
        A.ImageCompression(quality_lower=85, quality_upper=100, p=0.3),  # Compresión típica CCTV
        A.GaussianBlur(blur_limit=(1, 2), p=0.2),  # Desenfoque muy leve
    ], p=0.3),
], bbox_params=A.BboxParams(
    format='yolo',  # Formato YOLO [class_id, x_center, y_center, width, height]
    min_area=0.0001,
    min_visibility=0.3,  # Aumentamos para evitar recortes extremos
    label_fields=['class_labels']
))

# Transformaciones más ligeras para validación
val_transform = A.Compose([
    A.HorizontalFlip(p=0.3),
    A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.3),
    A.Resize(height=640, width=640)
], bbox_params=A.BboxParams(
    format='yolo',
    min_area=0.0001,
    min_visibility=0.3,
    label_fields=['class_labels']
))
# Out:
# <ipython-input-29-7c8a7e86a4cd>:28: UserWarning: Argument(s) 'fog_coef_lower, fog_coef_upper' are not valid for transform RandomFog
#   A.RandomFog(fog_coef_lower=0.01, fog_coef_upper=0.1, p=0.1),  # Niebla muy sutil
# <ipython-input-29-7c8a7e86a4cd>:33: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(5.0, 15.0), p=0.3),  # Ruido sutil
# <ipython-input-29-7c8a7e86a4cd>:35: UserWarning: Argument(s) 'quality_lower, quality_upper' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=85, quality_upper=100, p=0.3),  # Compresión típica CCTV

# %%
# Definimos exactamente dos transformaciones específicas basadas en las que solicitaste

# Aumentación tipo 1: Flip horizontal con más brillo
transform_type1 = A.Compose([
    A.HorizontalFlip(p=1.0),  # Siempre hacer flip horizontal
    A.RandomBrightnessContrast(brightness_limit=(0.1, 0.2), contrast_limit=0, p=1.0),  # Aumentar brillo
], bbox_params=A.BboxParams(
    format='yolo',
    min_area=0.0001,
    min_visibility=0.3,
    label_fields=['class_labels']
))

# Aumentación tipo 2: Pequeña rotación (como en la imagen 3)
transform_type2 = A.Compose([
    A.Rotate(limit=5, p=1.0),  # Rotación muy sutil, siempre aplicada
], bbox_params=A.BboxParams(
    format='yolo',
    min_area=0.0001,
    min_visibility=0.3,
    label_fields=['class_labels']
))

# %%
def visualize_bbox(img, bboxes, class_ids, class_name="person"):
    """Visualiza la imagen con sus bounding boxes para verificación"""
    img = img.copy()
    h, w, _ = img.shape

    for i, bbox in enumerate(bboxes):
        # Convertir de formato YOLO [x_center, y_center, width, height] a píxeles
        x_center, y_center, width, height = bbox
        x_min = int((x_center - width/2) * w)
        y_min = int((y_center - height/2) * h)
        x_max = int((x_center + width/2) * w)
        y_max = int((y_center + height/2) * h)

        # Dibujar rectángulo
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

        # Etiqueta
        cv2.putText(img, class_name, (x_min, y_min - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    return img

def apply_augmentation(image_path, label_path, output_image_dir, output_label_dir, transform,
                       num_augmentations=3, visualize=False, viz_sample_prob=0.05):
    """Aplica aumentación a una imagen y sus etiquetas"""
    # Leer imagen
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error al leer la imagen: {image_path}")
        return

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Leer etiquetas
    try:
        with open(label_path, 'r') as f:
            lines = f.readlines()
    except Exception as e:
        print(f"Error al leer el archivo de etiquetas {label_path}: {e}")
        return

    bboxes = []
    class_labels = []

    # Procesar etiquetas
    for line in lines:
        try:
            values = line.strip().split()
            class_id = int(values[0])
            x_center, y_center, width, height = [float(x) for x in values[1:5]]

            # Verificar si los valores están en el rango correcto (0-1 para YOLO)
            if not all(0 <= val <= 1 for val in [x_center, y_center, width, height]):
                print(f"Advertencia: Valores fuera de rango en {label_path}: {values}")
                continue

            bboxes.append([x_center, y_center, width, height])
            class_labels.append(class_id)
        except Exception as e:
            print(f"Error al procesar línea en {label_path}: {line} - {e}")
            continue

    # Si no hay cajas válidas, omitir esta imagen
    if not bboxes:
        print(f"No se encontraron bounding boxes válidos en {label_path}")
        return

    # Obtener nombre base del archivo
    base_name = os.path.basename(image_path).split('.')[0]

    # Visualizar imagen original
    if visualize and random.random() < viz_sample_prob:
        vis_img = visualize_bbox(image, bboxes, class_labels)
        plt.figure(figsize=(10, 10))
        plt.imshow(vis_img)
        plt.title("Original Image")
        plt.axis('off')
        plt.savefig(os.path.join(VIZ_DIR, f"{base_name}_original.jpg"), dpi=100)
        plt.close()

    # Crear augmentaciones
    augmentation_attempts = 0
    successful_augmentations = 0

    # Intentaremos más veces para conseguir el número deseado de aumentaciones válidas
    while successful_augmentations < num_augmentations and augmentation_attempts < num_augmentations * 2:
        augmentation_attempts += 1

        try:
            # Aplicar transformación
            augmented = transform(image=image, bboxes=bboxes, class_labels=class_labels)

            aug_image = augmented['image']
            aug_bboxes = augmented['bboxes']
            aug_class_labels = augmented['class_labels']

            # Verificar que la aumentación contiene los bounding boxes esperados
            if not aug_bboxes:
                continue

            # Verificar que los bounding boxes no están demasiado distorsionados
            valid_boxes = True
            for bbox in aug_bboxes:
                _, _, w, h = bbox
                # Rechazar si el ancho o alto son demasiado pequeños o grandes
                if w < 0.02 or h < 0.02 or w > 0.95 or h > 0.95:
                    valid_boxes = False
                    break

            if not valid_boxes:
                continue

            # Si llegamos aquí, la aumentación es válida
            successful_augmentations += 1

            # Guardar imagen aumentada
            output_image_path = os.path.join(output_image_dir, f"{base_name}_aug{successful_augmentations}.jpg")
            cv2.imwrite(output_image_path, cv2.cvtColor(aug_image, cv2.COLOR_RGB2BGR))

            # Guardar etiquetas aumentadas
            output_label_path = os.path.join(output_label_dir, f"{base_name}_aug{successful_augmentations}.txt")
            with open(output_label_path, 'w') as f:
                for bbox, class_id in zip(aug_bboxes, aug_class_labels):
                    f.write(f"{class_id} {' '.join([str(x) for x in bbox])}\n")

            # Visualizar aumentaciones
            if visualize and random.random() < viz_sample_prob:
                vis_aug_img = visualize_bbox(aug_image, aug_bboxes, aug_class_labels)
                plt.figure(figsize=(10, 10))
                plt.imshow(vis_aug_img)
                plt.title(f"Augmented Image {successful_augmentations}")
                plt.axis('off')
                plt.savefig(os.path.join(VIZ_DIR, f"{base_name}_aug{successful_augmentations}.jpg"), dpi=100)
                plt.close()

        except Exception as e:
            print(f"Error en la augmentación para {image_path}: {e}")
            continue

def process_split(split_name="train", augmentations_per_image=3, visualize_sample=True, max_images=None):
    """Procesa un conjunto de datos (train/val/test) con opción de limitar imágenes para pruebas"""
    print(f"\n{'='*50}")
    print(f"Procesando split: {split_name}")
    print(f"{'='*50}")

    # Directorios originales
    src_image_dir = os.path.join(DATASET_ROOT, "images", split_name)
    src_label_dir = os.path.join(DATASET_ROOT, "labels", split_name)

    # Directorios de salida
    output_image_dir = os.path.join(OUTPUT_ROOT, "images", split_name)
    output_label_dir = os.path.join(OUTPUT_ROOT, "labels", split_name)

    # Seleccionar transformación según el split
    transform = train_transform if split_name == "train" else val_transform

    # Obtener todas las imágenes
    image_files = glob.glob(os.path.join(src_image_dir, "*.jpg"))
    if not image_files:
        image_files = glob.glob(os.path.join(src_image_dir, "*.png"))

    if not image_files:
        print(f"ADVERTENCIA: No se encontraron imágenes en {src_image_dir}")
        return

    print(f"Encontradas {len(image_files)} imágenes en {src_image_dir}")

    # Limitar el número de imágenes para pruebas si es necesario
    if max_images is not None and max_images > 0 and max_images < len(image_files):
        print(f"Limitando procesamiento a {max_images} imágenes (para pruebas)")
        random.shuffle(image_files)  # Aleatorizamos para tener una muestra representativa
        image_files = image_files[:max_images]

    # Copiar archivos originales primero
    print("Copiando archivos originales...")
    for img_path in tqdm(image_files):
        base_name = os.path.basename(img_path)
        label_name = os.path.splitext(base_name)[0] + ".txt"
        label_path = os.path.join(src_label_dir, label_name)

        if os.path.exists(label_path):
            try:
                shutil.copy(img_path, os.path.join(output_image_dir, base_name))
                shutil.copy(label_path, os.path.join(output_label_dir, label_name))
            except Exception as e:
                print(f"Error al copiar archivos originales: {e}")

    # Aplicar aumentación solo si se requiere
    if augmentations_per_image > 0:
        print(f"Aplicando aumentación ({augmentations_per_image} por imagen)...")
        for img_path in tqdm(image_files):
            base_name = os.path.basename(img_path)
            label_name = os.path.splitext(base_name)[0] + ".txt"
            label_path = os.path.join(src_label_dir, label_name)

            if os.path.exists(label_path):
                apply_augmentation(
                    img_path,
                    label_path,
                    output_image_dir,
                    output_label_dir,
                    transform,
                    num_augmentations=augmentations_per_image,
                    visualize=visualize_sample,
                    viz_sample_prob=0.05  # Visualizamos más para asegurar
                )

def update_yaml_file():
    """Actualiza o crea el archivo data.yaml para el dataset aumentado"""
    src_yaml = os.path.join(DATASET_ROOT, "data.yaml")
    dst_yaml = os.path.join(OUTPUT_ROOT, "data.yaml")

    if os.path.exists(src_yaml):
        # Leer el YAML original
        with open(src_yaml, 'r') as f:
            yaml_content = f.read()

        # Actualizar rutas (para el caso de Drive, mejor usar rutas absolutas)
        updated_content = []
        for line in yaml_content.split('\n'):
            if line.startswith('train:') or line.startswith('val:') or line.startswith('test:'):
                key = line.split(':')[0].strip()
                updated_content.append(f"{key}: {os.path.join(OUTPUT_ROOT, 'images', key)}")
            else:
                updated_content.append(line)

        yaml_content = '\n'.join(updated_content)

        # Guardar nuevo YAML
        with open(dst_yaml, 'w') as f:
            f.write(yaml_content)

        print(f"Archivo data.yaml actualizado en {dst_yaml}")
    else:
        # Crear un YAML básico
        train_path = os.path.join(OUTPUT_ROOT, "images", "train")
        val_path = os.path.join(OUTPUT_ROOT, "images", "val")
        test_path = os.path.join(OUTPUT_ROOT, "images", "test")

        yaml_content = f"""# Dataset configuración para YOLOv11
train: {train_path}
val: {val_path}
test: {test_path}

# Número de clases
nc: 1

# Nombres de clases
names: ['person']
"""

        with open(dst_yaml, 'w') as f:
            f.write(yaml_content)

        print(f"Archivo data.yaml creado en {dst_yaml}")

def print_summary():
    """Imprime un resumen del proceso de aumentación"""
    print("\n\n" + "="*60)
    print("RESUMEN DE AUMENTACIÓN DE DATOS".center(60))
    print("="*60)

    for split in ["train", "val", "test"]:
        img_dir = os.path.join(DATASET_ROOT, "images", split)
        aug_img_dir = os.path.join(OUTPUT_ROOT, "images", split)

        if not os.path.exists(img_dir) or not os.path.exists(aug_img_dir):
            print(f"Split {split.upper()}: Directorio no encontrado, omitiendo...")
            continue

        orig_count = len(glob.glob(os.path.join(img_dir, "*.jpg")))
        if orig_count == 0:
            orig_count = len(glob.glob(os.path.join(img_dir, "*.png")))

        aug_count = len(glob.glob(os.path.join(aug_img_dir, "*.jpg")))
        if aug_count == 0:
            aug_count = len(glob.glob(os.path.join(aug_img_dir, "*.png")))

        if orig_count > 0:
            print(f"Split {split.upper()}:")
            print(f"  - Imágenes originales: {orig_count}")
            print(f"  - Imágenes después de aumentación: {aug_count}")
            print(f"  - Incremento: {aug_count - orig_count} imágenes ({(aug_count/orig_count - 1)*100:.1f}% más)")
            print("-"*60)

    print("\nVisualizaciones guardadas en:", VIZ_DIR)
    print(f"\nDataset aumentado guardado en: {OUTPUT_ROOT}")
    print("="*60)

def test_run_single_image():
    """Ejecuta una prueba en una sola imagen para verificar que todo funciona"""
    print("\nEjecutando prueba en una sola imagen...")

    # Buscar una imagen de prueba
    for split in ["train", "val"]:
        img_dir = os.path.join(DATASET_ROOT, "images", split)
        if os.path.exists(img_dir):
            image_files = glob.glob(os.path.join(img_dir, "*.jpg"))
            if not image_files:
                image_files = glob.glob(os.path.join(img_dir, "*.png"))

            if image_files:
                test_img = image_files[0]
                base_name = os.path.basename(test_img)
                label_name = os.path.splitext(base_name)[0] + ".txt"
                label_path = os.path.join(DATASET_ROOT, "labels", split, label_name)

                if os.path.exists(label_path):
                    print(f"Probando con imagen: {test_img}")
                    output_img_dir = os.path.join(OUTPUT_ROOT, "test_single")
                    output_label_dir = os.path.join(OUTPUT_ROOT, "test_single")
                    os.makedirs(output_img_dir, exist_ok=True)

                    # Aplicar aumentación a esta imagen solamente
                    transform = train_transform
                    apply_augmentation(
                        test_img,
                        label_path,
                        output_img_dir,
                        output_label_dir,
                        transform,
                        num_augmentations=5,  # Generamos 5 para ver variedad
                        visualize=True,
                        viz_sample_prob=1.0  # Siempre visualizar
                    )

                    print(f"Prueba completada. Verifica el directorio: {output_img_dir}")
                    return True

    print("No se pudo encontrar una imagen de prueba válida.")
    return False

# %%
# Ejecutar el proceso completo
if __name__ == "__main__":
    # OPCIÓN RECOMENDADA:
    # Primero hacer una prueba con una sola imagen para verificar transformaciones
    test_run_single_image()

    # Después, ejecutar el proceso completo
    # process_split("train", augmentations_per_image=5)  # 5 aumentaciones por imagen para train
    # process_split("val", augmentations_per_image=2)    # 2 aumentaciones por imagen para val
    # No aumentamos test para mantenerlo como referencia de evaluación

    # Actualizar el archivo YAML
    update_yaml_file()

    # Imprimir resumen
    print_summary()

    print("\n¡Proceso completado! Los datos aumentados están disponibles en Google Drive.")
# Out:
# Ejecutando prueba en una sola imagen...
# Probando con imagen: /content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people/images/train/people_3721.jpg
# Prueba completada. Verifica el directorio: /content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people_augmented/test_single
# Archivo data.yaml actualizado en /content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people_augmented/data.yaml
#
#
# ============================================================
#               RESUMEN DE AUMENTACIÓN DE DATOS
# ============================================================
# Split TRAIN:
#   - Imágenes originales: 5600
#   - Imágenes después de aumentación: 0
#   - Incremento: -5600 imágenes (-100.0% más)
# ------------------------------------------------------------
# Split VAL:
#   - Imágenes originales: 1600
#   - Imágenes después de aumentación: 0
#   - Incremento: -1600 imágenes (-100.0% más)
# ------------------------------------------------------------
# Split TEST:
#   - Imágenes originales: 800
#   - Imágenes después de aumentación: 0
#   - Incremento: -800 imágenes (-100.0% más)
# ------------------------------------------------------------
#
# Visualizaciones guardadas en: /content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people_augmented/visualizaciones
#
# Dataset aumentado guardado en: /content/drive/MyDrive/Proyecto IA-3/violence_school_project/dataset_people_augmented
# ============================================================
#
# ¡Proceso completado! Los datos aumentados están disponibles en Google Drive.

# %%
def visualize_bbox(img, bboxes, class_ids, class_name="person"):
    """Visualiza la imagen con sus bounding boxes para verificación"""
    img = img.copy()
    h, w, _ = img.shape

    for i, bbox in enumerate(bboxes):
        # Convertir de formato YOLO [x_center, y_center, width, height] a píxeles
        x_center, y_center, width, height = bbox
        x_min = int((x_center - width/2) * w)
        y_min = int((y_center - height/2) * h)
        x_max = int((x_center + width/2) * w)
        y_max = int((y_center + height/2) * h)

        # Dibujar rectángulo
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

        # Etiqueta
        cv2.putText(img, class_name, (x_min, y_min - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    return img

def apply_augmentation_type(image_path, label_path, output_image_dir, output_label_dir,
                            transform_type, aug_name, visualize=False):
    """Aplica un tipo específico de transformación a una imagen"""
    # Leer imagen
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error al leer la imagen: {image_path}")
        return False

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Leer etiquetas
    try:
        with open(label_path, 'r') as f:
            lines = f.readlines()
    except Exception as e:
        print(f"Error al leer el archivo de etiquetas {label_path}: {e}")
        return False

    bboxes = []
    class_labels = []

    # Procesar etiquetas
    for line in lines:
        try:
            values = line.strip().split()
            class_id = int(values[0])
            x_center, y_center, width, height = [float(x) for x in values[1:5]]

            # Verificar si los valores están en el rango correcto (0-1 para YOLO)
            if not all(0 <= val <= 1 for val in [x_center, y_center, width, height]):
                print(f"Advertencia: Valores fuera de rango en {label_path}: {values}")
                continue

            bboxes.append([x_center, y_center, width, height])
            class_labels.append(class_id)
        except Exception as e:
            print(f"Error al procesar línea en {label_path}: {line} - {e}")
            continue

    # Si no hay cajas válidas, omitir esta imagen
    if not bboxes:
        print(f"No se encontraron bounding boxes válidos en {label_path}")
        return False

    # Obtener nombre base del archivo
    base_name = os.path.basename(image_path).split('.')[0]

    try:
        # Aplicar transformación
        augmented = transform_type(image=image, bboxes=bboxes, class_labels=class_labels)

        aug_image = augmented['image']
        aug_bboxes = augmented['bboxes']
        aug_class_labels = augmented['class_labels']

        # Verificar que la aumentación contiene los bounding boxes esperados
        if not aug_bboxes:
            print(f"La transformación {aug_name} eliminó todos los bounding boxes para {image_path}, omitiendo.")
            return False

        # Guardar imagen aumentada
        output_image_path = os.path.join(output_image_dir, f"{base_name}_aug_{aug_name}.jpg")
        cv2.imwrite(output_image_path, cv2.cvtColor(aug_image, cv2.COLOR_RGB2BGR))

        # Guardar etiquetas aumentadas
        output_label_path = os.path.join(output_label_dir, f"{base_name}_aug_{aug_name}.txt")
        with open(output_label_path, 'w') as f:
            for bbox, class_id in zip(aug_bboxes, aug_class_labels):
                f.write(f"{class_id} {' '.join([str(x) for x in bbox])}\n")

        # Visualizar aumentación si se solicita
        if visualize:
            vis_aug_img = visualize_bbox(aug_image, aug_bboxes, aug_class_labels)
            plt.figure(figsize=(10, 10))
            plt.imshow(vis_aug_img)
            plt.title(f"Augmented Image - {aug_name}")
            plt.axis('off')
            plt.savefig(os.path.join(VIZ_DIR, f"{base_name}_aug_{aug_name}.jpg"), dpi=100)
            plt.close()

        return True  # La aumentación se realizó correctamente

    except Exception as e:
        print(f"Error en la aumentación {aug_name} para {image_path}: {e}")
        return False

def process_limited_split(split_name, total_images, visualize_sample=True):
    """
    Procesa una cantidad limitada de imágenes para cada tipo de aumentación.
    Garantiza que no se procese la misma imagen dos veces.

    Args:
        split_name: Nombre del split ('train' o 'val')
        total_images: Número total de imágenes a procesar (se dividirá entre los 2 tipos)
        visualize_sample: Si se deben visualizar algunas muestras
    """
    print(f"\n{'='*50}")
    print(f"Procesando split {split_name} con {total_images} imágenes totales")
    print(f"{'='*50}")

    # Directorios originales
    src_image_dir = os.path.join(DATASET_ROOT, "images", split_name)
    src_label_dir = os.path.join(DATASET_ROOT, "labels", split_name)

    # Directorios de salida
    output_image_dir = os.path.join(OUTPUT_ROOT, "images", split_name)
    output_label_dir = os.path.join(OUTPUT_ROOT, "labels", split_name)

    # Obtener todas las imágenes
    image_files = glob.glob(os.path.join(src_image_dir, "*.jpg"))
    if not image_files:
        image_files = glob.glob(os.path.join(src_image_dir, "*.png"))

    if not image_files:
        print(f"ADVERTENCIA: No se encontraron imágenes en {src_image_dir}")
        return

    print(f"Encontradas {len(image_files)} imágenes en {src_image_dir}")

    # Copiar archivos originales primero
    print("Copiando archivos originales...")
    valid_image_files = []  # Almacenar solo imágenes con etiquetas válidas

    for img_path in tqdm(image_files):
        base_name = os.path.basename(img_path)
        label_name = os.path.splitext(base_name)[0] + ".txt"
        label_path = os.path.join(src_label_dir, label_name)

        if os.path.exists(label_path):
            try:
                shutil.copy(img_path, os.path.join(output_image_dir, base_name))
                shutil.copy(label_path, os.path.join(output_label_dir, label_name))
                valid_image_files.append(img_path)  # Añadir a lista de imágenes válidas
            except Exception as e:
                print(f"Error al copiar archivos originales: {e}")

    print(f"Total de imágenes válidas con etiquetas: {len(valid_image_files)}")

    # Aleatorizar imágenes
    random.shuffle(valid_image_files)

    # Dividir en dos grupos para asegurar que no haya imágenes repetidas
    images_per_type = total_images // 2

    # Garantizar que no intentamos procesar más imágenes de las disponibles
    if images_per_type * 2 > len(valid_image_files):
        print(f"ADVERTENCIA: Solo hay {len(valid_image_files)} imágenes disponibles.")
        print(f"Reduciendo a {len(valid_image_files) // 2} imágenes por tipo de aumentación.")
        images_per_type = len(valid_image_files) // 2

    # Separar en dos grupos disjuntos (sin repetición)
    type1_images = valid_image_files[:images_per_type]
    type2_images = valid_image_files[images_per_type:images_per_type*2]

    print(f"Procesando {len(type1_images)} imágenes para aumentación tipo 1 (flip + brillo)")
    print(f"Procesando {len(type2_images)} imágenes para aumentación tipo 2 (rotación)")

    # Verificar que no hay solapamiento
    common_images = set(type1_images).intersection(set(type2_images))
    if common_images:
        print(f"ERROR: Se detectaron {len(common_images)} imágenes duplicadas entre ambos tipos.")
        print("Esto no debería ocurrir. Corrigiendo...")
        # No debería ocurrir con la lógica actual, pero añadimos esta comprobación por seguridad

    # Procesar aumentación tipo 1: Flip horizontal con brillo
    print(f"Aplicando aumentación tipo 1 (flip + brillo)...")
    type1_success = 0

    with tqdm(total=len(type1_images)) as pbar:
        for img_path in type1_images:
            base_name = os.path.basename(img_path)
            label_name = os.path.splitext(base_name)[0] + ".txt"
            label_path = os.path.join(src_label_dir, label_name)

            if os.path.exists(label_path):
                success = apply_augmentation_type(
                    img_path,
                    label_path,
                    output_image_dir,
                    output_label_dir,
                    transform_type1,
                    "flip_brightness",
                    visualize=visualize_sample and random.random() < 0.05
                )

                if success:
                    type1_success += 1
                pbar.update(1)

    # Procesar aumentación tipo 2: Rotación
    print(f"Aplicando aumentación tipo 2 (rotación)...")
    type2_success = 0

    with tqdm(total=len(type2_images)) as pbar:
        for img_path in type2_images:
            base_name = os.path.basename(img_path)
            label_name = os.path.splitext(base_name)[0] + ".txt"
            label_path = os.path.join(src_label_dir, label_name)

            if os.path.exists(label_path):
                success = apply_augmentation_type(
                    img_path,
                    label_path,
                    output_image_dir,
                    output_label_dir,
                    transform_type2,
                    "rotation",
                    visualize=visualize_sample and random.random() < 0.05
                )

                if success:
                    type2_success += 1
                pbar.update(1)

    print(f"Aumentación completada para {split_name}:")
    print(f"  - Tipo 1 (flip + brillo): {type1_success} imágenes procesadas exitosamente")
    print(f"  - Tipo 2 (rotación): {type2_success} imágenes procesadas exitosamente")
    print(f"  - Total: {type1_success + type2_success} imágenes aumentadas")

def update_yaml_file():
    """Actualiza o crea el archivo data.yaml para el dataset aumentado"""
    src_yaml = os.path.join(DATASET_ROOT, "data.yaml")
    dst_yaml = os.path.join(OUTPUT_ROOT, "data.yaml")

    if os.path.exists(src_yaml):
        # Leer el YAML original
        with open(src_yaml, 'r') as f:
            yaml_content = f.read()

        # Actualizar rutas (para el caso de Drive, mejor usar rutas absolutas)
        updated_content = []
        for line in yaml_content.split('\n'):
            if line.startswith('train:') or line.startswith('val:') or line.startswith('test:'):
                key = line.split(':')[0].strip()
                updated_content.append(f"{key}: {os.path.join(OUTPUT_ROOT, 'images', key)}")
            else:
                updated_content.append(line)

        yaml_content = '\n'.join(updated_content)

        # Guardar nuevo YAML
        with open(dst_yaml, 'w') as f:
            f.write(yaml_content)

        print(f"Archivo data.yaml actualizado en {dst_yaml}")
    else:
        # Crear un YAML básico
        train_path = os.path.join(OUTPUT_ROOT, "images", "train")
        val_path = os.path.join(OUTPUT_ROOT, "images", "val")
        test_path = os.path.join(OUTPUT_ROOT, "images", "test")

        yaml_content = f"""# Dataset configuración para YOLOv11
train: {train_path}
val: {val_path}
test: {test_path}

# Número de clases
nc: 1

# Nombres de clases
names: ['person']
"""

        with open(dst_yaml, 'w') as f:
            f.write(yaml_content)

        print(f"Archivo data.yaml creado en {dst_yaml}")

def print_summary():
    """Imprime un resumen del proceso de aumentación"""
    print("\n\n" + "="*60)
    print("RESUMEN DE AUMENTACIÓN DE DATOS".center(60))
    print("="*60)

    for split in ["train", "val", "test"]:
        img_dir = os.path.join(DATASET_ROOT, "images", split)
        aug_img_dir = os.path.join(OUTPUT_ROOT, "images", split)

        if not os.path.exists(img_dir) or not os.path.exists(aug_img_dir):
            print(f"Split {split.upper()}: Directorio no encontrado, omitiendo...")
            continue

        orig_count = len(glob.glob(os.path.join(img_dir, "*.jpg")))
        if orig_count == 0:
            orig_count = len(glob.glob(os.path.join(img_dir, "*.png")))

        aug_count = len(glob.glob(os.path.join(aug_img_dir, "*.jpg")))
        if aug_count == 0:
            aug_count = len(glob.glob(os.path.join(aug_img_dir, "*.png")))

        # Contar por tipo de aumentación
        aug_type1_count = len(glob.glob(os.path.join(aug_img_dir, "*_aug_flip_brightness.jpg")))
        aug_type2_count = len(glob.glob(os.path.join(aug_img_dir, "*_aug_rotation.jpg")))

        if orig_count > 0:
            print(f"Split {split.upper()}:")
            print(f"  - Imágenes originales: {orig_count}")
            print(f"  - Aumentación tipo 1 (flip + brillo): {aug_type1_count}")
            print(f"  - Aumentación tipo 2 (rotación): {aug_type2_count}")
            print(f"  - Total después de aumentación: {aug_count}")
            print(f"  - Incremento: {aug_count - orig_count} imágenes ({(aug_count/orig_count - 1)*100:.1f}% más)")
            print("-"*60)

    print("\nVisualizaciones guardadas en:", VIZ_DIR)
    print(f"\nDataset aumentado guardado en: {OUTPUT_ROOT}")
    print("="*60)

def test_run_single_image():
    """Ejecuta una prueba en una sola imagen para verificar que todo funciona"""
    print("\nEjecutando prueba en una sola imagen...")

    # Buscar una imagen de prueba
    for split in ["train", "val"]:
        img_dir = os.path.join(DATASET_ROOT, "images", split)
        if os.path.exists(img_dir):
            image_files = glob.glob(os.path.join(img_dir, "*.jpg"))
            if not image_files:
                image_files = glob.glob(os.path.join(img_dir, "*.png"))

            if image_files:
                test_img = image_files[0]
                base_name = os.path.basename(test_img)
                label_name = os.path.splitext(base_name)[0] + ".txt"
                label_path = os.path.join(DATASET_ROOT, "labels", split, label_name)

                if os.path.exists(label_path):
                    print(f"Probando con imagen: {test_img}")
                    output_img_dir = os.path.join(OUTPUT_ROOT, "test_single")
                    output_label_dir = os.path.join(OUTPUT_ROOT, "test_single")
                    os.makedirs(output_img_dir, exist_ok=True)
                    os.makedirs(output_label_dir, exist_ok=True)

                    # Aplicar las dos aumentaciones
                    apply_augmentation_type(
                        test_img,
                        label_path,
                        output_img_dir,
                        output_label_dir,
                        transform_type1,
                        "flip_brightness",
                        visualize=True
                    )

                    apply_augmentation_type(
                        test_img,
                        label_path,
                        output_img_dir,
                        output_label_dir,
                        transform_type2,
                        "rotation",
                        visualize=True
                    )

                    print(f"Prueba completada. Verifica el directorio: {output_img_dir}")
                    return True

    print("No se pudo encontrar una imagen de prueba válida.")
    return False

# %%
# Ejecutar el proceso completo
if __name__ == "__main__":
    # OPCIÓN RECOMENDADA:
    # Primero hacer una prueba con una sola imagen para verificar transformaciones
    # test_run_single_image()

    # Procesar una cantidad limitada de imágenes:
    # - 3000 para train (1500 tipo1 + 1500 tipo2)
    # - 1000 para val (500 tipo1 + 500 tipo2)
    # process_limited_split("train", 4550)
    # process_limited_split("val", 1400)
    # No aumentamos test para mantenerlo como referencia de evaluación

    # Actualizar el archivo YAML
    update_yaml_file()

    # Imprimir resumen
    print_summary()

    print("\n¡Proceso completado! Los datos aumentados están disponibles en Google Drive.")
# Out:
# ==================================================
# Procesando split val con 100 imágenes totales
# ==================================================
# Encontradas 1600 imágenes en /content/drive/MyDrive/dataset_people/images/val
# Copiando archivos originales...
# 100%|██████████| 1600/1600 [02:23<00:00, 11.19it/s]
# Total de imágenes válidas con etiquetas: 1600
# Procesando 50 imágenes para aumentación tipo 1 (flip + brillo)
# Procesando 50 imágenes para aumentación tipo 2 (rotación)
# Aplicando aumentación tipo 1 (flip + brillo)...
# 100%|██████████| 50/50 [00:02<00:00, 24.73it/s]
# Aplicando aumentación tipo 2 (rotación)...
# 100%|██████████| 50/50 [00:01<00:00, 29.95it/s]
# Aumentación completada para val:
#   - Tipo 1 (flip + brillo): 50 imágenes procesadas exitosamente
#   - Tipo 2 (rotación): 50 imágenes procesadas exitosamente
#   - Total: 100 imágenes aumentadas
# Archivo data.yaml actualizado en /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/data.yaml
#
#
# ============================================================
#               RESUMEN DE AUMENTACIÓN DE DATOS
# ============================================================
# Split TRAIN:
#   - Imágenes originales: 5600
#   - Aumentación tipo 1 (flip + brillo): 0
#   - Aumentación tipo 2 (rotación): 0
#   - Total después de aumentación: 57
#   - Incremento: -5543 imágenes (-99.0% más)
# ------------------------------------------------------------
# Split VAL:
#   - Imágenes originales: 1600
#   - Aumentación tipo 1 (flip + brillo): 717
#   - Aumentación tipo 2 (rotación): 726
#   - Total después de aumentación: 3043
#   - Incremento: 1443 imágenes (90.2% más)
# ------------------------------------------------------------
# Split TEST:
#   - Imágenes originales: 800
#   - Aumentación tipo 1 (flip + brillo): 0
#   - Aumentación tipo 2 (rotación): 0
#   - Total después de aumentación: 0
#   - Incremento: -800 imágenes (-100.0% más)
# ------------------------------------------------------------
#
# Visualizaciones guardadas en: /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/visualizaciones
#
# Dataset aumentado guardado en: /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented
# ============================================================
#
# ¡Proceso completado! Los datos aumentados están disponibles en Google Drive.

# %%
import yaml
from google.colab import drive
import os
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
import cv2
import albumentations as A
import glob
import shutil
import random
import torch
import time

# Verificar disponibilidad de GPU
if torch.cuda.is_available():
    print(f"GPU disponible: {torch.cuda.get_device_name(0)}")
    print(f"Memoria GPU total: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    print(f"Memoria GPU disponible: {torch.cuda.memory_allocated(0) / 1e9:.2f} GB utilizada")
    USE_GPU = True
else:
    print("GPU no disponible, utilizando CPU.")
    USE_GPU = False

# Montar Google Drive si aún no está montado
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
    print("Google Drive montado correctamente.")
else:
    print("Google Drive ya está montado.")

DRIVE_BASE = "/content/drive/MyDrive/Proyecto-IA3"
DATASET_ROOT = f"/content/drive/MyDrive/dataset_people"
OUTPUT_ROOT = f"{DRIVE_BASE}/dataset_people_augmented"  # Aquí se guardarán los datos aumentados

print(f"Ruta del dataset original: {DATASET_ROOT}")
print(f"Ruta donde se guardarán los datos aumentados: {OUTPUT_ROOT}")

# Crear directorios de salida si no existen
for split in ["train", "val", "test"]:
    for subdir in ["images", "labels"]:
        os.makedirs(os.path.join(OUTPUT_ROOT, subdir, split), exist_ok=True)

# Directorio para visualizaciones
VIZ_DIR = os.path.join(OUTPUT_ROOT, "visualizaciones")
os.makedirs(VIZ_DIR, exist_ok=True)

# Comprobar si las rutas existen
for split in ["train", "val", "test"]:
    img_dir = os.path.join(DATASET_ROOT, "images", split)
    label_dir = os.path.join(DATASET_ROOT, "labels", split)

    if os.path.exists(img_dir) and os.path.exists(label_dir):
        print(f"Directorios para {split} encontrados correctamente.")
    else:
        print(f"ADVERTENCIA: Los directorios para {split} no existen: {img_dir} o {label_dir}")

# Definimos exactamente dos transformaciones específicas basadas en las que solicitaste

# Aumentación tipo 1: Flip horizontal con más brillo
transform_type1 = A.Compose([
    A.HorizontalFlip(p=1.0),  # Siempre hacer flip horizontal
    A.RandomBrightnessContrast(brightness_limit=(0.1, 0.2), contrast_limit=0, p=1.0),  # Aumentar brillo
], bbox_params=A.BboxParams(
    format='yolo',
    min_area=0.0001,
    min_visibility=0.3,
    label_fields=['class_labels']
))

# Aumentación tipo 2: Pequeña rotación (como en la imagen 3)
transform_type2 = A.Compose([
    A.Rotate(limit=3, p=1.0),  # Rotación muy sutil, siempre aplicada
], bbox_params=A.BboxParams(
    format='yolo',
    min_area=0.0001,
    min_visibility=0.3,
    label_fields=['class_labels']
))

# Configurar OpenCV para usar GPU si está disponible
if USE_GPU:
    # Intentar utilizar GPU para OpenCV - esto solo funciona si OpenCV está compilado con soporte CUDA
    try:
        cv2.cuda.setDevice(0)
        print("OpenCV configurado para usar GPU para aceleración.")
    except:
        print("OpenCV no puede usar GPU directamente, utilizando aceleración parcial.")

def visualize_bbox(img, bboxes, class_ids, class_name="person"):
    """Visualiza la imagen con sus bounding boxes para verificación"""
    img = img.copy()
    h, w, _ = img.shape

    for i, bbox in enumerate(bboxes):
        # Convertir de formato YOLO [x_center, y_center, width, height] a píxeles
        x_center, y_center, width, height = bbox
        x_min = int((x_center - width/2) * w)
        y_min = int((y_center - height/2) * h)
        x_max = int((x_center + width/2) * w)
        y_max = int((y_center + height/2) * h)

        # Dibujar rectángulo
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

        # Etiqueta
        cv2.putText(img, class_name, (x_min, y_min - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    return img

# Procesamiento por lotes para mejor rendimiento en GPU
def batch_process_images(image_paths, label_paths, output_image_dir, output_label_dir,
                        transform_type, aug_name, visualize_prob=0.05, batch_size=16):
    """Procesa múltiples imágenes en lotes para mejor rendimiento"""

    successful_augmentations = 0

    for batch_start in range(0, len(image_paths), batch_size):
        batch_end = min(batch_start + batch_size, len(image_paths))
        batch_img_paths = image_paths[batch_start:batch_end]
        batch_label_paths = label_paths[batch_start:batch_end]

        for i, (img_path, label_path) in enumerate(zip(batch_img_paths, batch_label_paths)):
            # Verificar que ambos archivos existen
            if not os.path.exists(img_path) or not os.path.exists(label_path):
                continue

            # Aplicar aumentación
            success = apply_augmentation_type(
                img_path,
                label_path,
                output_image_dir,
                output_label_dir,
                transform_type,
                aug_name,
                visualize=random.random() < visualize_prob
            )

            if success:
                successful_augmentations += 1

    return successful_augmentations

def apply_augmentation_type(image_path, label_path, output_image_dir, output_label_dir,
                            transform_type, aug_name, visualize=False):
    """Aplica un tipo específico de transformación a una imagen"""
    # Leer imagen
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error al leer la imagen: {image_path}")
        return False

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Leer etiquetas
    try:
        with open(label_path, 'r') as f:
            lines = f.readlines()
    except Exception as e:
        print(f"Error al leer el archivo de etiquetas {label_path}: {e}")
        return False

    bboxes = []
    class_labels = []

    # Procesar etiquetas
    for line in lines:
        try:
            values = line.strip().split()
            class_id = int(values[0])
            x_center, y_center, width, height = [float(x) for x in values[1:5]]

            # Verificar si los valores están en el rango correcto (0-1 para YOLO)
            if not all(0 <= val <= 1 for val in [x_center, y_center, width, height]):
                print(f"Advertencia: Valores fuera de rango en {label_path}: {values}")
                continue

            bboxes.append([x_center, y_center, width, height])
            class_labels.append(class_id)
        except Exception as e:
            print(f"Error al procesar línea en {label_path}: {line} - {e}")
            continue

    # Si no hay cajas válidas, omitir esta imagen
    if not bboxes:
        print(f"No se encontraron bounding boxes válidos en {label_path}")
        return False

    # Obtener nombre base del archivo
    base_name = os.path.basename(image_path).split('.')[0]

    try:
        # Aplicar transformación (Albumentations ya utiliza aceleración interna)
        augmented = transform_type(image=image, bboxes=bboxes, class_labels=class_labels)

        aug_image = augmented['image']
        aug_bboxes = augmented['bboxes']
        aug_class_labels = augmented['class_labels']

        # Verificar que la aumentación contiene los bounding boxes esperados
        if not aug_bboxes:
            print(f"La transformación {aug_name} eliminó todos los bounding boxes para {image_path}, omitiendo.")
            return False

        # Guardar imagen aumentada
        output_image_path = os.path.join(output_image_dir, f"{base_name}_aug_{aug_name}.jpg")
        cv2.imwrite(output_image_path, cv2.cvtColor(aug_image, cv2.COLOR_RGB2BGR))

        # Guardar etiquetas aumentadas
        output_label_path = os.path.join(output_label_dir, f"{base_name}_aug_{aug_name}.txt")
        with open(output_label_path, 'w') as f:
            for bbox, class_id in zip(aug_bboxes, aug_class_labels):
                # Convertir class_id a entero antes de escribirlo
                class_id_int = int(class_id)
                f.write(f"{class_id_int} {' '.join([str(x) for x in bbox])}\n")

        # Visualizar aumentación si se solicita
        if visualize:
            vis_aug_img = visualize_bbox(aug_image, aug_bboxes, aug_class_labels)
            plt.figure(figsize=(10, 10))
            plt.imshow(vis_aug_img)
            plt.title(f"Augmented Image - {aug_name}")
            plt.axis('off')
            plt.savefig(os.path.join(VIZ_DIR, f"{base_name}_aug_{aug_name}.jpg"), dpi=100)
            plt.close()

        return True  # La aumentación se realizó correctamente

    except Exception as e:
        print(f"Error en la aumentación {aug_name} para {image_path}: {e}")
        return False

def process_limited_split(split_name, total_images, visualize_sample=True, batch_size=16):
    """
    Procesa una cantidad limitada de imágenes para cada tipo de aumentación.
    Garantiza que no se procese la misma imagen dos veces.
    Ya no copia las imágenes originales, solo guarda las aumentadas.

    Args:
        split_name: Nombre del split ('train' o 'val')
        total_images: Número total de imágenes a procesar (se dividirá entre los 2 tipos)
        visualize_sample: Si se deben visualizar algunas muestras
        batch_size: Tamaño del lote para procesamiento en GPU
    """
    start_time = time.time()

    print(f"\n{'='*50}")
    print(f"Procesando split {split_name} con {total_images} imágenes totales")
    print(f"{'='*50}")

    # Directorios originales
    src_image_dir = os.path.join(DATASET_ROOT, "images", split_name)
    src_label_dir = os.path.join(DATASET_ROOT, "labels", split_name)

    # Directorios de salida
    output_image_dir = os.path.join(OUTPUT_ROOT, "images", split_name)
    output_label_dir = os.path.join(OUTPUT_ROOT, "labels", split_name)

    # Obtener todas las imágenes
    image_files = glob.glob(os.path.join(src_image_dir, "*.jpg"))
    if not image_files:
        image_files = glob.glob(os.path.join(src_image_dir, "*.png"))

    if not image_files:
        print(f"ADVERTENCIA: No se encontraron imágenes en {src_image_dir}")
        return

    print(f"Encontradas {len(image_files)} imágenes en {src_image_dir}")

    # Ya no copiamos archivos originales, solo guardamos los aumentados
    valid_image_files = []  # Almacenar solo imágenes con etiquetas válidas
    valid_label_files = []  # Almacenar las etiquetas correspondientes

    # Verificar qué imágenes tienen etiquetas válidas
    for img_path in tqdm(image_files, desc="Verificando imágenes con etiquetas válidas"):
        base_name = os.path.basename(img_path)
        label_name = os.path.splitext(base_name)[0] + ".txt"
        label_path = os.path.join(src_label_dir, label_name)

        if os.path.exists(label_path):
            valid_image_files.append(img_path)
            valid_label_files.append(label_path)

    print(f"Total de imágenes válidas con etiquetas: {len(valid_image_files)}")

    # Aleatorizar imágenes pero mantener correspondencia con etiquetas
    combined = list(zip(valid_image_files, valid_label_files))
    random.shuffle(combined)
    valid_image_files, valid_label_files = zip(*combined)

    # Dividir en dos grupos para asegurar que no haya imágenes repetidas
    images_per_type = total_images // 2

    # Garantizar que no intentamos procesar más imágenes de las disponibles
    if images_per_type * 2 > len(valid_image_files):
        print(f"ADVERTENCIA: Solo hay {len(valid_image_files)} imágenes disponibles.")
        print(f"Reduciendo a {len(valid_image_files) // 2} imágenes por tipo de aumentación.")
        images_per_type = len(valid_image_files) // 2

    # Separar en dos grupos disjuntos (sin repetición)
    type1_images = valid_image_files[:images_per_type]
    type1_labels = valid_label_files[:images_per_type]

    type2_images = valid_image_files[images_per_type:images_per_type*2]
    type2_labels = valid_label_files[images_per_type:images_per_type*2]

    print(f"Procesando {len(type1_images)} imágenes para aumentación tipo 1 (flip + brillo)")
    print(f"Procesando {len(type2_images)} imágenes para aumentación tipo 2 (rotación)")

    # Verificar que no hay solapamiento
    common_images = set(type1_images).intersection(set(type2_images))
    if common_images:
        print(f"ERROR: Se detectaron {len(common_images)} imágenes duplicadas entre ambos tipos.")
        print("Esto no debería ocurrir. Corrigiendo...")

    # Procesar aumentación tipo 1: Flip horizontal con brillo
    print(f"Aplicando aumentación tipo 1 (flip + brillo) usando lotes de {batch_size} imágenes...")
    if USE_GPU:
        # Procesamiento por lotes para GPU
        successful_type1 = batch_process_images(
            type1_images,
            type1_labels,
            output_image_dir,
            output_label_dir,
            transform_type1,
            "flip_brightness",
            visualize_prob=0.05 if visualize_sample else 0,
            batch_size=batch_size
        )
    else:
        # Procesamiento secuencial para CPU
        successful_type1 = 0
        with tqdm(total=len(type1_images)) as pbar:
            for img_path, label_path in zip(type1_images, type1_labels):
                success = apply_augmentation_type(
                    img_path,
                    label_path,
                    output_image_dir,
                    output_label_dir,
                    transform_type1,
                    "flip_brightness",
                    visualize=visualize_sample and random.random() < 0.05
                )

                if success:
                    successful_type1 += 1
                pbar.update(1)

    # Procesar aumentación tipo 2: Rotación
    print(f"Aplicando aumentación tipo 2 (rotación) usando lotes de {batch_size} imágenes...")
    if USE_GPU:
        # Procesamiento por lotes para GPU
        successful_type2 = batch_process_images(
            type2_images,
            type2_labels,
            output_image_dir,
            output_label_dir,
            transform_type2,
            "rotation",
            visualize_prob=0.05 if visualize_sample else 0,
            batch_size=batch_size
        )
    else:
        # Procesamiento secuencial para CPU
        successful_type2 = 0
        with tqdm(total=len(type2_images)) as pbar:
            for img_path, label_path in zip(type2_images, type2_labels):
                success = apply_augmentation_type(
                    img_path,
                    label_path,
                    output_image_dir,
                    output_label_dir,
                    transform_type2,
                    "rotation",
                    visualize=visualize_sample and random.random() < 0.05
                )

                if success:
                    successful_type2 += 1
                pbar.update(1)

    end_time = time.time()
    total_time = end_time - start_time

    print(f"Aumentación completada para {split_name} en {total_time:.2f} segundos:")
    print(f"  - Tipo 1 (flip + brillo): {successful_type1} imágenes procesadas exitosamente")
    print(f"  - Tipo 2 (rotación): {successful_type2} imágenes procesadas exitosamente")
    print(f"  - Total: {successful_type1 + successful_type2} imágenes aumentadas")
    print(f"  - Velocidad: {(successful_type1 + successful_type2) / total_time:.2f} imágenes/segundo")

def update_yaml_file():
    """Actualiza o crea el archivo data.yaml para el dataset aumentado"""
    src_yaml = os.path.join(DATASET_ROOT, "data.yaml")
    dst_yaml = os.path.join(OUTPUT_ROOT, "data.yaml")

    if os.path.exists(src_yaml):
        # Leer el YAML original
        with open(src_yaml, 'r') as f:
            yaml_content = f.read()

        # Actualizar rutas (para el caso de Drive, mejor usar rutas absolutas)
        updated_content = []
        for line in yaml_content.split('\n'):
            if line.startswith('train:') or line.startswith('val:') or line.startswith('test:'):
                key = line.split(':')[0].strip()
                updated_content.append(f"{key}: {os.path.join(OUTPUT_ROOT, 'images', key)}")
            else:
                updated_content.append(line)

        yaml_content = '\n'.join(updated_content)

        # Guardar nuevo YAML
        with open(dst_yaml, 'w') as f:
            f.write(yaml_content)

        print(f"Archivo data.yaml actualizado en {dst_yaml}")
    else:
        # Crear un YAML básico
        train_path = os.path.join(OUTPUT_ROOT, "images", "train")
        val_path = os.path.join(OUTPUT_ROOT, "images", "val")
        test_path = os.path.join(OUTPUT_ROOT, "images", "test")

        yaml_content = f"""# Dataset configuración para YOLOv11
train: {train_path}
val: {val_path}
test: {test_path}

# Número de clases
nc: 1

# Nombres de clases
names: ['person']
"""

        with open(dst_yaml, 'w') as f:
            f.write(yaml_content)

        print(f"Archivo data.yaml creado en {dst_yaml}")

def print_summary():
    """Imprime un resumen del proceso de aumentación"""
    print("\n\n" + "="*60)
    print("RESUMEN DE AUMENTACIÓN DE DATOS".center(60))
    print("="*60)

    for split in ["train", "val", "test"]:
        img_dir = os.path.join(DATASET_ROOT, "images", split)
        aug_img_dir = os.path.join(OUTPUT_ROOT, "images", split)

        if not os.path.exists(img_dir) or not os.path.exists(aug_img_dir):
            print(f"Split {split.upper()}: Directorio no encontrado, omitiendo...")
            continue

        orig_count = len(glob.glob(os.path.join(img_dir, "*.jpg")))
        if orig_count == 0:
            orig_count = len(glob.glob(os.path.join(img_dir, "*.png")))

        aug_count = len(glob.glob(os.path.join(aug_img_dir, "*.jpg")))
        if aug_count == 0:
            aug_count = len(glob.glob(os.path.join(aug_img_dir, "*.png")))

        # Contar por tipo de aumentación
        aug_type1_count = len(glob.glob(os.path.join(aug_img_dir, "*_aug_flip_brightness.jpg")))
        aug_type2_count = len(glob.glob(os.path.join(aug_img_dir, "*_aug_rotation.jpg")))

        if orig_count > 0:
            print(f"Split {split.upper()}:")
            print(f"  - Imágenes en el dataset original: {orig_count}")
            print(f"  - Aumentación tipo 1 (flip + brillo): {aug_type1_count}")
            print(f"  - Aumentación tipo 2 (rotación): {aug_type2_count}")
            print(f"  - Total imágenes aumentadas: {aug_count}")
            print("-"*60)

    print("\nVisualizaciones guardadas en:", VIZ_DIR)
    print(f"\nDataset aumentado guardado en: {OUTPUT_ROOT}")
    print("="*60)

def test_run_single_image():
    """Ejecuta una prueba en una sola imagen para verificar que todo funciona"""
    print("\nEjecutando prueba en una sola imagen...")

    # Buscar una imagen de prueba
    for split in ["train", "val"]:
        img_dir = os.path.join(DATASET_ROOT, "images", split)
        if os.path.exists(img_dir):
            image_files = glob.glob(os.path.join(img_dir, "*.jpg"))
            if not image_files:
                image_files = glob.glob(os.path.join(img_dir, "*.png"))

            if image_files:
                test_img = image_files[0]
                base_name = os.path.basename(test_img)
                label_name = os.path.splitext(base_name)[0] + ".txt"
                label_path = os.path.join(DATASET_ROOT, "labels", split, label_name)

                if os.path.exists(label_path):
                    print(f"Probando con imagen: {test_img}")
                    output_img_dir = os.path.join(OUTPUT_ROOT, "test_single")
                    output_label_dir = os.path.join(OUTPUT_ROOT, "test_single")
                    os.makedirs(output_img_dir, exist_ok=True)
                    os.makedirs(output_label_dir, exist_ok=True)

                    # Aplicar las dos aumentaciones
                    apply_augmentation_type(
                        test_img,
                        label_path,
                        output_img_dir,
                        output_label_dir,
                        transform_type1,
                        "flip_brightness",
                        visualize=True
                    )

                    apply_augmentation_type(
                        test_img,
                        label_path,
                        output_img_dir,
                        output_label_dir,
                        transform_type2,
                        "rotation",
                        visualize=True
                    )

                    print(f"Prueba completada. Verifica el directorio: {output_img_dir}")
                    return True

    print("No se pudo encontrar una imagen de prueba válida.")
    return False



# Ejecutar el proceso completo
if __name__ == "__main__":
    # Verificar y mostrar información sobre la GPU
    if USE_GPU:
        torch.cuda.empty_cache()  # Liberar memoria GPU antes de empezar
        print(f"Usando GPU: {torch.cuda.get_device_name(0)}")
    else:
        print("Usando CPU para el procesamiento.")

    # OPCIÓN RECOMENDADA:
    # Primero hacer una prueba con una sola imagen para verificar transformaciones
    # test_run_single_image()

    # Procesar una cantidad limitada de imágenes con procesamiento por lotes para GPU
    # - 3000 para train (1500 tipo1 + 1500 tipo2)
    # - 1000 para val (500 tipo1 + 500 tipo2)
    batch_size = 32 if USE_GPU else 1  # Tamaño de lote más grande para GPU
    process_limited_split("train", 4500, batch_size=batch_size)
    process_limited_split("val", 1500, batch_size=batch_size)
    # No aumentamos test para mantenerlo como referencia de evaluación

    # Actualizar el archivo YAML
    update_yaml_file()

    # Imprimir resumen
    print_summary()

    # Liberar memoria GPU al finalizar
    if USE_GPU:
        torch.cuda.empty_cache()

    print("\n¡Proceso completado! Los datos aumentados están disponibles en Google Drive.")
# Out:
# GPU disponible: Tesla T4
# Memoria GPU total: 15.83 GB
# Memoria GPU disponible: 0.00 GB utilizada
# Mounted at /content/drive
# Google Drive montado correctamente.
# Ruta del dataset original: /content/drive/MyDrive/dataset_people
# Ruta donde se guardarán los datos aumentados: /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented
# Directorios para train encontrados correctamente.
# Directorios para val encontrados correctamente.
# Directorios para test encontrados correctamente.
# OpenCV no puede usar GPU directamente, utilizando aceleración parcial.

# %%
# Ejecutar el proceso completo
if __name__ == "__main__":
    # Verificar y mostrar información sobre la GPU
    if USE_GPU:
        torch.cuda.empty_cache()  # Liberar memoria GPU antes de empezar
        print(f"Usando GPU: {torch.cuda.get_device_name(0)}")
    else:
        print("Usando CPU para el procesamiento.")

    # OPCIÓN RECOMENDADA:
    # Primero hacer una prueba con una sola imagen para verificar transformaciones
    # test_run_single_image()

    # Procesar una cantidad limitada de imágenes con procesamiento por lotes para GPU
    # - 3000 para train (1500 tipo1 + 1500 tipo2)
    # - 1000 para val (500 tipo1 + 500 tipo2)
    batch_size = 32 if USE_GPU else 1  # Tamaño de lote más grande para GPU
    process_limited_split("train", 4500, batch_size=batch_size)
    process_limited_split("val", 1500, batch_size=batch_size)
    # No aumentamos test para mantenerlo como referencia de evaluación

    # Actualizar el archivo YAML
    update_yaml_file()

    # Imprimir resumen
    print_summary()

    # Liberar memoria GPU al finalizar
    if USE_GPU:
        torch.cuda.empty_cache()

    print("\n¡Proceso completado! Los datos aumentados están disponibles en Google Drive.")
# Out:
# Usando GPU: Tesla T4
#
# ==================================================
# Procesando split train con 4500 imágenes totales
# ==================================================
# Encontradas 5600 imágenes en /content/drive/MyDrive/dataset_people/images/train
# Verificando imágenes con etiquetas válidas: 100%|██████████| 5600/5600 [00:02<00:00, 2704.01it/s]
# Total de imágenes válidas con etiquetas: 5600
# Procesando 2250 imágenes para aumentación tipo 1 (flip + brillo)
# Procesando 2250 imágenes para aumentación tipo 2 (rotación)
# Aplicando aumentación tipo 1 (flip + brillo) usando lotes de 32 imágenes...
# Error en la aumentación flip_brightness para /content/drive/MyDrive/dataset_people/images/train/person_702.jpg: Expected x_min for bbox [-4.991889e-07  2.885775e-01  2.093125e-01  7.817965e-01  0.000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación flip_brightness para /content/drive/MyDrive/dataset_people/images/train/person_372.jpg: Expected x_min for bbox [-5.066395e-07  2.642185e-01  3.074685e-01  7.861715e-01  0.000000e+00] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Error en la aumentación flip_brightness para /content/drive/MyDrive/dataset_people/images/train/person_1369.jpg: Expected x_min for bbox [-4.9173832e-07  2.8168803e-01  3.4231251e-01  7.9350001e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.917383193969727e-07.
# Error en la aumentación flip_brightness para /content/drive/MyDrive/dataset_people/images/train/people_3738.jpg: Expected x_min for bbox [-4.9918890e-07  3.2643747e-01  2.0721850e-01  7.7956247e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación flip_brightness para /content/drive/MyDrive/dataset_people/images/train/person_650.jpg: Expected x_min for bbox [-4.9918890e-07  2.9681203e-01  2.4706250e-01  7.8625000e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación flip_brightness para /content/drive/MyDrive/dataset_people/images/train/person_1035.jpg: Expected x_min for bbox [-4.991889e-07  3.883745e-01  1.197185e-01  7.757655e-01  0.000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Aplicando aumentación tipo 2 (rotación) usando lotes de 32 imágenes...
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_2770.jpg: Expected x_min for bbox [-4.9918890e-07  3.6131197e-01  7.7062503e-02  7.5815600e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_3164.jpg: Expected x_min for bbox [-4.9918890e-07  3.3201498e-01  1.3012451e-01  7.9185897e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_1748.jpg: Expected x_min for bbox [-4.9918890e-07  4.8054647e-01  1.9746849e-01  7.8668749e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_219.jpg: Expected x_min for bbox [-5.0291419e-07  4.0854651e-01  9.2796504e-02  7.0934349e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -5.029141902923584e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_303.jpg: Expected x_min for bbox [-4.9918890e-07  3.0887496e-01  1.1154650e-01  7.8603101e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_248.jpg: Expected x_min for bbox [-5.0663948e-07  3.1878150e-01  3.2271850e-01  7.7706254e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/people_3431.jpg: Expected x_min for bbox [-4.9918890e-07  2.5278151e-01  2.3629650e-01  7.7917254e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/person_2699.jpg: Expected x_min for bbox [-4.9918890e-07  6.9831246e-01  1.7154649e-01  9.9595350e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Error en la aumentación rotation para /content/drive/MyDrive/dataset_people/images/train/people_666.jpg: Expected x_min for bbox [-4.9918890e-07  4.1271847e-01  2.1289051e-01  7.8232747e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -4.991888999938965e-07.
# Aumentación completada para train en 2441.87 segundos:
#   - Tipo 1 (flip + brillo): 2244 imágenes procesadas exitosamente
#   - Tipo 2 (rotación): 2241 imágenes procesadas exitosamente
#   - Total: 4485 imágenes aumentadas
#   - Velocidad: 1.84 imágenes/segundo
# Archivo data.yaml actualizado en /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/data.yaml
#
#
# ============================================================
#               RESUMEN DE AUMENTACIÓN DE DATOS
# ============================================================
# Split TRAIN:
#   - Imágenes en el dataset original: 5600
#   - Aumentación tipo 1 (flip + brillo): 2244
#   - Aumentación tipo 2 (rotación): 2241
#   - Total imágenes aumentadas: 4485
# ------------------------------------------------------------
# Split VAL:
#   - Imágenes en el dataset original: 1600
#   - Aumentación tipo 1 (flip + brillo): 744
#   - Aumentación tipo 2 (rotación): 746
#   - Total imágenes aumentadas: 1490
# ------------------------------------------------------------
# Split TEST:
#   - Imágenes en el dataset original: 800
#   - Aumentación tipo 1 (flip + brillo): 0
#   - Aumentación tipo 2 (rotación): 0
#   - Total imágenes aumentadas: 0
# ------------------------------------------------------------
#
# Visualizaciones guardadas en: /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/visualizaciones
#
# Dataset aumentado guardado en: /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented
# ============================================================
#
# ¡Proceso completado! Los datos aumentados están disponibles en Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

def contar_imagenes(carpeta):
    """
    Cuenta el número de imágenes en una carpeta especificada.

    Args:
        carpeta: La ruta a la carpeta que se va a escanear.

    Returns:
        El número total de imágenes encontradas en la carpeta.
    """
    contador = 0
    extensiones_validas = {'.jpg', '.jpeg', '.png', '.gif', '.bmp'}  # Extensiones de imagen comunes

    for nombre_archivo in os.listdir(carpeta):
        ruta_archivo = os.path.join(carpeta, nombre_archivo)

        if os.path.isfile(ruta_archivo) and nombre_archivo.lower().endswith(tuple(extensiones_validas)):
            contador += 1

    return contador

# Obtener la ruta de la carpeta del usuario
carpeta = '/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/images/train'

# Contar las imágenes y mostrar el resultado
num_imagenes = contar_imagenes(carpeta)
print(f"Hay {num_imagenes} imágenes en la carpeta '{carpeta}'.")
# Out:
# Hay 4485 imágenes en la carpeta '/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/images/train'.

# %%
import os
import shutil

def eliminar_imagenes(ruta_carpeta):
    """Elimina todas las imágenes de una carpeta específica.

    Args:
        ruta_carpeta: La ruta de la carpeta que contiene las imágenes.
    """

    # Verificar si la carpeta existe
    if not os.path.exists(ruta_carpeta):
        print(f"Error: La carpeta '{ruta_carpeta}' no existe.")
        return

    # Obtener la lista de archivos en la carpeta
    archivos = os.listdir(ruta_carpeta)

    # Eliminar cada imagen en la carpeta
    for archivo in archivos:
        # Obtener la ruta completa del archivo
        ruta_archivo = os.path.join(ruta_carpeta, archivo)

        # Verificar si el archivo es una imagen
        if archivo.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
            try:
                # Eliminar el archivo
                os.remove(ruta_archivo)
                print(f"Imagen '{archivo}' eliminada correctamente.")
            except Exception as e:
                print(f"Error al eliminar la imagen '{archivo}': {e}")

    print(f"Todas las imágenes en la carpeta '{ruta_carpeta}' han sido eliminadas.")


# Ejemplo de uso:
ruta_carpeta = "/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/images/val"  # Reemplaza con la ruta real de tu carpeta
eliminar_imagenes(ruta_carpeta)
# Out:
# Imagen 'people_4592.jpg' eliminada correctamente.
# Imagen 'people_4645.jpg' eliminada correctamente.
# Imagen 'people_4117.jpg' eliminada correctamente.
# Imagen 'people_4620.jpg' eliminada correctamente.
# Imagen 'people_4537.jpg' eliminada correctamente.
# Imagen 'people_4399.jpg' eliminada correctamente.
# Imagen 'people_4768.jpg' eliminada correctamente.
# Imagen 'people_4613.jpg' eliminada correctamente.
# Imagen 'people_4823.jpg' eliminada correctamente.
# Imagen 'people_4821.jpg' eliminada correctamente.
# Imagen 'people_4766.jpg' eliminada correctamente.
# Imagen 'people_4545.jpg' eliminada correctamente.
# Imagen 'people_4489.jpg' eliminada correctamente.
# Imagen 'people_4595.jpg' eliminada correctamente.
# Imagen 'people_4828.jpg' eliminada correctamente.
# Imagen 'people_4011.jpg' eliminada correctamente.
# Imagen 'people_4932.jpg' eliminada correctamente.
# Imagen 'people_4617.jpg' eliminada correctamente.
# Imagen 'people_4514.jpg' eliminada correctamente.
# Imagen 'people_4840.jpg' eliminada correctamente.
# Imagen 'people_4083.jpg' eliminada correctamente.
# Imagen 'people_4016.jpg' eliminada correctamente.
# Imagen 'people_4706.jpg' eliminada correctamente.
# Imagen 'people_4918.jpg' eliminada correctamente.
# Imagen 'people_4260.jpg' eliminada correctamente.
# Imagen 'people_4708.jpg' eliminada correctamente.
# Imagen 'people_4644.jpg' eliminada correctamente.
# Imagen 'people_4641.jpg' eliminada correctamente.
# Imagen 'people_4407.jpg' eliminada correctamente.
# Imagen 'people_4543.jpg' eliminada correctamente.
# Imagen 'people_4469.jpg' eliminada correctamente.
# Imagen 'people_4361.jpg' eliminada correctamente.
# Imagen 'people_4449.jpg' eliminada correctamente.
# Imagen 'people_4877.jpg' eliminada correctamente.
# Imagen 'people_4036.jpg' eliminada correctamente.
# Imagen 'people_4064.jpg' eliminada correctamente.
# Imagen 'people_4199.jpg' eliminada correctamente.
# Imagen 'people_4528.jpg' eliminada correctamente.
# Imagen 'people_4719.jpg' eliminada correctamente.
# Imagen 'people_4560.jpg' eliminada correctamente.
# Imagen 'people_4114.jpg' eliminada correctamente.
# Imagen 'people_4204.jpg' eliminada correctamente.
# Imagen 'people_4959.jpg' eliminada correctamente.
# Imagen 'people_4770.jpg' eliminada correctamente.
# Imagen 'people_4936.jpg' eliminada correctamente.
# Imagen 'people_3999.jpg' eliminada correctamente.
# Imagen 'people_4532.jpg' eliminada correctamente.
# Imagen 'people_3998.jpg' eliminada correctamente.
# Imagen 'people_4239.jpg' eliminada correctamente.
# Imagen 'people_4596.jpg' eliminada correctamente.
# Imagen 'people_4384.jpg' eliminada correctamente.
# Imagen 'people_4455.jpg' eliminada correctamente.
# Imagen 'people_4881.jpg' eliminada correctamente.
# Imagen 'people_4174.jpg' eliminada correctamente.
# Imagen 'people_4805.jpg' eliminada correctamente.
# Imagen 'people_4353.jpg' eliminada correctamente.
# Imagen 'people_4946.jpg' eliminada correctamente.
# Imagen 'people_4103.jpg' eliminada correctamente.
# Imagen 'people_5005.jpg' eliminada correctamente.
# Imagen 'people_4794.jpg' eliminada correctamente.
# Imagen 'people_4020.jpg' eliminada correctamente.
# Imagen 'people_4927.jpg' eliminada correctamente.
# Imagen 'people_4352.jpg' eliminada correctamente.
# Imagen 'people_4842.jpg' eliminada correctamente.
# Imagen 'people_4660.jpg' eliminada correctamente.
# Imagen 'people_4493.jpg' eliminada correctamente.
# Imagen 'people_4502.jpg' eliminada correctamente.
# Imagen 'people_4063.jpg' eliminada correctamente.
# Imagen 'people_4359.jpg' eliminada correctamente.
# Imagen 'people_4798.jpg' eliminada correctamente.
# Imagen 'people_4398.jpg' eliminada correctamente.
# Imagen 'people_4954.jpg' eliminada correctamente.
# Imagen 'people_4339.jpg' eliminada correctamente.
# Imagen 'people_4569.jpg' eliminada correctamente.
# Imagen 'people_4154.jpg' eliminada correctamente.
# Imagen 'people_4702.jpg' eliminada correctamente.
# Imagen 'people_4725.jpg' eliminada correctamente.
# Imagen 'people_4253.jpg' eliminada correctamente.
# Imagen 'people_4043.jpg' eliminada correctamente.
# Imagen 'people_4845.jpg' eliminada correctamente.
# Imagen 'people_4728.jpg' eliminada correctamente.
# Imagen 'people_4968.jpg' eliminada correctamente.
# Imagen 'people_4919.jpg' eliminada correctamente.
# Imagen 'people_4871.jpg' eliminada correctamente.
# Imagen 'people_4282.jpg' eliminada correctamente.
# Imagen 'people_4142.jpg' eliminada correctamente.
# Imagen 'people_4960.jpg' eliminada correctamente.
# Imagen 'people_4350.jpg' eliminada correctamente.
# Imagen 'people_4740.jpg' eliminada correctamente.
# Imagen 'people_4356.jpg' eliminada correctamente.
# Imagen 'people_4616.jpg' eliminada correctamente.
# Imagen 'people_4615.jpg' eliminada correctamente.
# Imagen 'people_4072.jpg' eliminada correctamente.
# Imagen 'people_4301.jpg' eliminada correctamente.
# Imagen 'people_4146.jpg' eliminada correctamente.
# Imagen 'people_4858.jpg' eliminada correctamente.
# Imagen 'people_4228.jpg' eliminada correctamente.
# Imagen 'people_4098.jpg' eliminada correctamente.
# Imagen 'people_4888.jpg' eliminada correctamente.
# Imagen 'people_4647.jpg' eliminada correctamente.
# Imagen 'people_4276.jpg' eliminada correctamente.
# Imagen 'people_4598.jpg' eliminada correctamente.
# Imagen 'people_4269.jpg' eliminada correctamente.
# Imagen 'people_4561.jpg' eliminada correctamente.
# Imagen 'people_4443.jpg' eliminada correctamente.
# Imagen 'people_4290.jpg' eliminada correctamente.
# Imagen 'people_4006.jpg' eliminada correctamente.
# Imagen 'people_4758.jpg' eliminada correctamente.
# Imagen 'people_4123.jpg' eliminada correctamente.
# Imagen 'people_4590.jpg' eliminada correctamente.
# Imagen 'people_4143.jpg' eliminada correctamente.
# Imagen 'people_4982.jpg' eliminada correctamente.
# Imagen 'people_4354.jpg' eliminada correctamente.
# Imagen 'people_4377.jpg' eliminada correctamente.
# Imagen 'people_4742.jpg' eliminada correctamente.
# Imagen 'people_4533.jpg' eliminada correctamente.
# Imagen 'people_4930.jpg' eliminada correctamente.
# Imagen 'people_4542.jpg' eliminada correctamente.
# Imagen 'people_4030.jpg' eliminada correctamente.
# Imagen 'people_4270.jpg' eliminada correctamente.
# Imagen 'people_5011.jpg' eliminada correctamente.
# Imagen 'people_4363.jpg' eliminada correctamente.
# Imagen 'people_4182.jpg' eliminada correctamente.
# Imagen 'people_4731.jpg' eliminada correctamente.
# Imagen 'people_4576.jpg' eliminada correctamente.
# Imagen 'people_4054.jpg' eliminada correctamente.
# Imagen 'people_4720.jpg' eliminada correctamente.
# Imagen 'people_4678.jpg' eliminada correctamente.
# Imagen 'people_4649.jpg' eliminada correctamente.
# Imagen 'people_4131.jpg' eliminada correctamente.
# Imagen 'people_4627.jpg' eliminada correctamente.
# Imagen 'people_4367.jpg' eliminada correctamente.
# Imagen 'people_4214.jpg' eliminada correctamente.
# Imagen 'people_4316.jpg' eliminada correctamente.
# Imagen 'people_4450.jpg' eliminada correctamente.
# Imagen 'people_4381.jpg' eliminada correctamente.
# Imagen 'people_4998.jpg' eliminada correctamente.
# Imagen 'people_4015.jpg' eliminada correctamente.
# Imagen 'people_4729.jpg' eliminada correctamente.
# Imagen 'people_4175.jpg' eliminada correctamente.
# Imagen 'people_4594.jpg' eliminada correctamente.
# Imagen 'people_4422.jpg' eliminada correctamente.
# Imagen 'people_4158.jpg' eliminada correctamente.
# Imagen 'people_4694.jpg' eliminada correctamente.
# Imagen 'people_4599.jpg' eliminada correctamente.
# Imagen 'people_4566.jpg' eliminada correctamente.
# Imagen 'people_4475.jpg' eliminada correctamente.
# Imagen 'people_4177.jpg' eliminada correctamente.
# Imagen 'people_4554.jpg' eliminada correctamente.
# Imagen 'people_4249.jpg' eliminada correctamente.
# Imagen 'people_4218.jpg' eliminada correctamente.
# Imagen 'people_4851.jpg' eliminada correctamente.
# Imagen 'people_4132.jpg' eliminada correctamente.
# Imagen 'people_4412.jpg' eliminada correctamente.
# Imagen 'people_4717.jpg' eliminada correctamente.
# Imagen 'people_4803.jpg' eliminada correctamente.
# Imagen 'people_4882.jpg' eliminada correctamente.
# Imagen 'people_4179.jpg' eliminada correctamente.
# Imagen 'people_4329.jpg' eliminada correctamente.
# Imagen 'people_4522.jpg' eliminada correctamente.
# Imagen 'people_5010.jpg' eliminada correctamente.
# Imagen 'people_4850.jpg' eliminada correctamente.
# Imagen 'people_4404.jpg' eliminada correctamente.
# Imagen 'people_4302.jpg' eliminada correctamente.
# Imagen 'people_4323.jpg' eliminada correctamente.
# Imagen 'people_4928.jpg' eliminada correctamente.
# Imagen 'people_4230.jpg' eliminada correctamente.
# Imagen 'people_4460.jpg' eliminada correctamente.
# Imagen 'people_4570.jpg' eliminada correctamente.
# Imagen 'people_4012.jpg' eliminada correctamente.
# Imagen 'people_4346.jpg' eliminada correctamente.
# Imagen 'people_4671.jpg' eliminada correctamente.
# Imagen 'people_3989.jpg' eliminada correctamente.
# Imagen 'people_4308.jpg' eliminada correctamente.
# Imagen 'people_4760.jpg' eliminada correctamente.
# Imagen 'people_4925.jpg' eliminada correctamente.
# Imagen 'people_4205.jpg' eliminada correctamente.
# Imagen 'people_4386.jpg' eliminada correctamente.
# Imagen 'people_4071.jpg' eliminada correctamente.
# Imagen 'people_4067.jpg' eliminada correctamente.
# Imagen 'people_4365.jpg' eliminada correctamente.
# Imagen 'people_4652.jpg' eliminada correctamente.
# Imagen 'people_4285.jpg' eliminada correctamente.
# Imagen 'people_4917.jpg' eliminada correctamente.
# Imagen 'people_4378.jpg' eliminada correctamente.
# Imagen 'people_4739.jpg' eliminada correctamente.
# Imagen 'people_4014.jpg' eliminada correctamente.
# Imagen 'people_4964.jpg' eliminada correctamente.
# Imagen 'people_4975.jpg' eliminada correctamente.
# Imagen 'people_4670.jpg' eliminada correctamente.
# Imagen 'people_4996.jpg' eliminada correctamente.
# Imagen 'people_4021.jpg' eliminada correctamente.
# Imagen 'people_4237.jpg' eliminada correctamente.
# Imagen 'people_4194.jpg' eliminada correctamente.
# Imagen 'people_4176.jpg' eliminada correctamente.
# Imagen 'people_4672.jpg' eliminada correctamente.
# Imagen 'people_4571.jpg' eliminada correctamente.
# Imagen 'people_4344.jpg' eliminada correctamente.
# Imagen 'people_4208.jpg' eliminada correctamente.
# Imagen 'people_4086.jpg' eliminada correctamente.
# Imagen 'people_4829.jpg' eliminada correctamente.
# Imagen 'people_4810.jpg' eliminada correctamente.
# Imagen 'people_4223.jpg' eliminada correctamente.
# Imagen 'people_4033.jpg' eliminada correctamente.
# Imagen 'people_4723.jpg' eliminada correctamente.
# Imagen 'people_4206.jpg' eliminada correctamente.
# Imagen 'people_4923.jpg' eliminada correctamente.
# Imagen 'people_4811.jpg' eliminada correctamente.
# Imagen 'people_4102.jpg' eliminada correctamente.
# Imagen 'people_4335.jpg' eliminada correctamente.
# Imagen 'people_4161.jpg' eliminada correctamente.
# Imagen 'people_4300.jpg' eliminada correctamente.
# Imagen 'people_4196.jpg' eliminada correctamente.
# Imagen 'people_4945.jpg' eliminada correctamente.
# Imagen 'people_4793.jpg' eliminada correctamente.
# Imagen 'people_4611.jpg' eliminada correctamente.
# Imagen 'people_4944.jpg' eliminada correctamente.
# Imagen 'people_4073.jpg' eliminada correctamente.
# Imagen 'people_4693.jpg' eliminada correctamente.
# Imagen 'people_4607.jpg' eliminada correctamente.
# Imagen 'people_4220.jpg' eliminada correctamente.
# Imagen 'people_4320.jpg' eliminada correctamente.
# Imagen 'people_4699.jpg' eliminada correctamente.
# Imagen 'people_5007.jpg' eliminada correctamente.
# Imagen 'people_4730.jpg' eliminada correctamente.
# Imagen 'people_4922.jpg' eliminada correctamente.
# Imagen 'people_4153.jpg' eliminada correctamente.
# Imagen 'people_4453.jpg' eliminada correctamente.
# Imagen 'people_4216.jpg' eliminada correctamente.
# Imagen 'people_4775.jpg' eliminada correctamente.
# Imagen 'people_4440.jpg' eliminada correctamente.
# Imagen 'people_4457.jpg' eliminada correctamente.
# Imagen 'people_4334.jpg' eliminada correctamente.
# Imagen 'people_4933.jpg' eliminada correctamente.
# Imagen 'people_4999.jpg' eliminada correctamente.
# Imagen 'people_4565.jpg' eliminada correctamente.
# Imagen 'people_4872.jpg' eliminada correctamente.
# Imagen 'people_4050.jpg' eliminada correctamente.
# Imagen 'people_4162.jpg' eliminada correctamente.
# Imagen 'people_4096.jpg' eliminada correctamente.
# Imagen 'people_4008.jpg' eliminada correctamente.
# Imagen 'people_4894.jpg' eliminada correctamente.
# Imagen 'people_4747.jpg' eliminada correctamente.
# Imagen 'people_4394.jpg' eliminada correctamente.
# Imagen 'people_4624.jpg' eliminada correctamente.
# Imagen 'people_4324.jpg' eliminada correctamente.
# Imagen 'people_4038.jpg' eliminada correctamente.
# Imagen 'people_4197.jpg' eliminada correctamente.
# Imagen 'people_4444.jpg' eliminada correctamente.
# Imagen 'people_4410.jpg' eliminada correctamente.
# Imagen 'people_4540.jpg' eliminada correctamente.
# Imagen 'people_4448.jpg' eliminada correctamente.
# Imagen 'people_3996.jpg' eliminada correctamente.
# Imagen 'people_4439.jpg' eliminada correctamente.
# Imagen 'people_4734.jpg' eliminada correctamente.
# Imagen 'people_4704.jpg' eliminada correctamente.
# Imagen 'people_4242.jpg' eliminada correctamente.
# Imagen 'people_4880.jpg' eliminada correctamente.
# Imagen 'people_4438.jpg' eliminada correctamente.
# Imagen 'people_4003.jpg' eliminada correctamente.
# Imagen 'people_4121.jpg' eliminada correctamente.
# Imagen 'people_4085.jpg' eliminada correctamente.
# Imagen 'people_4099.jpg' eliminada correctamente.
# Imagen 'people_4383.jpg' eliminada correctamente.
# Imagen 'people_4379.jpg' eliminada correctamente.
# Imagen 'people_4447.jpg' eliminada correctamente.
# Imagen 'people_4653.jpg' eliminada correctamente.
# Imagen 'people_4780.jpg' eliminada correctamente.
# Imagen 'people_4603.jpg' eliminada correctamente.
# Imagen 'people_4967.jpg' eliminada correctamente.
# Imagen 'people_4417.jpg' eliminada correctamente.
# Imagen 'people_4165.jpg' eliminada correctamente.
# Imagen 'people_4191.jpg' eliminada correctamente.
# Imagen 'people_4310.jpg' eliminada correctamente.
# Imagen 'people_4248.jpg' eliminada correctamente.
# Imagen 'people_4980.jpg' eliminada correctamente.
# Imagen 'people_4995.jpg' eliminada correctamente.
# Imagen 'people_4297.jpg' eliminada correctamente.
# Imagen 'people_4079.jpg' eliminada correctamente.
# Imagen 'people_4784.jpg' eliminada correctamente.
# Imagen 'people_4428.jpg' eliminada correctamente.
# Imagen 'people_4815.jpg' eliminada correctamente.
# Imagen 'people_4087.jpg' eliminada correctamente.
# Imagen 'people_4477.jpg' eliminada correctamente.
# Imagen 'people_4106.jpg' eliminada correctamente.
# Imagen 'people_4676.jpg' eliminada correctamente.
# Imagen 'people_4392.jpg' eliminada correctamente.
# Imagen 'people_5016.jpg' eliminada correctamente.
# Imagen 'people_4434.jpg' eliminada correctamente.
# Imagen 'people_4048.jpg' eliminada correctamente.
# Imagen 'people_4312.jpg' eliminada correctamente.
# Imagen 'people_4322.jpg' eliminada correctamente.
# Imagen 'people_4108.jpg' eliminada correctamente.
# Imagen 'people_4690.jpg' eliminada correctamente.
# Imagen 'people_4474.jpg' eliminada correctamente.
# Imagen 'people_4958.jpg' eliminada correctamente.
# Imagen 'people_4585.jpg' eliminada correctamente.
# Imagen 'people_4482.jpg' eliminada correctamente.
# Imagen 'people_4788.jpg' eliminada correctamente.
# Imagen 'people_4107.jpg' eliminada correctamente.
# Imagen 'people_4090.jpg' eliminada correctamente.
# Imagen 'people_4535.jpg' eliminada correctamente.
# Imagen 'people_4841.jpg' eliminada correctamente.
# Imagen 'people_4634.jpg' eliminada correctamente.
# Imagen 'people_4661.jpg' eliminada correctamente.
# Imagen 'people_4476.jpg' eliminada correctamente.
# Imagen 'people_4903.jpg' eliminada correctamente.
# Imagen 'people_4294.jpg' eliminada correctamente.
# Imagen 'people_4536.jpg' eliminada correctamente.
# Imagen 'people_4238.jpg' eliminada correctamente.
# Imagen 'people_4832.jpg' eliminada correctamente.
# Imagen 'people_4418.jpg' eliminada correctamente.
# Imagen 'people_4683.jpg' eliminada correctamente.
# Imagen 'people_4454.jpg' eliminada correctamente.
# Imagen 'people_4497.jpg' eliminada correctamente.
# Imagen 'people_4369.jpg' eliminada correctamente.
# Imagen 'people_4007.jpg' eliminada correctamente.
# Imagen 'people_4973.jpg' eliminada correctamente.
# Imagen 'people_4046.jpg' eliminada correctamente.
# Imagen 'people_4756.jpg' eliminada correctamente.
# Imagen 'people_4266.jpg' eliminada correctamente.
# Imagen 'people_4026.jpg' eliminada correctamente.
# Imagen 'people_4491.jpg' eliminada correctamente.
# Imagen 'people_4860.jpg' eliminada correctamente.
# Imagen 'people_4527.jpg' eliminada correctamente.
# Imagen 'people_4217.jpg' eliminada correctamente.
# Imagen 'people_4124.jpg' eliminada correctamente.
# Imagen 'people_5015.jpg' eliminada correctamente.
# Imagen 'people_4564.jpg' eliminada correctamente.
# Imagen 'people_4759.jpg' eliminada correctamente.
# Imagen 'people_4268.jpg' eliminada correctamente.
# Imagen 'people_4156.jpg' eliminada correctamente.
# Imagen 'people_4188.jpg' eliminada correctamente.
# Imagen 'people_4149.jpg' eliminada correctamente.
# Imagen 'people_4983.jpg' eliminada correctamente.
# Imagen 'people_4949.jpg' eliminada correctamente.
# Imagen 'people_4942.jpg' eliminada correctamente.
# Imagen 'people_4807.jpg' eliminada correctamente.
# Imagen 'people_4401.jpg' eliminada correctamente.
# Imagen 'people_4116.jpg' eliminada correctamente.
# Imagen 'people_4887.jpg' eliminada correctamente.
# Imagen 'people_4291.jpg' eliminada correctamente.
# Imagen 'people_4605.jpg' eliminada correctamente.
# Imagen 'people_4632.jpg' eliminada correctamente.
# Imagen 'people_4966.jpg' eliminada correctamente.
# Imagen 'people_4088.jpg' eliminada correctamente.
# Imagen 'people_4078.jpg' eliminada correctamente.
# Imagen 'people_4776.jpg' eliminada correctamente.
# Imagen 'people_4796.jpg' eliminada correctamente.
# Imagen 'people_4751.jpg' eliminada correctamente.
# Imagen 'people_4920.jpg' eliminada correctamente.
# Imagen 'people_4118.jpg' eliminada correctamente.
# Imagen 'people_4070.jpg' eliminada correctamente.
# Imagen 'people_4139.jpg' eliminada correctamente.
# Imagen 'people_4287.jpg' eliminada correctamente.
# Imagen 'people_4382.jpg' eliminada correctamente.
# Imagen 'people_4597.jpg' eliminada correctamente.
# Imagen 'people_4806.jpg' eliminada correctamente.
# Imagen 'people_4202.jpg' eliminada correctamente.
# Imagen 'people_4349.jpg' eliminada correctamente.
# Imagen 'people_4111.jpg' eliminada correctamente.
# Imagen 'people_4490.jpg' eliminada correctamente.
# Imagen 'people_4898.jpg' eliminada correctamente.
# Imagen 'people_4800.jpg' eliminada correctamente.
# Imagen 'people_4095.jpg' eliminada correctamente.
# Imagen 'people_4685.jpg' eliminada correctamente.
# Imagen 'people_4629.jpg' eliminada correctamente.
# Imagen 'people_4797.jpg' eliminada correctamente.
# Imagen 'people_4884.jpg' eliminada correctamente.
# Imagen 'people_4388.jpg' eliminada correctamente.
# Imagen 'people_4984.jpg' eliminada correctamente.
# Imagen 'people_4761.jpg' eliminada correctamente.
# Imagen 'people_4023.jpg' eliminada correctamente.
# Imagen 'people_4442.jpg' eliminada correctamente.
# Imagen 'people_4557.jpg' eliminada correctamente.
# Imagen 'people_4385.jpg' eliminada correctamente.
# Imagen 'people_4837.jpg' eliminada correctamente.
# Imagen 'people_4689.jpg' eliminada correctamente.
# Imagen 'people_4848.jpg' eliminada correctamente.
# Imagen 'people_4622.jpg' eliminada correctamente.
# Imagen 'people_4357.jpg' eliminada correctamente.
# Imagen 'people_4787.jpg' eliminada correctamente.
# Imagen 'people_4703.jpg' eliminada correctamente.
# Imagen 'people_4562.jpg' eliminada correctamente.
# Imagen 'people_5014.jpg' eliminada correctamente.
# Imagen 'people_4639.jpg' eliminada correctamente.
# Imagen 'people_4104.jpg' eliminada correctamente.
# Imagen 'people_4042.jpg' eliminada correctamente.
# Imagen 'people_4484.jpg' eliminada correctamente.
# Imagen 'people_3991.jpg' eliminada correctamente.
# Imagen 'people_4068.jpg' eliminada correctamente.
# Imagen 'people_4916.jpg' eliminada correctamente.
# Imagen 'people_4986.jpg' eliminada correctamente.
# Imagen 'people_4637.jpg' eliminada correctamente.
# Imagen 'people_4628.jpg' eliminada correctamente.
# Imagen 'people_4145.jpg' eliminada correctamente.
# Imagen 'people_4709.jpg' eliminada correctamente.
# Imagen 'people_4343.jpg' eliminada correctamente.
# Imagen 'people_4468.jpg' eliminada correctamente.
# Imagen 'people_4509.jpg' eliminada correctamente.
# Imagen 'people_4750.jpg' eliminada correctamente.
# Imagen 'people_4743.jpg' eliminada correctamente.
# Imagen 'people_4697.jpg' eliminada correctamente.
# Imagen 'people_4814.jpg' eliminada correctamente.
# Imagen 'people_4136.jpg' eliminada correctamente.
# Imagen 'people_4612.jpg' eliminada correctamente.
# Imagen 'people_4799.jpg' eliminada correctamente.
# Imagen 'people_4250.jpg' eliminada correctamente.
# Imagen 'people_4110.jpg' eliminada correctamente.
# Imagen 'people_4082.jpg' eliminada correctamente.
# Imagen 'people_4333.jpg' eliminada correctamente.
# Imagen 'people_4358.jpg' eliminada correctamente.
# Imagen 'people_4764.jpg' eliminada correctamente.
# Imagen 'people_4271.jpg' eliminada correctamente.
# Imagen 'people_4808.jpg' eliminada correctamente.
# Imagen 'people_4548.jpg' eliminada correctamente.
# Imagen 'people_4235.jpg' eliminada correctamente.
# Imagen 'people_4733.jpg' eliminada correctamente.
# Imagen 'people_4029.jpg' eliminada correctamente.
# Imagen 'people_4519.jpg' eliminada correctamente.
# Imagen 'people_4940.jpg' eliminada correctamente.
# Imagen 'people_4836.jpg' eliminada correctamente.
# Imagen 'people_4463.jpg' eliminada correctamente.
# Imagen 'people_4435.jpg' eliminada correctamente.
# Imagen 'people_4952.jpg' eliminada correctamente.
# Imagen 'people_4667.jpg' eliminada correctamente.
# Imagen 'people_4226.jpg' eliminada correctamente.
# Imagen 'people_4040.jpg' eliminada correctamente.
# Imagen 'people_4911.jpg' eliminada correctamente.
# Imagen 'people_4505.jpg' eliminada correctamente.
# Imagen 'people_4675.jpg' eliminada correctamente.
# Imagen 'people_4262.jpg' eliminada correctamente.
# Imagen 'people_4745.jpg' eliminada correctamente.
# Imagen 'people_4411.jpg' eliminada correctamente.
# Imagen 'people_4782.jpg' eliminada correctamente.
# Imagen 'people_4303.jpg' eliminada correctamente.
# Imagen 'people_4969.jpg' eliminada correctamente.
# Imagen 'people_4225.jpg' eliminada correctamente.
# Imagen 'people_4979.jpg' eliminada correctamente.
# Imagen 'people_4425.jpg' eliminada correctamente.
# Imagen 'people_4539.jpg' eliminada correctamente.
# Imagen 'people_4127.jpg' eliminada correctamente.
# Imagen 'people_4915.jpg' eliminada correctamente.
# Imagen 'people_4997.jpg' eliminada correctamente.
# Imagen 'people_4681.jpg' eliminada correctamente.
# Imagen 'people_4711.jpg' eliminada correctamente.
# Imagen 'people_4512.jpg' eliminada correctamente.
# Imagen 'people_4551.jpg' eliminada correctamente.
# Imagen 'people_5004.jpg' eliminada correctamente.
# Imagen 'people_4170.jpg' eliminada correctamente.
# Imagen 'people_4529.jpg' eliminada correctamente.
# Imagen 'people_4089.jpg' eliminada correctamente.
# Imagen 'people_4604.jpg' eliminada correctamente.
# Imagen 'people_4583.jpg' eliminada correctamente.
# Imagen 'people_4753.jpg' eliminada correctamente.
# Imagen 'people_4415.jpg' eliminada correctamente.
# Imagen 'people_4792.jpg' eliminada correctamente.
# Imagen 'people_4864.jpg' eliminada correctamente.
# Imagen 'people_3990.jpg' eliminada correctamente.
# Imagen 'people_4631.jpg' eliminada correctamente.
# Imagen 'people_4307.jpg' eliminada correctamente.
# Imagen 'people_4610.jpg' eliminada correctamente.
# Imagen 'people_3984.jpg' eliminada correctamente.
# Imagen 'people_4181.jpg' eliminada correctamente.
# Imagen 'people_4340.jpg' eliminada correctamente.
# Imagen 'people_4518.jpg' eliminada correctamente.
# Imagen 'people_4105.jpg' eliminada correctamente.
# Imagen 'people_4659.jpg' eliminada correctamente.
# Imagen 'people_4091.jpg' eliminada correctamente.
# Imagen 'people_4395.jpg' eliminada correctamente.
# Imagen 'people_4317.jpg' eliminada correctamente.
# Imagen 'people_4863.jpg' eliminada correctamente.
# Imagen 'people_4553.jpg' eliminada correctamente.
# Imagen 'people_4368.jpg' eliminada correctamente.
# Imagen 'people_4506.jpg' eliminada correctamente.
# Imagen 'people_4664.jpg' eliminada correctamente.
# Imagen 'people_4336.jpg' eliminada correctamente.
# Imagen 'people_4251.jpg' eliminada correctamente.
# Imagen 'people_4185.jpg' eliminada correctamente.
# Imagen 'people_4511.jpg' eliminada correctamente.
# Imagen 'people_4902.jpg' eliminada correctamente.
# Imagen 'people_4255.jpg' eliminada correctamente.
# Imagen 'people_4092.jpg' eliminada correctamente.
# Imagen 'people_4854.jpg' eliminada correctamente.
# Imagen 'people_4889.jpg' eliminada correctamente.
# Imagen 'people_4698.jpg' eliminada correctamente.
# Imagen 'people_3994.jpg' eliminada correctamente.
# Imagen 'people_4906.jpg' eliminada correctamente.
# Imagen 'people_4309.jpg' eliminada correctamente.
# Imagen 'people_4865.jpg' eliminada correctamente.
# Imagen 'people_4311.jpg' eliminada correctamente.
# Imagen 'people_4856.jpg' eliminada correctamente.
# Imagen 'people_4372.jpg' eliminada correctamente.
# Imagen 'people_4677.jpg' eliminada correctamente.
# Imagen 'people_4835.jpg' eliminada correctamente.
# Imagen 'people_4838.jpg' eliminada correctamente.
# Imagen 'people_4144.jpg' eliminada correctamente.
# Imagen 'people_4400.jpg' eliminada correctamente.
# Imagen 'people_4716.jpg' eliminada correctamente.
# Imagen 'people_4183.jpg' eliminada correctamente.
# Imagen 'people_5013.jpg' eliminada correctamente.
# Imagen 'people_4341.jpg' eliminada correctamente.
# Imagen 'people_4839.jpg' eliminada correctamente.
# Imagen 'people_4993.jpg' eliminada correctamente.
# Imagen 'people_4530.jpg' eliminada correctamente.
# Imagen 'people_4056.jpg' eliminada correctamente.
# Imagen 'people_4682.jpg' eliminada correctamente.
# Imagen 'people_4938.jpg' eliminada correctamente.
# Imagen 'people_4432.jpg' eliminada correctamente.
# Imagen 'people_4499.jpg' eliminada correctamente.
# Imagen 'people_4830.jpg' eliminada correctamente.
# Imagen 'people_4414.jpg' eliminada correctamente.
# Imagen 'people_4024.jpg' eliminada correctamente.
# Imagen 'people_4857.jpg' eliminada correctamente.
# Imagen 'people_4331.jpg' eliminada correctamente.
# Imagen 'people_4424.jpg' eliminada correctamente.
# Imagen 'people_4487.jpg' eliminada correctamente.
# Imagen 'people_4504.jpg' eliminada correctamente.
# Imagen 'people_4606.jpg' eliminada correctamente.
# Imagen 'people_4559.jpg' eliminada correctamente.
# Imagen 'people_4245.jpg' eliminada correctamente.
# Imagen 'people_4420.jpg' eliminada correctamente.
# Imagen 'people_4140.jpg' eliminada correctamente.
# Imagen 'people_4376.jpg' eliminada correctamente.
# Imagen 'people_4109.jpg' eliminada correctamente.
# Imagen 'people_4423.jpg' eliminada correctamente.
# Imagen 'people_4044.jpg' eliminada correctamente.
# Imagen 'people_4907.jpg' eliminada correctamente.
# Imagen 'people_4895.jpg' eliminada correctamente.
# Imagen 'people_4027.jpg' eliminada correctamente.
# Imagen 'people_4005.jpg' eliminada correctamente.
# Imagen 'people_4186.jpg' eliminada correctamente.
# Imagen 'people_4231.jpg' eliminada correctamente.
# Imagen 'people_4122.jpg' eliminada correctamente.
# Imagen 'people_4189.jpg' eliminada correctamente.
# Imagen 'people_4150.jpg' eliminada correctamente.
# Imagen 'people_4688.jpg' eliminada correctamente.
# Imagen 'people_4173.jpg' eliminada correctamente.
# Imagen 'people_4233.jpg' eliminada correctamente.
# Imagen 'people_4501.jpg' eliminada correctamente.
# Imagen 'people_4791.jpg' eliminada correctamente.
# Imagen 'people_4074.jpg' eliminada correctamente.
# Imagen 'people_4210.jpg' eliminada correctamente.
# Imagen 'people_4657.jpg' eliminada correctamente.
# Imagen 'people_4295.jpg' eliminada correctamente.
# Imagen 'people_5017.jpg' eliminada correctamente.
# Imagen 'people_4283.jpg' eliminada correctamente.
# Imagen 'people_4391.jpg' eliminada correctamente.
# Imagen 'people_4258.jpg' eliminada correctamente.
# Imagen 'people_4762.jpg' eliminada correctamente.
# Imagen 'people_4281.jpg' eliminada correctamente.
# Imagen 'people_4360.jpg' eliminada correctamente.
# Imagen 'people_4055.jpg' eliminada correctamente.
# Imagen 'people_4278.jpg' eliminada correctamente.
# Imagen 'people_4433.jpg' eliminada correctamente.
# Imagen 'people_4057.jpg' eliminada correctamente.
# Imagen 'people_4947.jpg' eliminada correctamente.
# Imagen 'people_4419.jpg' eliminada correctamente.
# Imagen 'people_4138.jpg' eliminada correctamente.
# Imagen 'people_4573.jpg' eliminada correctamente.
# Imagen 'people_3985.jpg' eliminada correctamente.
# Imagen 'people_4897.jpg' eliminada correctamente.
# Imagen 'people_4002.jpg' eliminada correctamente.
# Imagen 'people_4039.jpg' eliminada correctamente.
# Imagen 'people_4714.jpg' eliminada correctamente.
# Imagen 'people_4914.jpg' eliminada correctamente.
# Imagen 'people_4956.jpg' eliminada correctamente.
# Imagen 'people_4190.jpg' eliminada correctamente.
# Imagen 'people_4305.jpg' eliminada correctamente.
# Imagen 'people_4525.jpg' eliminada correctamente.
# Imagen 'people_4500.jpg' eliminada correctamente.
# Imagen 'people_4034.jpg' eliminada correctamente.
# Imagen 'people_4586.jpg' eliminada correctamente.
# Imagen 'people_4326.jpg' eliminada correctamente.
# Imagen 'people_4513.jpg' eliminada correctamente.
# Imagen 'people_4261.jpg' eliminada correctamente.
# Imagen 'people_4727.jpg' eliminada correctamente.
# Imagen 'people_4221.jpg' eliminada correctamente.
# Imagen 'people_4904.jpg' eliminada correctamente.
# Imagen 'people_4579.jpg' eliminada correctamente.
# Imagen 'people_4152.jpg' eliminada correctamente.
# Imagen 'people_4547.jpg' eliminada correctamente.
# Imagen 'people_4471.jpg' eliminada correctamente.
# Imagen 'people_4846.jpg' eliminada correctamente.
# Imagen 'people_4876.jpg' eliminada correctamente.
# Imagen 'people_4517.jpg' eliminada correctamente.
# Imagen 'people_4257.jpg' eliminada correctamente.
# Imagen 'people_4215.jpg' eliminada correctamente.
# Imagen 'people_4989.jpg' eliminada correctamente.
# Imagen 'people_4066.jpg' eliminada correctamente.
# Imagen 'people_4674.jpg' eliminada correctamente.
# Imagen 'people_4351.jpg' eliminada correctamente.
# Imagen 'people_4976.jpg' eliminada correctamente.
# Imagen 'people_4650.jpg' eliminada correctamente.
# Imagen 'people_4134.jpg' eliminada correctamente.
# Imagen 'people_4896.jpg' eliminada correctamente.
# Imagen 'people_4125.jpg' eliminada correctamente.
# Imagen 'people_4374.jpg' eliminada correctamente.
# Imagen 'people_4461.jpg' eliminada correctamente.
# Imagen 'people_4866.jpg' eliminada correctamente.
# Imagen 'people_4900.jpg' eliminada correctamente.
# Imagen 'people_4342.jpg' eliminada correctamente.
# Imagen 'people_4013.jpg' eliminada correctamente.
# Imagen 'people_4765.jpg' eliminada correctamente.
# Imagen 'people_4061.jpg' eliminada correctamente.
# Imagen 'people_4130.jpg' eliminada correctamente.
# Imagen 'people_4437.jpg' eliminada correctamente.
# Imagen 'people_4642.jpg' eliminada correctamente.
# Imagen 'people_4879.jpg' eliminada correctamente.
# Imagen 'people_4769.jpg' eliminada correctamente.
# Imagen 'people_4267.jpg' eliminada correctamente.
# Imagen 'people_4280.jpg' eliminada correctamente.
# Imagen 'people_4338.jpg' eliminada correctamente.
# Imagen 'people_4446.jpg' eliminada correctamente.
# Imagen 'people_4259.jpg' eliminada correctamente.
# Imagen 'people_4503.jpg' eliminada correctamente.
# Imagen 'people_4892.jpg' eliminada correctamente.
# Imagen 'people_4665.jpg' eliminada correctamente.
# Imagen 'people_3987.jpg' eliminada correctamente.
# Imagen 'people_4396.jpg' eliminada correctamente.
# Imagen 'people_4171.jpg' eliminada correctamente.
# Imagen 'people_4520.jpg' eliminada correctamente.
# Imagen 'people_4619.jpg' eliminada correctamente.
# Imagen 'people_4623.jpg' eliminada correctamente.
# Imagen 'people_4935.jpg' eliminada correctamente.
# Imagen 'people_4241.jpg' eliminada correctamente.
# Imagen 'people_4052.jpg' eliminada correctamente.
# Imagen 'people_4348.jpg' eliminada correctamente.
# Imagen 'people_4696.jpg' eliminada correctamente.
# Imagen 'people_4234.jpg' eliminada correctamente.
# Imagen 'people_4833.jpg' eliminada correctamente.
# Imagen 'people_4430.jpg' eliminada correctamente.
# Imagen 'people_5001.jpg' eliminada correctamente.
# Imagen 'people_4891.jpg' eliminada correctamente.
# Imagen 'people_4167.jpg' eliminada correctamente.
# Imagen 'people_4926.jpg' eliminada correctamente.
# Imagen 'people_4441.jpg' eliminada correctamente.
# Imagen 'people_4955.jpg' eliminada correctamente.
# Imagen 'people_4315.jpg' eliminada correctamente.
# Imagen 'people_4568.jpg' eliminada correctamente.
# Imagen 'people_4817.jpg' eliminada correctamente.
# Imagen 'people_4387.jpg' eliminada correctamente.
# Imagen 'people_4582.jpg' eliminada correctamente.
# Imagen 'people_4187.jpg' eliminada correctamente.
# Imagen 'people_4362.jpg' eliminada correctamente.
# Imagen 'people_4552.jpg' eliminada correctamente.
# Imagen 'people_4601.jpg' eliminada correctamente.
# Imagen 'people_4534.jpg' eliminada correctamente.
# Imagen 'people_4773.jpg' eliminada correctamente.
# Imagen 'people_4393.jpg' eliminada correctamente.
# Imagen 'people_4589.jpg' eliminada correctamente.
# Imagen 'people_4330.jpg' eliminada correctamente.
# Imagen 'people_4017.jpg' eliminada correctamente.
# Imagen 'people_4516.jpg' eliminada correctamente.
# Imagen 'people_4781.jpg' eliminada correctamente.
# Imagen 'people_4686.jpg' eliminada correctamente.
# Imagen 'people_4771.jpg' eliminada correctamente.
# Imagen 'people_4550.jpg' eliminada correctamente.
# Imagen 'people_4371.jpg' eliminada correctamente.
# Imagen 'people_4971.jpg' eliminada correctamente.
# Imagen 'people_4981.jpg' eliminada correctamente.
# Imagen 'people_4779.jpg' eliminada correctamente.
# Imagen 'people_4974.jpg' eliminada correctamente.
# Imagen 'people_4075.jpg' eliminada correctamente.
# Imagen 'people_4009.jpg' eliminada correctamente.
# Imagen 'people_4126.jpg' eliminada correctamente.
# Imagen 'people_4416.jpg' eliminada correctamente.
# Imagen 'people_4721.jpg' eliminada correctamente.
# Imagen 'people_4593.jpg' eliminada correctamente.
# Imagen 'people_4019.jpg' eliminada correctamente.
# Imagen 'people_4948.jpg' eliminada correctamente.
# Imagen 'people_4991.jpg' eliminada correctamente.
# Imagen 'people_4409.jpg' eliminada correctamente.
# Imagen 'people_4757.jpg' eliminada correctamente.
# Imagen 'people_4778.jpg' eliminada correctamente.
# Imagen 'people_4192.jpg' eliminada correctamente.
# Imagen 'people_4133.jpg' eliminada correctamente.
# Imagen 'people_4635.jpg' eliminada correctamente.
# Imagen 'people_5012.jpg' eliminada correctamente.
# Imagen 'people_4483.jpg' eliminada correctamente.
# Imagen 'people_4812.jpg' eliminada correctamente.
# Imagen 'people_4397.jpg' eliminada correctamente.
# Imagen 'people_4726.jpg' eliminada correctamente.
# Imagen 'people_4496.jpg' eliminada correctamente.
# Imagen 'people_4666.jpg' eliminada correctamente.
# Imagen 'people_3986.jpg' eliminada correctamente.
# Imagen 'people_4485.jpg' eliminada correctamente.
# Imagen 'people_4470.jpg' eliminada correctamente.
# Imagen 'people_4987.jpg' eliminada correctamente.
# Imagen 'people_4184.jpg' eliminada correctamente.
# Imagen 'people_4924.jpg' eliminada correctamente.
# Imagen 'people_4492.jpg' eliminada correctamente.
# Imagen 'people_4988.jpg' eliminada correctamente.
# Imagen 'people_4112.jpg' eliminada correctamente.
# Imagen 'people_5018.jpg' eliminada correctamente.
# Imagen 'people_3995.jpg' eliminada correctamente.
# Imagen 'people_4777.jpg' eliminada correctamente.
# Imagen 'people_4028.jpg' eliminada correctamente.
# Imagen 'people_4744.jpg' eliminada correctamente.
# Imagen 'people_4992.jpg' eliminada correctamente.
# Imagen 'people_4436.jpg' eliminada correctamente.
# Imagen 'people_4680.jpg' eliminada correctamente.
# Imagen 'people_4094.jpg' eliminada correctamente.
# Imagen 'people_4129.jpg' eliminada correctamente.
# Imagen 'people_4178.jpg' eliminada correctamente.
# Imagen 'people_4985.jpg' eliminada correctamente.
# Imagen 'people_4978.jpg' eliminada correctamente.
# Imagen 'people_4288.jpg' eliminada correctamente.
# Imagen 'people_4668.jpg' eliminada correctamente.
# Imagen 'people_4236.jpg' eliminada correctamente.
# Imagen 'people_4580.jpg' eliminada correctamente.
# Imagen 'people_4467.jpg' eliminada correctamente.
# Imagen 'people_4939.jpg' eliminada correctamente.
# Imagen 'people_4710.jpg' eliminada correctamente.
# Imagen 'people_4277.jpg' eliminada correctamente.
# Imagen 'people_4429.jpg' eliminada correctamente.
# Imagen 'people_4421.jpg' eliminada correctamente.
# Imagen 'people_4618.jpg' eliminada correctamente.
# Imagen 'people_4478.jpg' eliminada correctamente.
# Imagen 'people_4621.jpg' eliminada correctamente.
# Imagen 'people_4783.jpg' eliminada correctamente.
# Imagen 'people_4077.jpg' eliminada correctamente.
# Imagen 'people_4100.jpg' eliminada correctamente.
# Imagen 'people_4963.jpg' eliminada correctamente.
# Imagen 'people_4825.jpg' eliminada correctamente.
# Imagen 'people_4735.jpg' eliminada correctamente.
# Imagen 'people_4970.jpg' eliminada correctamente.
# Imagen 'people_4480.jpg' eliminada correctamente.
# Imagen 'people_4390.jpg' eliminada correctamente.
# Imagen 'people_4801.jpg' eliminada correctamente.
# Imagen 'people_4715.jpg' eliminada correctamente.
# Imagen 'people_4951.jpg' eliminada correctamente.
# Imagen 'people_4849.jpg' eliminada correctamente.
# Imagen 'people_4479.jpg' eliminada correctamente.
# Imagen 'people_4032.jpg' eliminada correctamente.
# Imagen 'people_5006.jpg' eliminada correctamente.
# Imagen 'people_4563.jpg' eliminada correctamente.
# Imagen 'people_4638.jpg' eliminada correctamente.
# Imagen 'people_4994.jpg' eliminada correctamente.
# Imagen 'people_4296.jpg' eliminada correctamente.
# Imagen 'people_4058.jpg' eliminada correctamente.
# Imagen 'people_4655.jpg' eliminada correctamente.
# Imagen 'people_4364.jpg' eliminada correctamente.
# Imagen 'people_4180.jpg' eliminada correctamente.
# Imagen 'people_4663.jpg' eliminada correctamente.
# Imagen 'people_4651.jpg' eliminada correctamente.
# Imagen 'people_4212.jpg' eliminada correctamente.
# Imagen 'people_4065.jpg' eliminada correctamente.
# Imagen 'people_4157.jpg' eliminada correctamente.
# Imagen 'people_4224.jpg' eliminada correctamente.
# Imagen 'people_4018.jpg' eliminada correctamente.
# Imagen 'people_4279.jpg' eliminada correctamente.
# Imagen 'people_4148.jpg' eliminada correctamente.
# Imagen 'people_4405.jpg' eliminada correctamente.
# Imagen 'people_4203.jpg' eliminada correctamente.
# Imagen 'people_4193.jpg' eliminada correctamente.
# Imagen 'people_4899.jpg' eliminada correctamente.
# Imagen 'people_4578.jpg' eliminada correctamente.
# Imagen 'people_5002.jpg' eliminada correctamente.
# Imagen 'people_4272.jpg' eliminada correctamente.
# Imagen 'people_4754.jpg' eliminada correctamente.
# Imagen 'people_4748.jpg' eliminada correctamente.
# Imagen 'people_4901.jpg' eliminada correctamente.
# Imagen 'people_4494.jpg' eliminada correctamente.
# Imagen 'people_4587.jpg' eliminada correctamente.
# Imagen 'people_4370.jpg' eliminada correctamente.
# Imagen 'people_4847.jpg' eliminada correctamente.
# Imagen 'people_4347.jpg' eliminada correctamente.
# Imagen 'people_4263.jpg' eliminada correctamente.
# Imagen 'people_4609.jpg' eliminada correctamente.
# Imagen 'people_4695.jpg' eliminada correctamente.
# Imagen 'people_4402.jpg' eliminada correctamente.
# Imagen 'people_4289.jpg' eliminada correctamente.
# Imagen 'people_4943.jpg' eliminada correctamente.
# Imagen 'people_4093.jpg' eliminada correctamente.
# Imagen 'people_4737.jpg' eliminada correctamente.
# Imagen 'people_4531.jpg' eliminada correctamente.
# Imagen 'people_4081.jpg' eliminada correctamente.
# Imagen 'people_4931.jpg' eliminada correctamente.
# Imagen 'people_4069.jpg' eliminada correctamente.
# Imagen 'people_4328.jpg' eliminada correctamente.
# Imagen 'people_4875.jpg' eliminada correctamente.
# Imagen 'people_4818.jpg' eliminada correctamente.
# Imagen 'people_4507.jpg' eliminada correctamente.
# Imagen 'people_4746.jpg' eliminada correctamente.
# Imagen 'people_4577.jpg' eliminada correctamente.
# Imagen 'people_4816.jpg' eliminada correctamente.
# Imagen 'people_4292.jpg' eliminada correctamente.
# Imagen 'people_4047.jpg' eliminada correctamente.
# Imagen 'people_4243.jpg' eliminada correctamente.
# Imagen 'people_4572.jpg' eliminada correctamente.
# Imagen 'people_4691.jpg' eliminada correctamente.
# Imagen 'people_4001.jpg' eliminada correctamente.
# Imagen 'people_4636.jpg' eliminada correctamente.
# Imagen 'people_4403.jpg' eliminada correctamente.
# Imagen 'people_4004.jpg' eliminada correctamente.
# Imagen 'people_4732.jpg' eliminada correctamente.
# Imagen 'people_4135.jpg' eliminada correctamente.
# Imagen 'people_4692.jpg' eliminada correctamente.
# Imagen 'people_4867.jpg' eliminada correctamente.
# Imagen 'people_4824.jpg' eliminada correctamente.
# Imagen 'people_4062.jpg' eliminada correctamente.
# Imagen 'people_4630.jpg' eliminada correctamente.
# Imagen 'people_4456.jpg' eliminada correctamente.
# Imagen 'people_4738.jpg' eliminada correctamente.
# Imagen 'people_4820.jpg' eliminada correctamente.
# Imagen 'people_4325.jpg' eliminada correctamente.
# Imagen 'people_4868.jpg' eliminada correctamente.
# Imagen 'people_4861.jpg' eliminada correctamente.
# Imagen 'people_4201.jpg' eliminada correctamente.
# Imagen 'people_4037.jpg' eliminada correctamente.
# Imagen 'people_4669.jpg' eliminada correctamente.
# Imagen 'people_5000.jpg' eliminada correctamente.
# Imagen 'people_4408.jpg' eliminada correctamente.
# Imagen 'people_4853.jpg' eliminada correctamente.
# Imagen 'people_4207.jpg' eliminada correctamente.
# Imagen 'people_4633.jpg' eliminada correctamente.
# Imagen 'people_4990.jpg' eliminada correctamente.
# Imagen 'people_4495.jpg' eliminada correctamente.
# Imagen 'people_4031.jpg' eliminada correctamente.
# Imagen 'people_4115.jpg' eliminada correctamente.
# Imagen 'people_4101.jpg' eliminada correctamente.
# Imagen 'people_4327.jpg' eliminada correctamente.
# Imagen 'people_4913.jpg' eliminada correctamente.
# Imagen 'people_4937.jpg' eliminada correctamente.
# Imagen 'people_4774.jpg' eliminada correctamente.
# Imagen 'people_4741.jpg' eliminada correctamente.
# Imagen 'people_4164.jpg' eliminada correctamente.
# Imagen 'people_4763.jpg' eliminada correctamente.
# Imagen 'people_4713.jpg' eliminada correctamente.
# Imagen 'people_4147.jpg' eliminada correctamente.
# Imagen 'people_4870.jpg' eliminada correctamente.
# Imagen 'people_4053.jpg' eliminada correctamente.
# Imagen 'people_4862.jpg' eliminada correctamente.
# Imagen 'people_4804.jpg' eliminada correctamente.
# Imagen 'people_4481.jpg' eliminada correctamente.
# Imagen 'people_4466.jpg' eliminada correctamente.
# Imagen 'people_4465.jpg' eliminada correctamente.
# Imagen 'people_4169.jpg' eliminada correctamente.
# Imagen 'people_4472.jpg' eliminada correctamente.
# Imagen 'people_4299.jpg' eliminada correctamente.
# Imagen 'people_4749.jpg' eliminada correctamente.
# Imagen 'people_4458.jpg' eliminada correctamente.
# Imagen 'people_4151.jpg' eliminada correctamente.
# Imagen 'people_4662.jpg' eliminada correctamente.
# Imagen 'people_4886.jpg' eliminada correctamente.
# Imagen 'people_4256.jpg' eliminada correctamente.
# Imagen 'people_4712.jpg' eliminada correctamente.
# Imagen 'people_4972.jpg' eliminada correctamente.
# Imagen 'people_4319.jpg' eliminada correctamente.
# Imagen 'people_4905.jpg' eliminada correctamente.
# Imagen 'people_4451.jpg' eliminada correctamente.
# Imagen 'people_4885.jpg' eliminada correctamente.
# Imagen 'people_4049.jpg' eliminada correctamente.
# Imagen 'people_4160.jpg' eliminada correctamente.
# Imagen 'people_3993.jpg' eliminada correctamente.
# Imagen 'people_4822.jpg' eliminada correctamente.
# Imagen 'people_4445.jpg' eliminada correctamente.
# Imagen 'people_4246.jpg' eliminada correctamente.
# Imagen 'people_4366.jpg' eliminada correctamente.
# Imagen 'people_4772.jpg' eliminada correctamente.
# Imagen 'people_4912.jpg' eliminada correctamente.
# Imagen 'people_4051.jpg' eliminada correctamente.
# Imagen 'people_4128.jpg' eliminada correctamente.
# Imagen 'people_4625.jpg' eliminada correctamente.
# Imagen 'people_4789.jpg' eliminada correctamente.
# Imagen 'people_4523.jpg' eliminada correctamente.
# Imagen 'people_3997.jpg' eliminada correctamente.
# Imagen 'people_4431.jpg' eliminada correctamente.
# Imagen 'people_4498.jpg' eliminada correctamente.
# Imagen 'people_4724.jpg' eliminada correctamente.
# Imagen 'people_4852.jpg' eliminada correctamente.
# Imagen 'people_4767.jpg' eliminada correctamente.
# Imagen 'people_4873.jpg' eliminada correctamente.
# Imagen 'people_5003.jpg' eliminada correctamente.
# Imagen 'people_4137.jpg' eliminada correctamente.
# Imagen 'people_4869.jpg' eliminada correctamente.
# Imagen 'people_4464.jpg' eliminada correctamente.
# Imagen 'people_4321.jpg' eliminada correctamente.
# Imagen 'people_4059.jpg' eliminada correctamente.
# Imagen 'people_4687.jpg' eliminada correctamente.
# Imagen 'people_4488.jpg' eliminada correctamente.
# Imagen 'people_4041.jpg' eliminada correctamente.
# Imagen 'people_4264.jpg' eliminada correctamente.
# Imagen 'people_4426.jpg' eliminada correctamente.
# Imagen 'people_4701.jpg' eliminada correctamente.
# Imagen 'people_4345.jpg' eliminada correctamente.
# Imagen 'people_4555.jpg' eliminada correctamente.
# Imagen 'people_4752.jpg' eliminada correctamente.
# Imagen 'people_3983.jpg' eliminada correctamente.
# Imagen 'people_4656.jpg' eliminada correctamente.
# Imagen 'people_4602.jpg' eliminada correctamente.
# Imagen 'people_4274.jpg' eliminada correctamente.
# Imagen 'people_4473.jpg' eliminada correctamente.
# Imagen 'people_4684.jpg' eliminada correctamente.
# Imagen 'people_4304.jpg' eliminada correctamente.
# Imagen 'people_4921.jpg' eliminada correctamente.
# Imagen 'people_4375.jpg' eliminada correctamente.
# Imagen 'people_4219.jpg' eliminada correctamente.
# Imagen 'people_4211.jpg' eliminada correctamente.
# Imagen 'people_4795.jpg' eliminada correctamente.
# Imagen 'people_4198.jpg' eliminada correctamente.
# Imagen 'people_4247.jpg' eliminada correctamente.
# Imagen 'people_4025.jpg' eliminada correctamente.
# Imagen 'people_4591.jpg' eliminada correctamente.
# Imagen 'people_4679.jpg' eliminada correctamente.
# Imagen 'people_4953.jpg' eliminada correctamente.
# Imagen 'people_4736.jpg' eliminada correctamente.
# Imagen 'people_4790.jpg' eliminada correctamente.
# Imagen 'people_4574.jpg' eliminada correctamente.
# Imagen 'people_4163.jpg' eliminada correctamente.
# Imagen 'people_4284.jpg' eliminada correctamente.
# Imagen 'people_4254.jpg' eliminada correctamente.
# Imagen 'person_4244.jpg' eliminada correctamente.
# Imagen 'person_4138.jpg' eliminada correctamente.
# Imagen 'person_4434.jpg' eliminada correctamente.
# Imagen 'person_4164.jpg' eliminada correctamente.
# Imagen 'person_3742.jpg' eliminada correctamente.
# Imagen 'person_4375.jpg' eliminada correctamente.
# Imagen 'person_3772.jpg' eliminada correctamente.
# Imagen 'person_3861.jpg' eliminada correctamente.
# Imagen 'person_4418.jpg' eliminada correctamente.
# Imagen 'person_4226.jpg' eliminada correctamente.
# Imagen 'person_3634.jpg' eliminada correctamente.
# Imagen 'person_3905.jpg' eliminada correctamente.
# Imagen 'person_3920.jpg' eliminada correctamente.
# Imagen 'person_3542.jpg' eliminada correctamente.
# Imagen 'person_4378.jpg' eliminada correctamente.
# Imagen 'person_3902.jpg' eliminada correctamente.
# Imagen 'person_4092.jpg' eliminada correctamente.
# Imagen 'person_4440.jpg' eliminada correctamente.
# Imagen 'person_4106.jpg' eliminada correctamente.
# Imagen 'person_3609.jpg' eliminada correctamente.
# Imagen 'person_4195.jpg' eliminada correctamente.
# Imagen 'person_4246.jpg' eliminada correctamente.
# Imagen 'person_3590.jpg' eliminada correctamente.
# Imagen 'person_3756.jpg' eliminada correctamente.
# Imagen 'person_4271.jpg' eliminada correctamente.
# Imagen 'person_3622.jpg' eliminada correctamente.
# Imagen 'person_4324.jpg' eliminada correctamente.
# Imagen 'person_3677.jpg' eliminada correctamente.
# Imagen 'person_4117.jpg' eliminada correctamente.
# Imagen 'person_3669.jpg' eliminada correctamente.
# Imagen 'person_4451.jpg' eliminada correctamente.
# Imagen 'person_3601.jpg' eliminada correctamente.
# Imagen 'person_3814.jpg' eliminada correctamente.
# Imagen 'person_4245.jpg' eliminada correctamente.
# Imagen 'person_4024.jpg' eliminada correctamente.
# Imagen 'person_3873.jpg' eliminada correctamente.
# Imagen 'person_4391.jpg' eliminada correctamente.
# Imagen 'person_3544.jpg' eliminada correctamente.
# Imagen 'person_4118.jpg' eliminada correctamente.
# Imagen 'person_3719.jpg' eliminada correctamente.
# Imagen 'person_4290.jpg' eliminada correctamente.
# Imagen 'person_4377.jpg' eliminada correctamente.
# Imagen 'person_4373.jpg' eliminada correctamente.
# Imagen 'person_4461.jpg' eliminada correctamente.
# Imagen 'person_3627.jpg' eliminada correctamente.
# Imagen 'person_4355.jpg' eliminada correctamente.
# Imagen 'person_3935.jpg' eliminada correctamente.
# ...
# Imagen 'person_4469_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4229_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4975_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4064_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4368_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3878_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_5010_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3809_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4063_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4446_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3960_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4504_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4969_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4764_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4395_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4882_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4807_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4375_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4048_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4420_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4927_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3622_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4739_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4855_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4213_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3938_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4098_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4982_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4654_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4610_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4047_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4272_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4083_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4812_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4758_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4198_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3623_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3703_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4356_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4456_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4388_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4564_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4162_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4008_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4261_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3730_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4552_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4700_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4436_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4996_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3765_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4364_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3764_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4469_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4082_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4863_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3874_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3518_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4899_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3807_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4123_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4351_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3613_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3909_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4715_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3992_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3608_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4495_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4891_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4663_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4810_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4078_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4789_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4330_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4536_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4658_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4555_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4016_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4295_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4477_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4722_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4409_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3521_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4216_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4628_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4396_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4384_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4099_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4149_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4415_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4407_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4924_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4902_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3682_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4348_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3759_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4917_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4491_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4275_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4171_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3981_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3820_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4404_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4381_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4154_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4344_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3744_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4278_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4496_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3893_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4643_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4293_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4437_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4493_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4711_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4438_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3568_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4953_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4331_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4227_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4081_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4071_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3896_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4189_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4563_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4488_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4485_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4297_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4333_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4068_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4274_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3886_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4530_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4551_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4203_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4498_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4675_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4337_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4580_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4362_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4062_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4398_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4171_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4547_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4162_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4034_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4187_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4158_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4952_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4871_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4370_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4337_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4930_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4482_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4880_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4267_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4429_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3571_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4399_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4379_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3628_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4447_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4423_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3766_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4202_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3802_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4934_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_5009_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4451_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3932_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4514_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4018_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4254_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3988_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4100_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3780_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4405_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4667_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_5015_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4306_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4394_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3891_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4181_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4966_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4828_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4299_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4248_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3735_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4148_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4296_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3969_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4003_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4560_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3658_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4176_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4561_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3989_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4015_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4883_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3872_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_3994_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4234_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4430_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4755_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4948_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4397_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4465_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_4246_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4578_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4861_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4062_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3984_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4313_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4444_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3544_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4904_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4951_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_3999_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4708_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4840_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4473_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4403_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4661_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'person_3933_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4237_aug_flip_brightness.jpg' eliminada correctamente.
# Imagen 'people_4100_aug_flip_brightness.jpg' eliminada correctamente.
# Todas las imágenes en la carpeta '/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/images/val' han sido eliminadas.

# %%
import os
import shutil

def eliminar_archivos_txt(carpeta):
    """Elimina todos los archivos .txt de una carpeta específica.

    Args:
        carpeta: La ruta de la carpeta donde se eliminarán los archivos .txt.
    """
    for filename in os.listdir(carpeta):
        file_path = os.path.join(carpeta, filename)
        try:
            if os.path.isfile(file_path) and filename.endswith(".txt"):
                os.remove(file_path)
                print(f"Archivo eliminado: {file_path}")
        except Exception as e:
            print(f"Error al eliminar el archivo {file_path}: {e}")

# Ejemplo de uso
carpeta_a_limpiar = "/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/labels/val"  # Reemplaza con la ruta de tu carpeta
eliminar_archivos_txt(carpeta_a_limpiar)
print("Proceso completado.")
# Out:
# Proceso completado.

# %%
import os
# from google.colab import drive

# Montar Google Drive
# drive.mount('/content/drive')

# Ruta de la carpeta en Google Drive
carpeta_drive = '/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/labels/train'  # Reemplaza 'tu_carpeta' con la ruta de tu carpeta

# Contar archivos .txt
cantidad_txt = 0
for archivo in os.listdir(carpeta_drive):
  if archivo.endswith('.txt'):
    cantidad_txt += 1

# Mostrar el resultado
print(f'Hay {cantidad_txt} archivos .txt en la carpeta {carpeta_drive}')
# Out:
# Hay 4485 archivos .txt en la carpeta /content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/labels/train

# %% [markdown]
# # CORRECCION DE LOS LABELS

# %%
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
from tqdm import tqdm

# Ruta al dataset aumentado
DRIVE_BASE = "/content/drive/MyDrive/Proyecto-IA3"
OUTPUT_ROOT = f"{DRIVE_BASE}/dataset_people_augmented"

def fix_label_files():
    """Corrige los archivos de etiquetas para asegurar que el ID de clase sea un entero"""
    print("Corrigiendo archivos de etiquetas...")

    # Buscar todos los archivos de etiquetas aumentados
    label_files = []
    for split in ["train", "val"]:
        label_dir = os.path.join(OUTPUT_ROOT, "labels", split)
        if os.path.exists(label_dir):
            # Buscar solo archivos que contienen "_aug_" en el nombre
            aug_files = glob.glob(os.path.join(label_dir, "*_aug_*.txt"))
            label_files.extend(aug_files)

    print(f"Encontrados {len(label_files)} archivos de etiquetas a corregir.")

    # Corregir cada archivo
    fixed_count = 0
    for label_path in tqdm(label_files):
        try:
            # Leer el contenido actual
            with open(label_path, 'r') as f:
                lines = f.readlines()

            # Corregir cada línea
            new_lines = []
            modified = False

            for line in lines:
                parts = line.strip().split()
                if len(parts) >= 5:
                    # Verificar si el primer valor es un número flotante con punto decimal
                    if '.' in parts[0]:
                        try:
                            class_id = int(float(parts[0]))  # Convertir a entero
                            # Reconstruir la línea con el ID de clase como entero
                            new_line = f"{class_id} {' '.join(parts[1:])}\n"
                            new_lines.append(new_line)
                            modified = True
                            continue
                        except ValueError:
                            pass

                # Si no necesita corrección o hubo un error, mantener la línea original
                new_lines.append(line)

            # Guardar el archivo corregido si se realizaron cambios
            if modified:
                with open(label_path, 'w') as f:
                    f.writelines(new_lines)
                fixed_count += 1

        except Exception as e:
            print(f"Error al procesar archivo {label_path}: {e}")

    print(f"Corregidos {fixed_count} archivos de etiquetas.")

# Ejecutar la corrección
fix_label_files()
# Out:
# Corrigiendo archivos de etiquetas...
# Encontrados 5975 archivos de etiquetas a corregir.
#   1%|          | 46/5975 [01:13<20:57:18, 12.72s/it]

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import glob
from tqdm import tqdm

# Configuración de rutas
DRIVE_BASE = "/content/drive/MyDrive/Proyecto-IA3"
AUGMENTED_ROOT = f"{DRIVE_BASE}/dataset_people_augmented"

# Directorio para guardar las visualizaciones si quieres
VIZ_SAMPLES_DIR = os.path.join(AUGMENTED_ROOT, "visualizaciones_muestras")
os.makedirs(VIZ_SAMPLES_DIR, exist_ok=True)

# Número de muestras aleatorias a visualizar
NUM_SAMPLES = 50

# Definimos una paleta de colores para cada tipo de aumentación
COLORS = {
    "flip_brightness": (0, 255, 0),  # Verde para flip + brillo
    "rotation": (255, 0, 0),        # Rojo para rotación
}

def visualize_bbox(img, bboxes, labels, color=(0, 255, 0), thickness=2):
    """Visualiza la imagen con sus bounding boxes"""
    h, w, _ = img.shape

    for i, bbox in enumerate(bboxes):
        # Convertir de formato YOLO [x_center, y_center, width, height] a píxeles
        x_center, y_center, width, height = bbox
        x_min = int((x_center - width/2) * w)
        y_min = int((y_center - height/2) * h)
        x_max = int((x_center + width/2) * w)
        y_max = int((y_center + height/2) * h)

        # Restricción para evitar valores fuera de la imagen
        x_min = max(0, x_min)
        y_min = max(0, y_min)
        x_max = min(w, x_max)
        y_max = min(h, y_max)

        # Dibujar rectángulo
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color, thickness)

        # Etiqueta
        label_text = f"person {i+1}"
        cv2.putText(img, label_text, (x_min, y_min - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    return img

def get_augmentation_type(filename):
    """Determina el tipo de aumentación basado en el nombre del archivo"""
    if "_aug_flip_brightness." in filename:
        return "flip_brightness"
    elif "_aug_rotation." in filename:
        return "rotation"
    else:
        return "original"

def load_label(label_path):
    """Carga las etiquetas desde un archivo .txt"""
    bboxes = []
    labels = []

    try:
        with open(label_path, 'r') as f:
            lines = f.readlines()

        for line in lines:
            values = line.strip().split()
            class_id = int(values[0])
            x_center, y_center, width, height = [float(x) for x in values[1:5]]

            # Verificar si los valores están en el rango correcto
            if 0 <= x_center <= 1 and 0 <= y_center <= 1 and 0 <= width <= 1 and 0 <= height <= 1:
                bboxes.append([x_center, y_center, width, height])
                labels.append(class_id)
            else:
                print(f"Advertencia: Valores fuera de rango en {label_path}: {values}")
    except Exception as e:
        print(f"Error al leer el archivo de etiquetas {label_path}: {e}")

    return bboxes, labels

def get_all_augmented_images():
    """Obtiene todas las imágenes aumentadas del dataset"""
    augmented_images = []

    # Buscar en train y val
    for split in ["train", "val"]:
        image_dir = os.path.join(AUGMENTED_ROOT, "images", split)

        if os.path.exists(image_dir):
            # Buscar imágenes aumentadas (contienen _aug_ en el nombre)
            aug_files = glob.glob(os.path.join(image_dir, "*_aug_*.jpg"))

            for img_path in aug_files:
                label_name = os.path.basename(img_path).replace('.jpg', '.txt')
                label_path = os.path.join(AUGMENTED_ROOT, "labels", split, label_name)

                if os.path.exists(label_path):
                    augmented_images.append((img_path, label_path, split))

    return augmented_images

def visualize_random_samples(num_samples=50, save_to_disk=True, fig_size=(15, 15), cols=5):
    """Visualiza un número específico de muestras aleatorias del dataset aumentado"""
    # Obtener todas las imágenes aumentadas
    all_images = get_all_augmented_images()
    print(f"Total de imágenes aumentadas encontradas: {len(all_images)}")

    # Seleccionar muestras aleatorias
    if num_samples > len(all_images):
        num_samples = len(all_images)
        print(f"Ajustando a {num_samples} muestras disponibles")

    samples = random.sample(all_images, num_samples)

    # Calcular número de filas necesarias
    rows = (num_samples + cols - 1) // cols

    # Crear figura grande
    plt.figure(figsize=fig_size)

    for i, (img_path, label_path, split) in enumerate(tqdm(samples, desc="Visualizando muestras")):
        # Leer imagen
        img = cv2.imread(img_path)
        if img is None:
            print(f"Error al leer la imagen: {img_path}")
            continue

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Leer etiquetas
        bboxes, labels = load_label(label_path)

        # Determinar tipo de aumentación
        aug_type = get_augmentation_type(img_path)
        color = COLORS.get(aug_type, (0, 0, 255))  # Color predeterminado azul

        # Visualizar bounding boxes
        img_with_boxes = visualize_bbox(img.copy(), bboxes, labels, color=color)

        # Añadir a la figura
        plt.subplot(rows, cols, i+1)
        plt.imshow(img_with_boxes)
        plt.title(f"{split} - {aug_type}")
        plt.axis('off')

    plt.tight_layout()

    # Guardar visualización si se solicita
    if save_to_disk:
        output_path = os.path.join(VIZ_SAMPLES_DIR, f"random_samples_{num_samples}.jpg")
        plt.savefig(output_path, dpi=150, bbox_inches='tight')
        print(f"Visualización guardada en: {output_path}")

    plt.show()

# Función para visualizar una sola imagen con sus bounding boxes
def visualize_single_image(img_path, save_to_disk=False):
    """Visualiza una sola imagen con sus bounding boxes"""
    split = "train" if "train" in img_path else "val" if "val" in img_path else "test"

    # Determinar ruta del label
    label_name = os.path.basename(img_path).replace('.jpg', '.txt')
    label_path = os.path.join(AUGMENTED_ROOT, "labels", split, label_name)

    if not os.path.exists(label_path):
        print(f"No se encontró el archivo de etiquetas: {label_path}")
        return

    # Leer imagen
    img = cv2.imread(img_path)
    if img is None:
        print(f"Error al leer la imagen: {img_path}")
        return

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Leer etiquetas
    bboxes, labels = load_label(label_path)

    # Determinar tipo de aumentación
    aug_type = get_augmentation_type(img_path)
    color = COLORS.get(aug_type, (0, 0, 255))  # Color predeterminado azul

    # Visualizar bounding boxes
    img_with_boxes = visualize_bbox(img.copy(), bboxes, labels, color=color)

    # Mostrar imagen
    plt.figure(figsize=(10, 10))
    plt.imshow(img_with_boxes)
    plt.title(f"{split} - {aug_type} - {os.path.basename(img_path)}")
    plt.axis('off')

    # Guardar visualización si se solicita
    if save_to_disk:
        output_path = os.path.join(VIZ_SAMPLES_DIR, f"single_{os.path.basename(img_path)}")
        plt.savefig(output_path, dpi=150, bbox_inches='tight')
        print(f"Visualización guardada en: {output_path}")

    plt.show()

# %%
# Ejecutar la visualización
if __name__ == "__main__":
    # Visualizar 50 muestras aleatorias
    visualize_random_samples(NUM_SAMPLES, save_to_disk=True, fig_size=(20, 20), cols=5)

    # Si quieres ver una imagen específica (opcional)
    # example_path = "/content/drive/MyDrive/Proyecto-IA3/dataset_people_augmented/images/val/person_4115_aug_rotation.jpg"
    # visualize_single_image(example_path, save_to_disk=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import glob
from tqdm import tqdm

# Configuración de rutas
DRIVE_BASE = "/content/drive/MyDrive/Proyecto-IA3"
AUGMENTED_ROOT = f"{DRIVE_BASE}/dataset_people_augmented"

# Directorio para guardar las visualizaciones
VIZ_SAMPLES_DIR = os.path.join(AUGMENTED_ROOT, "visualizaciones_muestras")
os.makedirs(VIZ_SAMPLES_DIR, exist_ok=True)

# Número de muestras aleatorias a visualizar
NUM_SAMPLES = 50

# Definimos una paleta de colores para cada tipo de aumentación
COLORS = {
    "flip_brightness": (0, 255, 0),  # Verde para flip + brillo
    "rotation": (255, 0, 0),        # Rojo para rotación
}

def visualize_bbox(img, bboxes, labels, color=(0, 255, 0), thickness=2):
    """Visualiza la imagen con sus bounding boxes"""
    h, w, _ = img.shape

    for i, bbox in enumerate(bboxes):
        # Convertir de formato YOLO [x_center, y_center, width, height] a píxeles
        x_center, y_center, width, height = bbox
        x_min = int((x_center - width/2) * w)
        y_min = int((y_center - height/2) * h)
        x_max = int((x_center + width/2) * w)
        y_max = int((y_center + height/2) * h)

        # Restricción para evitar valores fuera de la imagen
        x_min = max(0, min(w-1, x_min))
        y_min = max(0, min(h-1, y_min))
        x_max = max(0, min(w, x_max))
        y_max = max(0, min(h, y_max))

        # Dibujar rectángulo
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color, thickness)

        # Etiqueta
        label_text = f"person {i+1}"
        cv2.putText(img, label_text, (x_min, y_min - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    return img

def get_augmentation_type(filename):
    """Determina el tipo de aumentación basado en el nombre del archivo"""
    if "_aug_flip_brightness." in filename:
        return "flip_brightness"
    elif "_aug_rotation." in filename:
        return "rotation"
    else:
        return "original"

def load_label(label_path):
    """Carga las etiquetas desde un archivo .txt, manejando correctamente flotantes y enteros"""
    bboxes = []
    labels = []

    try:
        with open(label_path, 'r') as f:
            lines = f.readlines()

        for line in lines:
            values = line.strip().split()
            if len(values) >= 5:
                # Manejar tanto enteros como flotantes para el class_id
                try:
                    # Primero intentar como entero
                    class_id = int(values[0])
                except ValueError:
                    # Si falla, intentar como flotante
                    try:
                        class_id = int(float(values[0]))
                    except ValueError:
                        print(f"Advertencia: Valor de clase inválido en {label_path}: {values[0]}")
                        continue

                # Procesar coordenadas
                try:
                    x_center = float(values[1])
                    y_center = float(values[2])
                    width = float(values[3])
                    height = float(values[4])

                    # Verificar rango
                    if 0 <= x_center <= 1 and 0 <= y_center <= 1 and 0 <= width <= 1 and 0 <= height <= 1:
                        bboxes.append([x_center, y_center, width, height])
                        labels.append(class_id)
                    else:
                        print(f"Advertencia: Coordenadas fuera de rango en {label_path}")
                except Exception as e:
                    print(f"Error al procesar coordenadas en {label_path}: {e}")
    except Exception as e:
        print(f"Error al leer el archivo de etiquetas {label_path}: {e}")

    return bboxes, labels

def get_all_augmented_images():
    """Obtiene todas las imágenes aumentadas del dataset"""
    augmented_images = []

    # Buscar en train y val
    for split in ["train", "val"]:
        image_dir = os.path.join(AUGMENTED_ROOT, "images", split)

        if os.path.exists(image_dir):
            # Buscar imágenes aumentadas (contienen _aug_ en el nombre)
            aug_files = glob.glob(os.path.join(image_dir, "*_aug_*.jpg"))

            for img_path in aug_files:
                label_name = os.path.basename(img_path).replace('.jpg', '.txt')
                label_path = os.path.join(AUGMENTED_ROOT, "labels", split, label_name)

                if os.path.exists(label_path):
                    augmented_images.append((img_path, label_path, split))

    return augmented_images

def visualize_random_samples(num_samples=50, save_to_disk=True, fig_size=(15, 15), cols=5):
    """Visualiza un número específico de muestras aleatorias del dataset aumentado"""
    # Obtener todas las imágenes aumentadas
    all_images = get_all_augmented_images()
    print(f"Total de imágenes aumentadas encontradas: {len(all_images)}")

    # Seleccionar muestras aleatorias
    if num_samples > len(all_images):
        num_samples = len(all_images)
        print(f"Ajustando a {num_samples} muestras disponibles")

    samples = random.sample(all_images, num_samples)

    # Calcular número de filas necesarias
    rows = (num_samples + cols - 1) // cols

    # Crear figura grande
    plt.figure(figsize=fig_size)

    successful_samples = 0
    for i, (img_path, label_path, split) in enumerate(tqdm(samples, desc="Visualizando muestras")):
        try:
            # Leer imagen
            img = cv2.imread(img_path)
            if img is None:
                print(f"Error al leer la imagen: {img_path}")
                continue

            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Leer etiquetas con manejo mejorado
            bboxes, labels = load_label(label_path)

            if not bboxes:
                print(f"No se encontraron bounding boxes válidos en {label_path}")
                continue

            # Determinar tipo de aumentación
            aug_type = get_augmentation_type(img_path)
            color = COLORS.get(aug_type, (0, 0, 255))  # Color predeterminado azul

            # Visualizar bounding boxes
            img_with_boxes = visualize_bbox(img.copy(), bboxes, labels, color=color)

            # Añadir a la figura
            plt.subplot(rows, cols, successful_samples+1)
            plt.imshow(img_with_boxes)
            plt.title(f"{split} - {aug_type}")
            plt.axis('off')

            successful_samples += 1

            # Si hemos completado suficientes muestras exitosas, terminar
            if successful_samples >= num_samples:
                break

        except Exception as e:
            print(f"Error al procesar {img_path}: {e}")

    plt.tight_layout()

    # Guardar visualización si se solicita
    if save_to_disk:
        output_path = os.path.join(VIZ_SAMPLES_DIR, f"random_samples_{successful_samples}.jpg")
        plt.savefig(output_path, dpi=150, bbox_inches='tight')
        print(f"Visualización guardada en: {output_path}")

    plt.show()

    return successful_samples

# Ejecutar la visualización
if __name__ == "__main__":
    # Visualizar 50 muestras aleatorias
    num_visualized = visualize_random_samples(NUM_SAMPLES, save_to_disk=True, fig_size=(20, 20), cols=5)
    print(f"Se visualizaron correctamente {num_visualized} imágenes con sus bounding boxes")
