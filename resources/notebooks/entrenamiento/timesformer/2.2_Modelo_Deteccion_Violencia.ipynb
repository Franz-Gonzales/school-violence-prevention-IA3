# %% [markdown]
# # Proyecto: Detección de Violencia Física Escolar en Tiempo Real

# %%
# !pip install transformers datasets tqdm scikit-learn matplotlib seaborn opencv-python onnx onnxruntime-gpu wandb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting onnx
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (5.29.4)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.13.2)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu) (1.13.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.28.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 111.9 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (283.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 4.5 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: onnx, humanfriendly, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.18.0 onnxruntime-gpu-1.22.0

# %%
import os
import time
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from torch.utils.data import Dataset, DataLoader
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, classification_report
from torch.cuda.amp import GradScaler, autocast
from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm.notebook import tqdm
import logging
from pathlib import Path
import cv2
import onnx
import onnxruntime as ort
import wandb
from datetime import datetime
import warnings
import requests
from retrying import retry
import subprocess
import transformers
warnings.filterwarnings("ignore")

# %%
# !pip install retrying
# Out:
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying) (1.17.0)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: retrying
# Successfully installed retrying-1.3.4

# %%
# Configurar logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Configurar semillas para reproducibilidad
torch.manual_seed(42)
np.random.seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# --- Sección 1: Configuración Inicial ---
# Montar Google Drive
try:
    drive.mount('/content/drive')
    logger.info("Google Drive montado correctamente")
except Exception as e:
    logger.error(f"Error al montar Google Drive: {e}")
    raise
# Out:
# Mounted at /content/drive

# %%
# Configurar dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")

# Verificar versión de transformers
print(f"Versión de transformers: {transformers.__version__}")
if transformers.__version__ < "4.30.0":
    logger.warning("Versión de transformers antigua. Se recomienda actualizar: !pip install --upgrade transformers")

# Definir rutas
DATASET_PATH = "/content/drive/MyDrive/dataset_violencia"
CHECKPOINT_PATH = "/content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints"
Path(CHECKPOINT_PATH).mkdir(parents=True, exist_ok=True)
# Out:
# Usando dispositivo: cuda
# Versión de transformers: 4.51.3

# %%
# Configuraciones globales
NUM_CLASSES = 2
BATCH_SIZE = 2  # Reducido para estabilidad
ACCUMULATION_STEPS = 2  # Gradient accumulation para simular batch size 4
NUM_EPOCHS_TL = 20
NUM_EPOCHS_FT = 15
LEARNING_RATE_TL = 5e-5
LEARNING_RATE_FT = 2e-5
WEIGHT_DECAY = 1e-4
DROPOUT = 0.3
PATIENCE = 5
NUM_FRAMES = 8
IMG_SIZE = 224
FPS = 15
LABELS = ["no_violence", "violence"]
TIMESTAMP = datetime.now().strftime("%Y%m%d_%H%M%S")
MODEL_ID = "facebook/timesformer-base-finetuned-k400"

# gonzalesfranz2019@gmail.com
APY_KEY = '096223375376bd39ddf1dd5e53e6cf1df1f3fa65'

# Inicializar Weights & Biases
wandb.init(project="timesformer_violence_detection", config={
    "batch_size": BATCH_SIZE,
    "learning_rate_tl": LEARNING_RATE_TL,
    "learning_rate_ft": LEARNING_RATE_FT,
    "num_epochs_tl": NUM_EPOCHS_TL,
    "num_epochs_ft": NUM_EPOCHS_FT,
    "weight_decay": WEIGHT_DECAY,
    "dropout": DROPOUT,
    "num_frames": NUM_FRAMES,
    "img_size": IMG_SIZE,
    "model_id": MODEL_ID
})
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: gonzalesfranz2019 (gonzalesfranz2019-universidad-mayor-real-y-pontificia-de) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250518_110634-n8vco1ad</code>
# Syncing run <strong><a href='https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection/runs/n8vco1ad' target="_blank">smooth-bush-3</a></strong> to <a href='https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection' target="_blank">https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection</a>
#  View run at <a href='https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection/runs/n8vco1ad' target="_blank">https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection/runs/n8vco1ad</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/gonzalesfranz2019-universidad-mayor-real-y-pontificia-de/timesformer_violence_detection/runs/n8vco1ad?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# --- Sección 2: Validación del Modelo y Procesador ---
@retry(stop_max_attempt_number=3, wait_fixed=2000)
def validate_model_access(model_id):
    """Valida la accesibilidad del modelo y procesador en Hugging Face."""
    try:
        processor = AutoImageProcessor.from_pretrained(model_id)
        model = TimesformerForVideoClassification.from_pretrained(model_id)
        print(f"Modelo {model_id} accesible correctamente")
        return processor, model
    except Exception as e:
        logger.error(f"Error al acceder al modelo {model_id}: {e}")
        print("Si el repositorio es privado, ejecuta: !huggingface-cli login")
        raise

try:
    processor, _ = validate_model_access(MODEL_ID)
except Exception as e:
    logger.error("Fallo al cargar el modelo. Verifica el identificador o tu conexión.")
    raise
# Out:
# preprocessor_config.json:   0%|          | 0.00/412 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# config.json:   0%|          | 0.00/22.7k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/486M [00:00<?, ?B/s]
# Modelo facebook/timesformer-base-finetuned-k400 accesible correctamente

# %%
# --- Sección 2: Validación del Modelo y Procesador ---
@retry(stop_max_attempt_number=3, wait_fixed=2000)
def validate_model_access(model_id):
    """Valida la accesibilidad del modelo y procesador en Hugging Face."""
    try:
        processor = AutoImageProcessor.from_pretrained(model_id)
        model = TimesformerForVideoClassification.from_pretrained(model_id)
        print(f"Modelo {model_id} accesible correctamente")
        return processor, model
    except Exception as e:
        logger.error(f"Error al acceder al modelo {model_id}: {e}")
        print("Si el repositorio es privado, ejecuta: !huggingface-cli login")
        raise

try:
    processor, _ = validate_model_access(MODEL_ID)
except Exception as e:
    logger.error("Fallo al cargar el modelo. Verifica el identificador o tu conexión.")
    raise

# --- Sección 3: Monitoreo de GPU ---
def log_gpu_memory():
    """Registra el uso de memoria de la GPU."""
    try:
        result = subprocess.check_output(['nvidia-smi', '--query-gpu=memory.used,memory.total', '--format=csv'])
        print(f"Uso de GPU:\n{result.decode('utf-8')}")
    except Exception as e:
        logger.warning(f"No se pudo obtener información de GPU: {e}")

log_gpu_memory()

# --- Sección 4: Validación del Dataset ---
def validate_dataset(root_dir):
    """Valida la integridad del dataset y registra estadísticas detalladas."""
    splits = ["train", "val", "test"]
    total_videos = 0
    class_counts = {label: 0 for label in LABELS}
    problematic_videos = []

    for split in splits:
        for label in LABELS:
            label_dir = os.path.join(root_dir, split, label)
            if not os.path.exists(label_dir):
                logger.error(f"Directorio no encontrado: {label_dir}")
                raise FileNotFoundError(f"Directorio {label_dir} no existe")
            videos = [f for f in os.listdir(label_dir) if f.endswith(".mp4")]
            print(f"{split}/{label}: {len(videos)} videos")
            total_videos += len(videos)
            class_counts[label] += len(videos)

            for video in videos:
                video_path = os.path.join(label_dir, video)
                cap = cv2.VideoCapture(video_path)
                if not cap.isOpened():
                    logger.error(f"Video corrupto: {video_path}")
                    problematic_videos.append(video_path)
                    continue
                frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
                fps = cap.get(cv2.CAP_PROP_FPS) or FPS
                width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                if frame_count < 1:
                    logger.error(f"Video sin frames: {video_path}")
                    problematic_videos.append(video_path)
                if fps <= 0:
                    logger.warning(f"FPS inválido en {video_path}, usando FPS por defecto: {FPS}")
                if width == 0 or height == 0:
                    logger.error(f"Resolución inválida en {video_path}")
                    problematic_videos.append(video_path)
                logger.debug(f"Video: {video_path}, Frames: {frame_count}, FPS: {fps}, Resolución: {width}x{height}")
                cap.release()

    print(f"Total de videos validados: {total_videos}")
    print(f"Distribución de clases: {class_counts}")
    print(f"Videos problemáticos detectados: {len(problematic_videos)}")
    if problematic_videos:
        logger.warning(f"Videos problemáticos: {problematic_videos}")
    if abs(class_counts["violence"] - class_counts["no_violence"]) / total_videos > 0.2:
        logger.warning("Desbalance de clases detectado. Considerar técnicas de balanceo.")
    return problematic_videos

problematic_videos = validate_dataset(DATASET_PATH)
# Out:
# Modelo facebook/timesformer-base-finetuned-k400 accesible correctamente
# Uso de GPU:
# memory.used [MiB], memory.total [MiB]
# 2 MiB, 15360 MiB
#
# train/no_violence: 4000 videos
# ERROR:__main__:Video corrupto: /content/drive/MyDrive/dataset_violencia/train/no_violence/no_violencia_1822_horizontal_flip.mp4
# train/violence: 4000 videos
# ERROR:__main__:Video corrupto: /content/drive/MyDrive/dataset_violencia/train/violence/violencia_directa_1240_horizontal_flip.mp4
# val/no_violence: 750 videos
# val/violence: 750 videos
# test/no_violence: 400 videos
# test/violence: 400 videos
# WARNING:__main__:Videos problemáticos: ['/content/drive/MyDrive/dataset_violencia/train/no_violence/no_violencia_1822_horizontal_flip.mp4', '/content/drive/MyDrive/dataset_violencia/train/violence/violencia_directa_1240_horizontal_flip.mp4']
# Total de videos validados: 10300
# Distribución de clases: {'no_violence': 5150, 'violence': 5150}
# Videos problemáticos detectados: 2

# %%
# --- Sección 2: Validación del Dataset ---
def validate_dataset(root_dir):
    """Valida la integridad del dataset."""
    splits = ["train", "val", "test"]
    total_videos = 0
    for split in splits:
        for label in LABELS:
            label_dir = os.path.join(root_dir, split, label)
            if not os.path.exists(label_dir):
                logger.error(f"Directorio no encontrado: {label_dir}")
                raise FileNotFoundError(f"Directorio {label_dir} no existe")
            videos = [f for f in os.listdir(label_dir) if f.endswith(".mp4")]
            logger.info(f"{split}/{label}: {len(videos)} videos")
            print(f"{split}/{label}: {len(videos)} videos")
            total_videos += len(videos)

            # Add this part to list the videos
            print(f"Videos in {split}/{label}:")
            for video in videos:
                print(f"- {video}")
            print("-" * 20) # Separator for clarity

            # Validar videos
            for video in videos[:5]:  # Verificar primeros 5
                cap = cv2.VideoCapture(os.path.join(label_dir, video))
                if not cap.isOpened():
                    logger.error(f"Video corrupto: {video}")
                cap.release()

    logger.info(f"Total de videos validados: {total_videos}")
    print(f"Total de videos validados: {total_videos}")

validate_dataset(DATASET_PATH)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# - violencia_directa_2047_horizontal_flip.mp4
# - violencia_directa_2048_horizontal_flip.mp4
# - violencia_directa_2049_horizontal_flip.mp4
# - violencia_directa_2045_horizontal_flip.mp4
# - violencia_directa_2046_horizontal_flip.mp4
# - violencia_directa_2044_horizontal_flip.mp4
# - violencia_directa_2052_horizontal_flip.mp4
# - violencia_directa_2053_horizontal_flip.mp4
# - violencia_directa_2051_horizontal_flip.mp4
# - violencia_directa_2050_horizontal_flip.mp4
# - violencia_directa_2054_horizontal_flip.mp4
# - violencia_directa_2055_horizontal_flip.mp4
# - violencia_directa_2059_horizontal_flip.mp4
# - violencia_directa_2058_horizontal_flip.mp4
# - violencia_directa_2056_horizontal_flip.mp4
# - violencia_directa_2057_horizontal_flip.mp4
# - violencia_directa_2060_horizontal_flip.mp4
# - violencia_directa_2061_horizontal_flip.mp4
# - violencia_directa_2062_horizontal_flip.mp4
# - violencia_directa_2063_horizontal_flip.mp4
# - violencia_directa_2066_horizontal_flip.mp4
# - violencia_directa_2064_horizontal_flip.mp4
# - violencia_directa_2065_horizontal_flip.mp4
# - violencia_directa_2068_horizontal_flip.mp4
# - violencia_directa_2069_horizontal_flip.mp4
# - violencia_directa_2070_horizontal_flip.mp4
# - violencia_directa_2067_horizontal_flip.mp4
# - violencia_directa_2071_horizontal_flip.mp4
# - violencia_directa_2073_horizontal_flip.mp4
# - violencia_directa_2076_horizontal_flip.mp4
# - violencia_directa_2075_horizontal_flip.mp4
# - violencia_directa_2077_horizontal_flip.mp4
# - violencia_directa_2074_horizontal_flip.mp4
# - violencia_directa_2072_horizontal_flip.mp4
# - violencia_directa_2083_horizontal_flip.mp4
# - violencia_directa_2080_horizontal_flip.mp4
# - violencia_directa_2079_horizontal_flip.mp4
# - violencia_directa_2081_horizontal_flip.mp4
# - violencia_directa_2082_horizontal_flip.mp4
# - violencia_directa_2078_horizontal_flip.mp4
# - violencia_directa_2087_horizontal_flip.mp4
# - violencia_directa_2085_horizontal_flip.mp4
# - violencia_directa_2091_horizontal_flip.mp4
# - violencia_directa_2084_horizontal_flip.mp4
# - violencia_directa_2089_horizontal_flip.mp4
# - violencia_directa_2086_horizontal_flip.mp4
# - violencia_directa_2090_horizontal_flip.mp4
# - violencia_directa_2099_horizontal_flip.mp4
# - violencia_directa_2093_horizontal_flip.mp4
# - violencia_directa_2096_horizontal_flip.mp4
# - violencia_directa_2092_horizontal_flip.mp4
# - violencia_directa_2098_horizontal_flip.mp4
# - violencia_directa_2095_horizontal_flip.mp4
# - violencia_directa_2094_horizontal_flip.mp4
# - violencia_directa_2109_horizontal_flip.mp4
# - violencia_directa_2104_horizontal_flip.mp4
# - violencia_directa_2105_horizontal_flip.mp4
# - violencia_directa_2101_horizontal_flip.mp4
# - violencia_directa_2100_horizontal_flip.mp4
# - violencia_directa_2106_horizontal_flip.mp4
# - violencia_directa_2108_horizontal_flip.mp4
# - violencia_directa_2103_horizontal_flip.mp4
# - violencia_directa_2107_horizontal_flip.mp4
# - violencia_directa_2102_horizontal_flip.mp4
# - violencia_directa_2115_horizontal_flip.mp4
# - violencia_directa_2118_horizontal_flip.mp4
# - violencia_directa_2114_horizontal_flip.mp4
# - violencia_directa_2112_horizontal_flip.mp4
# - violencia_directa_2117_horizontal_flip.mp4
# - violencia_directa_2111_horizontal_flip.mp4
# - violencia_directa_2113_horizontal_flip.mp4
# - violencia_directa_2110_horizontal_flip.mp4
# - violencia_directa_2116_horizontal_flip.mp4
# - violencia_directa_2119_horizontal_flip.mp4
# - violencia_directa_2124_horizontal_flip.mp4
# - violencia_directa_2121_horizontal_flip.mp4
# - violencia_directa_2123_horizontal_flip.mp4
# - violencia_directa_2122_horizontal_flip.mp4
# - violencia_directa_2120_horizontal_flip.mp4
# - violencia_directa_2129_horizontal_flip.mp4
# - violencia_directa_2130_horizontal_flip.mp4
# - violencia_directa_2128_horizontal_flip.mp4
# - violencia_directa_2126_horizontal_flip.mp4
# - violencia_directa_2125_horizontal_flip.mp4
# - violencia_directa_2132_horizontal_flip.mp4
# - violencia_directa_2133_horizontal_flip.mp4
# - violencia_directa_2127_horizontal_flip.mp4
# - violencia_directa_2138_horizontal_flip.mp4
# - violencia_directa_2134_horizontal_flip.mp4
# - violencia_directa_2137_horizontal_flip.mp4
# - violencia_directa_2136_horizontal_flip.mp4
# - violencia_directa_2135_horizontal_flip.mp4
# - violencia_directa_2139_horizontal_flip.mp4
# - violencia_directa_2144_horizontal_flip.mp4
# - violencia_directa_2143_horizontal_flip.mp4
# - violencia_directa_2142_horizontal_flip.mp4
# - violencia_directa_2141_horizontal_flip.mp4
# - violencia_directa_2145_horizontal_flip.mp4
# - violencia_directa_2140_horizontal_flip.mp4
# - violencia_directa_2152_horizontal_flip.mp4
# - violencia_directa_2148_horizontal_flip.mp4
# - violencia_directa_2150_horizontal_flip.mp4
# - violencia_directa_2149_horizontal_flip.mp4
# - violencia_directa_2151_horizontal_flip.mp4
# - violencia_directa_2146_horizontal_flip.mp4
# - violencia_directa_2147_horizontal_flip.mp4
# - violencia_directa_2153_horizontal_flip.mp4
# - violencia_directa_2155_horizontal_flip.mp4
# - violencia_directa_2154_horizontal_flip.mp4
# - violencia_directa_2156_horizontal_flip.mp4
# - violencia_directa_2159_horizontal_flip.mp4
# - violencia_directa_2160_horizontal_flip.mp4
# - violencia_directa_2157_horizontal_flip.mp4
# - violencia_directa_2158_horizontal_flip.mp4
# - violencia_directa_2165_horizontal_flip.mp4
# - violencia_directa_2170_horizontal_flip.mp4
# - violencia_directa_2162_horizontal_flip.mp4
# - violencia_directa_2163_horizontal_flip.mp4
# - violencia_directa_2164_horizontal_flip.mp4
# - violencia_directa_2168_horizontal_flip.mp4
# - violencia_directa_2166_horizontal_flip.mp4
# - violencia_directa_2167_horizontal_flip.mp4
# - violencia_directa_2169_horizontal_flip.mp4
# - violencia_directa_2176_horizontal_flip.mp4
# - violencia_directa_2178_horizontal_flip.mp4
# - violencia_directa_2173_horizontal_flip.mp4
# - violencia_directa_2179_horizontal_flip.mp4
# - violencia_directa_2171_horizontal_flip.mp4
# - violencia_directa_2172_horizontal_flip.mp4
# - violencia_directa_2175_horizontal_flip.mp4
# - violencia_directa_2174_horizontal_flip.mp4
# - violencia_directa_2177_horizontal_flip.mp4
# - violencia_directa_2181_horizontal_flip.mp4
# - violencia_directa_2180_horizontal_flip.mp4
# - violencia_directa_2182_horizontal_flip.mp4
# - violencia_directa_2184_horizontal_flip.mp4
# - violencia_directa_2185_horizontal_flip.mp4
# - violencia_directa_2183_horizontal_flip.mp4
# - violencia_directa_2187_horizontal_flip.mp4
# - violencia_directa_2190_horizontal_flip.mp4
# - violencia_directa_2188_horizontal_flip.mp4
# - violencia_directa_2189_horizontal_flip.mp4
# - violencia_directa_2186_horizontal_flip.mp4
# - violencia_directa_2196_horizontal_flip.mp4
# - violencia_directa_2193_horizontal_flip.mp4
# - violencia_directa_2194_horizontal_flip.mp4
# - violencia_directa_2195_horizontal_flip.mp4
# - violencia_directa_2192_horizontal_flip.mp4
# - violencia_directa_2200_horizontal_flip.mp4
# - violencia_directa_2198_horizontal_flip.mp4
# - violencia_directa_2197_horizontal_flip.mp4
# - violencia_directa_2201_horizontal_flip.mp4
# - violencia_directa_2199_horizontal_flip.mp4
# - violencia_directa_2205_horizontal_flip.mp4
# - violencia_directa_2204_horizontal_flip.mp4
# - violencia_directa_2202_horizontal_flip.mp4
# - violencia_directa_2203_horizontal_flip.mp4
# - violencia_directa_2215_horizontal_flip.mp4
# - violencia_directa_2212_horizontal_flip.mp4
# - violencia_directa_2207_horizontal_flip.mp4
# - violencia_directa_2208_horizontal_flip.mp4
# - violencia_directa_2211_horizontal_flip.mp4
# - violencia_directa_2206_horizontal_flip.mp4
# - violencia_directa_2213_horizontal_flip.mp4
# - violencia_directa_2214_horizontal_flip.mp4
# - violencia_directa_2209_horizontal_flip.mp4
# - violencia_directa_2216_horizontal_flip.mp4
# - violencia_directa_2223_horizontal_flip.mp4
# - violencia_directa_2226_horizontal_flip.mp4
# - violencia_directa_2224_horizontal_flip.mp4
# - violencia_directa_2221_horizontal_flip.mp4
# - violencia_directa_2220_horizontal_flip.mp4
# - violencia_directa_2217_horizontal_flip.mp4
# - violencia_directa_2225_horizontal_flip.mp4
# - violencia_directa_2218_horizontal_flip.mp4
# - violencia_directa_2219_horizontal_flip.mp4
# - violencia_directa_2222_horizontal_flip.mp4
# - violencia_directa_2227_horizontal_flip.mp4
# - violencia_directa_2228_horizontal_flip.mp4
# - violencia_directa_2230_horizontal_flip.mp4
# - violencia_directa_2229_horizontal_flip.mp4
# - violencia_directa_2231_horizontal_flip.mp4
# - violencia_directa_2232_horizontal_flip.mp4
# - violencia_directa_2237_horizontal_flip.mp4
# - violencia_directa_2235_horizontal_flip.mp4
# - violencia_directa_2236_horizontal_flip.mp4
# - violencia_directa_2238_horizontal_flip.mp4
# - violencia_directa_2234_horizontal_flip.mp4
# - violencia_directa_2233_horizontal_flip.mp4
# - violencia_directa_2242_horizontal_flip.mp4
# - violencia_directa_2244_horizontal_flip.mp4
# - violencia_directa_2241_horizontal_flip.mp4
# - violencia_directa_2240_horizontal_flip.mp4
# - violencia_directa_2243_horizontal_flip.mp4
# - violencia_directa_2239_horizontal_flip.mp4
# - violencia_directa_2246_horizontal_flip.mp4
# - violencia_directa_2245_horizontal_flip.mp4
# - violencia_directa_2247_horizontal_flip.mp4
# - violencia_directa_2250_horizontal_flip.mp4
# - violencia_directa_2251_horizontal_flip.mp4
# - violencia_directa_2249_horizontal_flip.mp4
# - violencia_directa_2248_horizontal_flip.mp4
# - violencia_directa_2252_horizontal_flip.mp4
# - violencia_directa_2253_horizontal_flip.mp4
# - violencia_directa_2254_horizontal_flip.mp4
# - violencia_directa_2256_horizontal_flip.mp4
# - violencia_directa_2255_horizontal_flip.mp4
# - violencia_directa_2257_horizontal_flip.mp4
# - violencia_directa_2258_horizontal_flip.mp4
# - violencia_directa_2260_horizontal_flip.mp4
# - violencia_directa_2259_horizontal_flip.mp4
# - violencia_directa_2262_horizontal_flip.mp4
# - violencia_directa_2261_horizontal_flip.mp4
# - violencia_directa_2270_horizontal_flip.mp4
# - violencia_directa_2269_horizontal_flip.mp4
# - violencia_directa_2265_horizontal_flip.mp4
# - violencia_directa_2267_horizontal_flip.mp4
# - violencia_directa_2268_horizontal_flip.mp4
# - violencia_directa_2264_horizontal_flip.mp4
# - violencia_directa_2266_horizontal_flip.mp4
# - violencia_directa_2274_horizontal_flip.mp4
# - violencia_directa_2272_horizontal_flip.mp4
# - violencia_directa_2271_horizontal_flip.mp4
# - violencia_directa_2273_horizontal_flip.mp4
# - violencia_directa_2275_horizontal_flip.mp4
# - violencia_directa_2281_horizontal_flip.mp4
# - violencia_directa_2279_horizontal_flip.mp4
# - violencia_directa_2280_horizontal_flip.mp4
# - violencia_directa_2278_horizontal_flip.mp4
# - violencia_directa_2276_horizontal_flip.mp4
# - violencia_directa_2277_horizontal_flip.mp4
# - violencia_directa_2284_horizontal_flip.mp4
# - violencia_directa_2283_horizontal_flip.mp4
# - violencia_directa_2282_horizontal_flip.mp4
# - violencia_directa_2290_horizontal_flip.mp4
# - violencia_directa_2289_horizontal_flip.mp4
# - violencia_directa_2287_horizontal_flip.mp4
# - violencia_directa_2285_horizontal_flip.mp4
# - violencia_directa_2286_horizontal_flip.mp4
# - violencia_directa_2288_horizontal_flip.mp4
# - violencia_directa_2295_horizontal_flip.mp4
# - violencia_directa_2294_horizontal_flip.mp4
# - violencia_directa_2293_horizontal_flip.mp4
# - violencia_directa_2291_horizontal_flip.mp4
# - violencia_directa_2292_horizontal_flip.mp4
# - violencia_directa_2298_horizontal_flip.mp4
# - violencia_directa_2302_horizontal_flip.mp4
# - violencia_directa_2301_horizontal_flip.mp4
# - violencia_directa_2296_horizontal_flip.mp4
# - violencia_directa_2299_horizontal_flip.mp4
# - violencia_directa_2297_horizontal_flip.mp4
# - violencia_directa_2303_horizontal_flip.mp4
# - violencia_directa_2300_horizontal_flip.mp4
# - violencia_directa_2306_horizontal_flip.mp4
# - violencia_directa_2308_horizontal_flip.mp4
# - violencia_directa_2307_horizontal_flip.mp4
# - violencia_directa_2304_horizontal_flip.mp4
# - violencia_directa_2305_horizontal_flip.mp4
# - violencia_directa_2311_horizontal_flip.mp4
# - violencia_directa_2316_horizontal_flip.mp4
# - violencia_directa_2313_horizontal_flip.mp4
# - violencia_directa_2312_horizontal_flip.mp4
# - violencia_directa_2315_horizontal_flip.mp4
# - violencia_directa_2310_horizontal_flip.mp4
# - violencia_directa_2314_horizontal_flip.mp4
# - violencia_directa_2309_horizontal_flip.mp4
# - violencia_directa_2320_horizontal_flip.mp4
# - violencia_directa_2321_horizontal_flip.mp4
# - violencia_directa_2322_horizontal_flip.mp4
# - violencia_directa_2319_horizontal_flip.mp4
# - violencia_directa_2318_horizontal_flip.mp4
# - violencia_directa_2317_horizontal_flip.mp4
# - violencia_directa_2327_horizontal_flip.mp4
# - violencia_directa_2328_horizontal_flip.mp4
# - violencia_directa_2323_horizontal_flip.mp4
# - violencia_directa_2329_horizontal_flip.mp4
# - violencia_directa_2326_horizontal_flip.mp4
# - violencia_directa_2324_horizontal_flip.mp4
# - violencia_directa_2325_horizontal_flip.mp4
# - violencia_directa_2331_horizontal_flip.mp4
# - violencia_directa_2330_horizontal_flip.mp4
# - violencia_directa_2335_horizontal_flip.mp4
# - violencia_directa_2333_horizontal_flip.mp4
# - violencia_directa_2337_horizontal_flip.mp4
# - violencia_directa_2332_horizontal_flip.mp4
# - violencia_directa_2336_horizontal_flip.mp4
# - violencia_directa_2334_horizontal_flip.mp4
# - violencia_directa_2343_horizontal_flip.mp4
# - violencia_directa_2344_horizontal_flip.mp4
# - violencia_directa_2345_horizontal_flip.mp4
# - violencia_directa_2342_horizontal_flip.mp4
# - violencia_directa_2338_horizontal_flip.mp4
# - violencia_directa_2340_horizontal_flip.mp4
# - violencia_directa_2339_horizontal_flip.mp4
# - violencia_directa_2341_horizontal_flip.mp4
# - violencia_directa_2349_horizontal_flip.mp4
# - violencia_directa_2350_horizontal_flip.mp4
# - violencia_directa_2346_horizontal_flip.mp4
# - violencia_directa_2348_horizontal_flip.mp4
# - violencia_directa_2347_horizontal_flip.mp4
# - violencia_directa_2351_horizontal_flip.mp4
# - violencia_directa_2352_horizontal_flip.mp4
# - violencia_directa_2353_horizontal_flip.mp4
# - violencia_directa_2359_horizontal_flip.mp4
# - violencia_directa_2356_horizontal_flip.mp4
# - violencia_directa_2361_horizontal_flip.mp4
# - violencia_directa_2355_horizontal_flip.mp4
# - violencia_directa_2360_horizontal_flip.mp4
# - violencia_directa_2358_horizontal_flip.mp4
# - violencia_directa_2357_horizontal_flip.mp4
# - violencia_directa_2366_horizontal_flip.mp4
# - violencia_directa_2365_horizontal_flip.mp4
# - violencia_directa_2364_horizontal_flip.mp4
# - violencia_directa_2363_horizontal_flip.mp4
# - violencia_directa_2362_horizontal_flip.mp4
# - violencia_directa_2367_horizontal_flip.mp4
# - violencia_directa_2372_horizontal_flip.mp4
# - violencia_directa_2373_horizontal_flip.mp4
# - violencia_directa_2369_horizontal_flip.mp4
# - violencia_directa_2370_horizontal_flip.mp4
# - violencia_directa_2368_horizontal_flip.mp4
# - violencia_directa_2378_horizontal_flip.mp4
# - violencia_directa_2374_horizontal_flip.mp4
# - violencia_directa_2377_horizontal_flip.mp4
# - violencia_directa_2375_horizontal_flip.mp4
# - violencia_directa_2376_horizontal_flip.mp4
# - violencia_directa_2381_horizontal_flip.mp4
# - violencia_directa_2384_horizontal_flip.mp4
# - violencia_directa_2380_horizontal_flip.mp4
# - violencia_directa_2383_horizontal_flip.mp4
# - violencia_directa_2382_horizontal_flip.mp4
# - violencia_directa_2379_horizontal_flip.mp4
# - violencia_directa_2388_horizontal_flip.mp4
# - violencia_directa_2386_horizontal_flip.mp4
# - violencia_directa_2389_horizontal_flip.mp4
# - violencia_directa_2394_horizontal_flip.mp4
# - violencia_directa_2392_horizontal_flip.mp4
# - violencia_directa_2393_horizontal_flip.mp4
# - violencia_directa_2395_horizontal_flip.mp4
# - violencia_directa_2391_horizontal_flip.mp4
# - violencia_directa_2403_horizontal_flip.mp4
# - violencia_directa_2400_horizontal_flip.mp4
# - violencia_directa_2396_horizontal_flip.mp4
# - violencia_directa_2404_horizontal_flip.mp4
# - violencia_directa_2402_horizontal_flip.mp4
# - violencia_directa_2398_horizontal_flip.mp4
# - violencia_directa_2397_horizontal_flip.mp4
# - violencia_directa_2401_horizontal_flip.mp4
# - violencia_directa_2399_horizontal_flip.mp4
# - violencia_directa_2405_horizontal_flip.mp4
# - violencia_directa_2409_horizontal_flip.mp4
# - violencia_directa_2406_horizontal_flip.mp4
# - violencia_directa_2407_horizontal_flip.mp4
# - violencia_directa_2408_horizontal_flip.mp4
# - violencia_directa_2410_horizontal_flip.mp4
# - violencia_directa_2415_horizontal_flip.mp4
# - violencia_directa_2411_horizontal_flip.mp4
# - violencia_directa_2417_horizontal_flip.mp4
# - violencia_directa_2414_horizontal_flip.mp4
# - violencia_directa_2416_horizontal_flip.mp4
# - violencia_directa_2412_horizontal_flip.mp4
# - violencia_directa_2413_horizontal_flip.mp4
# - violencia_directa_2423_horizontal_flip.mp4
# - violencia_directa_2419_horizontal_flip.mp4
# - violencia_directa_2418_horizontal_flip.mp4
# - violencia_directa_2421_horizontal_flip.mp4
# - violencia_directa_2422_horizontal_flip.mp4
# - violencia_directa_2429_horizontal_flip.mp4
# - violencia_directa_2433_horizontal_flip.mp4
# - violencia_directa_2426_horizontal_flip.mp4
# - violencia_directa_2428_horizontal_flip.mp4
# - violencia_directa_2434_horizontal_flip.mp4
# - violencia_directa_2431_horizontal_flip.mp4
# - violencia_directa_2435_horizontal_flip.mp4
# - violencia_directa_2425_horizontal_flip.mp4
# - violencia_directa_2430_horizontal_flip.mp4
# - violencia_directa_2427_horizontal_flip.mp4
# - violencia_directa_2441_horizontal_flip.mp4
# - violencia_directa_2443_horizontal_flip.mp4
# - violencia_directa_2436_horizontal_flip.mp4
# - violencia_directa_2442_horizontal_flip.mp4
# - violencia_directa_2437_horizontal_flip.mp4
# - violencia_directa_2439_horizontal_flip.mp4
# - violencia_directa_2444_horizontal_flip.mp4
# - violencia_directa_2438_horizontal_flip.mp4
# - violencia_directa_2451_horizontal_flip.mp4
# - violencia_directa_2446_horizontal_flip.mp4
# - violencia_directa_2447_horizontal_flip.mp4
# - violencia_directa_2453_horizontal_flip.mp4
# - violencia_directa_2445_horizontal_flip.mp4
# - violencia_directa_2454_horizontal_flip.mp4
# - violencia_directa_2450_horizontal_flip.mp4
# - violencia_directa_2449_horizontal_flip.mp4
# - violencia_directa_2448_horizontal_flip.mp4
# - violencia_directa_2455_horizontal_flip.mp4
# - violencia_directa_2459_horizontal_flip.mp4
# - violencia_directa_2457_horizontal_flip.mp4
# - violencia_directa_2463_horizontal_flip.mp4
# - violencia_directa_2460_horizontal_flip.mp4
# - violencia_directa_2458_horizontal_flip.mp4
# - violencia_directa_2464_horizontal_flip.mp4
# - violencia_directa_2462_horizontal_flip.mp4
# - violencia_directa_2456_horizontal_flip.mp4
# - violencia_directa_2466_horizontal_flip.mp4
# - violencia_directa_2468_horizontal_flip.mp4
# - violencia_directa_2465_horizontal_flip.mp4
# - violencia_directa_2469_horizontal_flip.mp4
# - violencia_directa_2473_horizontal_flip.mp4
# - violencia_directa_2472_horizontal_flip.mp4
# - violencia_directa_2474_horizontal_flip.mp4
# - violencia_directa_2470_horizontal_flip.mp4
# - violencia_directa_2471_horizontal_flip.mp4
# - violencia_directa_2478_horizontal_flip.mp4
# - violencia_directa_2475_horizontal_flip.mp4
# - violencia_directa_2477_horizontal_flip.mp4
# - violencia_directa_2479_horizontal_flip.mp4
# - violencia_directa_2481_horizontal_flip.mp4
# - violencia_directa_2480_horizontal_flip.mp4
# - violencia_directa_2487_horizontal_flip.mp4
# - violencia_directa_2484_horizontal_flip.mp4
# - violencia_directa_2482_horizontal_flip.mp4
# - violencia_directa_2488_horizontal_flip.mp4
# - violencia_directa_2489_horizontal_flip.mp4
# - violencia_directa_2483_horizontal_flip.mp4
# - violencia_directa_2485_horizontal_flip.mp4
# - violencia_directa_2486_horizontal_flip.mp4
# - violencia_directa_2492_horizontal_flip.mp4
# - violencia_directa_2495_horizontal_flip.mp4
# - violencia_directa_2493_horizontal_flip.mp4
# - violencia_directa_2494_horizontal_flip.mp4
# - violencia_directa_2490_horizontal_flip.mp4
# - violencia_directa_2496_horizontal_flip.mp4
# - violencia_directa_2497_horizontal_flip.mp4
# - violencia_directa_2491_horizontal_flip.mp4
# - violencia_directa_2498_horizontal_flip.mp4
# - violencia_directa_2499_horizontal_flip.mp4
# - violencia_directa_2500_horizontal_flip.mp4
# - violencia_directa_002_horizontal_flip.mp4
# - violencia_directa_013_horizontal_flip.mp4
# - violencia_directa_015_horizontal_flip.mp4
# - violencia_directa_014_horizontal_flip.mp4
# - violencia_directa_018_horizontal_flip.mp4
# - violencia_directa_017_horizontal_flip.mp4
# - violencia_directa_023_horizontal_flip.mp4
# - violencia_directa_021_horizontal_flip.mp4
# - violencia_directa_019_horizontal_flip.mp4
# - violencia_directa_022_horizontal_flip.mp4
# - violencia_directa_020_horizontal_flip.mp4
# - violencia_directa_027_horizontal_flip.mp4
# - violencia_directa_028_horizontal_flip.mp4
# - violencia_directa_031_horizontal_flip.mp4
# - violencia_directa_024_horizontal_flip.mp4
# - violencia_directa_025_horizontal_flip.mp4
# - violencia_directa_029_horizontal_flip.mp4
# - violencia_directa_030_horizontal_flip.mp4
# - violencia_directa_033_horizontal_flip.mp4
# - violencia_directa_034_horizontal_flip.mp4
# - violencia_directa_032_horizontal_flip.mp4
# - violencia_directa_035_horizontal_flip.mp4
# - violencia_directa_039_horizontal_flip.mp4
# - violencia_directa_040_horizontal_flip.mp4
# - violencia_directa_041_horizontal_flip.mp4
# - violencia_directa_042_horizontal_flip.mp4
# - violencia_directa_045_horizontal_flip.mp4
# - violencia_directa_046_horizontal_flip.mp4
# - violencia_directa_043_horizontal_flip.mp4
# - violencia_directa_044_horizontal_flip.mp4
# - violencia_directa_047_horizontal_flip.mp4
# - violencia_directa_055_horizontal_flip.mp4
# - violencia_directa_054_horizontal_flip.mp4
# - violencia_directa_051_horizontal_flip.mp4
# - violencia_directa_052_horizontal_flip.mp4
# - violencia_directa_050_horizontal_flip.mp4
# - violencia_directa_053_horizontal_flip.mp4
# - violencia_directa_049_horizontal_flip.mp4
# - violencia_directa_048_horizontal_flip.mp4
# - violencia_directa_056_horizontal_flip.mp4
# - violencia_directa_061_horizontal_flip.mp4
# - violencia_directa_057_horizontal_flip.mp4
# - violencia_directa_059_horizontal_flip.mp4
# - violencia_directa_058_horizontal_flip.mp4
# - violencia_directa_063_horizontal_flip.mp4
# - violencia_directa_066_horizontal_flip.mp4
# - violencia_directa_068_horizontal_flip.mp4
# - violencia_directa_067_horizontal_flip.mp4
# - violencia_directa_077_horizontal_flip.mp4
# - violencia_directa_072_horizontal_flip.mp4
# - violencia_directa_071_horizontal_flip.mp4
# - violencia_directa_086_horizontal_flip.mp4
# - violencia_directa_1000_horizontal_flip.mp4
# - violencia_directa_1007_horizontal_flip.mp4
# - violencia_directa_1001_horizontal_flip.mp4
# - violencia_directa_1006_horizontal_flip.mp4
# - violencia_directa_1004_horizontal_flip.mp4
# - violencia_directa_1005_horizontal_flip.mp4
# - violencia_directa_1002_horizontal_flip.mp4
# - violencia_directa_1003_horizontal_flip.mp4
# - violencia_directa_1012_horizontal_flip.mp4
# - violencia_directa_1008_horizontal_flip.mp4
# - violencia_directa_1010_horizontal_flip.mp4
# - violencia_directa_1011_horizontal_flip.mp4
# - violencia_directa_1009_horizontal_flip.mp4
# - violencia_directa_1018_horizontal_flip.mp4
# - violencia_directa_1015_horizontal_flip.mp4
# - violencia_directa_1019_horizontal_flip.mp4
# - violencia_directa_1013_horizontal_flip.mp4
# - violencia_directa_1014_horizontal_flip.mp4
# - violencia_directa_1020_horizontal_flip.mp4
# - violencia_directa_1017_horizontal_flip.mp4
# - violencia_directa_1016_horizontal_flip.mp4
# - violencia_directa_1023_horizontal_flip.mp4
# - violencia_directa_1021_horizontal_flip.mp4
# - violencia_directa_1024_horizontal_flip.mp4
# - violencia_directa_1025_horizontal_flip.mp4
# - violencia_directa_1022_horizontal_flip.mp4
# - violencia_directa_1026_horizontal_flip.mp4
# - violencia_directa_1028_horizontal_flip.mp4
# - violencia_directa_1027_horizontal_flip.mp4
# - violencia_directa_1030_horizontal_flip.mp4
# - violencia_directa_1031_horizontal_flip.mp4
# - violencia_directa_1033_horizontal_flip.mp4
# - violencia_directa_1029_horizontal_flip.mp4
# - violencia_directa_1032_horizontal_flip.mp4
# - violencia_directa_1035_horizontal_flip.mp4
# - violencia_directa_1034_horizontal_flip.mp4
# - violencia_directa_1038_horizontal_flip.mp4
# - violencia_directa_1039_horizontal_flip.mp4
# - violencia_directa_1042_horizontal_flip.mp4
# - violencia_directa_1041_horizontal_flip.mp4
# - violencia_directa_1040_horizontal_flip.mp4
# - violencia_directa_1037_horizontal_flip.mp4
# - violencia_directa_1036_horizontal_flip.mp4
# - violencia_directa_1045_horizontal_flip.mp4
# - violencia_directa_1043_horizontal_flip.mp4
# - violencia_directa_1047_horizontal_flip.mp4
# - violencia_directa_1044_horizontal_flip.mp4
# - violencia_directa_1048_horizontal_flip.mp4
# - violencia_directa_1046_horizontal_flip.mp4
# - violencia_directa_1053_horizontal_flip.mp4
# - violencia_directa_1054_horizontal_flip.mp4
# - violencia_directa_1051_horizontal_flip.mp4
# - violencia_directa_1052_horizontal_flip.mp4
# - violencia_directa_1049_horizontal_flip.mp4
# - violencia_directa_1050_horizontal_flip.mp4
# - violencia_directa_1057_horizontal_flip.mp4
# - violencia_directa_1061_horizontal_flip.mp4
# - violencia_directa_1055_horizontal_flip.mp4
# - violencia_directa_1056_horizontal_flip.mp4
# - violencia_directa_1058_horizontal_flip.mp4
# - violencia_directa_1060_horizontal_flip.mp4
# - violencia_directa_1059_horizontal_flip.mp4
# - violencia_directa_1062_horizontal_flip.mp4
# - violencia_directa_1064_horizontal_flip.mp4
# - violencia_directa_1063_horizontal_flip.mp4
# - violencia_directa_1068_horizontal_flip.mp4
# - violencia_directa_1067_horizontal_flip.mp4
# - violencia_directa_1069_horizontal_flip.mp4
# - violencia_directa_1065_horizontal_flip.mp4
# - violencia_directa_1070_horizontal_flip.mp4
# - violencia_directa_1073_horizontal_flip.mp4
# - violencia_directa_1071_horizontal_flip.mp4
# - violencia_directa_1072_horizontal_flip.mp4
# - violencia_directa_1074_horizontal_flip.mp4
# - violencia_directa_1075_horizontal_flip.mp4
# - violencia_directa_1082_horizontal_flip.mp4
# - violencia_directa_1076_horizontal_flip.mp4
# - violencia_directa_1077_horizontal_flip.mp4
# - violencia_directa_1079_horizontal_flip.mp4
# - violencia_directa_1081_horizontal_flip.mp4
# - violencia_directa_1078_horizontal_flip.mp4
# - violencia_directa_1087_horizontal_flip.mp4
# - violencia_directa_1083_horizontal_flip.mp4
# - violencia_directa_1084_horizontal_flip.mp4
# - violencia_directa_1086_horizontal_flip.mp4
# - violencia_directa_1085_horizontal_flip.mp4
# - violencia_directa_1091_horizontal_flip.mp4
# - violencia_directa_1088_horizontal_flip.mp4
# - violencia_directa_1093_horizontal_flip.mp4
# - violencia_directa_1092_horizontal_flip.mp4
# - violencia_directa_1090_horizontal_flip.mp4
# - violencia_directa_1089_horizontal_flip.mp4
# - violencia_directa_1099_horizontal_flip.mp4
# - violencia_directa_1096_horizontal_flip.mp4
# - violencia_directa_1098_horizontal_flip.mp4
# - violencia_directa_1094_horizontal_flip.mp4
# - violencia_directa_1097_horizontal_flip.mp4
# - violencia_directa_1102_horizontal_flip.mp4
# - violencia_directa_1106_horizontal_flip.mp4
# - violencia_directa_1101_horizontal_flip.mp4
# - violencia_directa_1104_horizontal_flip.mp4
# - violencia_directa_1103_horizontal_flip.mp4
# - violencia_directa_1100_horizontal_flip.mp4
# - violencia_directa_1108_horizontal_flip.mp4
# - violencia_directa_1109_horizontal_flip.mp4
# - violencia_directa_1111_horizontal_flip.mp4
# - violencia_directa_1110_horizontal_flip.mp4
# - violencia_directa_1114_horizontal_flip.mp4
# - violencia_directa_1115_horizontal_flip.mp4
# - violencia_directa_1118_horizontal_flip.mp4
# - violencia_directa_1113_horizontal_flip.mp4
# - violencia_directa_1117_horizontal_flip.mp4
# - violencia_directa_1112_horizontal_flip.mp4
# - violencia_directa_1119_horizontal_flip.mp4
# - violencia_directa_1116_horizontal_flip.mp4
# - violencia_directa_1122_horizontal_flip.mp4
# - violencia_directa_1121_horizontal_flip.mp4
# - violencia_directa_1124_horizontal_flip.mp4
# - violencia_directa_1125_horizontal_flip.mp4
# - violencia_directa_1123_horizontal_flip.mp4
# - violencia_directa_1120_horizontal_flip.mp4
# - violencia_directa_1129_horizontal_flip.mp4
# - violencia_directa_1126_horizontal_flip.mp4
# - violencia_directa_1127_horizontal_flip.mp4
# - violencia_directa_1128_horizontal_flip.mp4
# - violencia_directa_1131_horizontal_flip.mp4
# - violencia_directa_1130_horizontal_flip.mp4
# - violencia_directa_1132_horizontal_flip.mp4
# - violencia_directa_1133_horizontal_flip.mp4
# - violencia_directa_1138_horizontal_flip.mp4
# - violencia_directa_1136_horizontal_flip.mp4
# - violencia_directa_1134_horizontal_flip.mp4
# - violencia_directa_1135_horizontal_flip.mp4
# - violencia_directa_1137_horizontal_flip.mp4
# - violencia_directa_1139_horizontal_flip.mp4
# - violencia_directa_1140_horizontal_flip.mp4
# - violencia_directa_1141_horizontal_flip.mp4
# - violencia_directa_1142_horizontal_flip.mp4
# - violencia_directa_1147_horizontal_flip.mp4
# - violencia_directa_1143_horizontal_flip.mp4
# - violencia_directa_1144_horizontal_flip.mp4
# - violencia_directa_1145_horizontal_flip.mp4
# - violencia_directa_1146_horizontal_flip.mp4
# - violencia_directa_1148_horizontal_flip.mp4
# - violencia_directa_1150_horizontal_flip.mp4
# - violencia_directa_1152_horizontal_flip.mp4
# - violencia_directa_1149_horizontal_flip.mp4
# - violencia_directa_1151_horizontal_flip.mp4
# - violencia_directa_1156_horizontal_flip.mp4
# - violencia_directa_1155_horizontal_flip.mp4
# - violencia_directa_1153_horizontal_flip.mp4
# - violencia_directa_1154_horizontal_flip.mp4
# - violencia_directa_1162_horizontal_flip.mp4
# - violencia_directa_1160_horizontal_flip.mp4
# - violencia_directa_1159_horizontal_flip.mp4
# - violencia_directa_1158_horizontal_flip.mp4
# - violencia_directa_1161_horizontal_flip.mp4
# - violencia_directa_1157_horizontal_flip.mp4
# - violencia_directa_1167_horizontal_flip.mp4
# - violencia_directa_1166_horizontal_flip.mp4
# - violencia_directa_1164_horizontal_flip.mp4
# - violencia_directa_1163_horizontal_flip.mp4
# - violencia_directa_1168_horizontal_flip.mp4
# - violencia_directa_1169_horizontal_flip.mp4
# - violencia_directa_1165_horizontal_flip.mp4
# - violencia_directa_1170_horizontal_flip.mp4
# - violencia_directa_1174_horizontal_flip.mp4
# - violencia_directa_1172_horizontal_flip.mp4
# - violencia_directa_1171_horizontal_flip.mp4
# - violencia_directa_1173_horizontal_flip.mp4
# - violencia_directa_1175_horizontal_flip.mp4
# - violencia_directa_1177_horizontal_flip.mp4
# - violencia_directa_1176_horizontal_flip.mp4
# - violencia_directa_1181_horizontal_flip.mp4
# - violencia_directa_1179_horizontal_flip.mp4
# - violencia_directa_1180_horizontal_flip.mp4
# - violencia_directa_1182_horizontal_flip.mp4
# - violencia_directa_1184_horizontal_flip.mp4
# - violencia_directa_1183_horizontal_flip.mp4
# - violencia_directa_1186_horizontal_flip.mp4
# - violencia_directa_1189_horizontal_flip.mp4
# - violencia_directa_1188_horizontal_flip.mp4
# - violencia_directa_1185_horizontal_flip.mp4
# - violencia_directa_1187_horizontal_flip.mp4
# - violencia_directa_1194_horizontal_flip.mp4
# - violencia_directa_1191_horizontal_flip.mp4
# - violencia_directa_1192_horizontal_flip.mp4
# - violencia_directa_1193_horizontal_flip.mp4
# - violencia_directa_1190_horizontal_flip.mp4
# - violencia_directa_1197_horizontal_flip.mp4
# - violencia_directa_1195_horizontal_flip.mp4
# - violencia_directa_1196_horizontal_flip.mp4
# - violencia_directa_1199_horizontal_flip.mp4
# - violencia_directa_1198_horizontal_flip.mp4
# - violencia_directa_1200_horizontal_flip.mp4
# - violencia_directa_1201_horizontal_flip.mp4
# - violencia_directa_1202_horizontal_flip.mp4
# - violencia_directa_635.mp4
# - violencia_directa_1165.mp4
# - violencia_directa_698.mp4
# - violencia_directa_1769.mp4
# - violencia_directa_127.mp4
# - violencia_directa_250.mp4
# - violencia_directa_1222.mp4
# - violencia_directa_576.mp4
# - violencia_directa_1056.mp4
# - violencia_directa_263.mp4
# - violencia_directa_1681.mp4
# - violencia_directa_308.mp4
# - violencia_directa_276.mp4
# - violencia_directa_1388.mp4
# - violencia_directa_1477.mp4
# - violencia_directa_230.mp4
# - violencia_directa_1032.mp4
# - violencia_directa_1468.mp4
# - violencia_directa_569.mp4
# - violencia_directa_297.mp4
# - violencia_directa_1746.mp4
# - violencia_directa_600.mp4
# - violencia_directa_788.mp4
# - violencia_directa_1940.mp4
# - violencia_directa_036.mp4
# - violencia_directa_527.mp4
# - violencia_directa_1160.mp4
# - violencia_directa_1830.mp4
# - violencia_directa_1065.mp4
# - violencia_directa_720.mp4
# - violencia_directa_694.mp4
# - violencia_directa_1357.mp4
# - violencia_directa_1942.mp4
# - violencia_directa_264.mp4
# - violencia_directa_975.mp4
# - violencia_directa_599.mp4
# - violencia_directa_1207.mp4
# - violencia_directa_772.mp4
# - violencia_directa_1959.mp4
# - violencia_directa_1909.mp4
# - violencia_directa_1686.mp4
# - violencia_directa_1765.mp4
# - violencia_directa_1204.mp4
# - violencia_directa_1994.mp4
# - violencia_directa_1719.mp4
# - violencia_directa_1206.mp4
# - violencia_directa_1117.mp4
# - violencia_directa_1214.mp4
# - violencia_directa_1928.mp4
# - violencia_directa_1880.mp4
# - violencia_directa_1146.mp4
# - violencia_directa_1676.mp4
# - violencia_directa_1657.mp4
# - violencia_directa_1170.mp4
# - violencia_directa_920.mp4
# - violencia_directa_1196.mp4
# - violencia_directa_1786.mp4
# - violencia_directa_573.mp4
# - violencia_directa_1315.mp4
# - violencia_directa_536.mp4
# - violencia_directa_849.mp4
# - violencia_directa_1090.mp4
# - violencia_directa_919.mp4
# - violencia_directa_1876.mp4
# - violencia_directa_1910.mp4
# - violencia_directa_1078.mp4
# - violencia_directa_824.mp4
# - violencia_directa_133.mp4
# - violencia_directa_1599.mp4
# - violencia_directa_802.mp4
# - violencia_directa_1644.mp4
# - violencia_directa_1218.mp4
# - violencia_directa_1330.mp4
# - violencia_directa_896.mp4
# - violencia_directa_1729.mp4
# - violencia_directa_1034.mp4
# - violencia_directa_080.mp4
# - violencia_directa_1185.mp4
# - violencia_directa_1554.mp4
# - violencia_directa_1294.mp4
# - violencia_directa_078.mp4
# - violencia_directa_162.mp4
# - violencia_directa_1355.mp4
# - violencia_directa_266.mp4
# - violencia_directa_683.mp4
# - violencia_directa_689.mp4
# - violencia_directa_735.mp4
# - violencia_directa_1996.mp4
# - violencia_directa_875.mp4
# - violencia_directa_1113.mp4
# - violencia_directa_763.mp4
# - violencia_directa_115.mp4
# - violencia_directa_610.mp4
# - violencia_directa_775.mp4
# - violencia_directa_1219.mp4
# - violencia_directa_395.mp4
# - violencia_directa_033.mp4
# - violencia_directa_530.mp4
# - violencia_directa_866.mp4
# - violencia_directa_1726.mp4
# - violencia_directa_423.mp4
# - violencia_directa_1132.mp4
# - violencia_directa_082.mp4
# - violencia_directa_831.mp4
# - violencia_directa_182.mp4
# - violencia_directa_029.mp4
# - violencia_directa_1318.mp4
# - violencia_directa_1060.mp4
# - violencia_directa_1820.mp4
# - violencia_directa_544.mp4
# - violencia_directa_381.mp4
# - violencia_directa_1396.mp4
# - violencia_directa_1064.mp4
# - violencia_directa_1808.mp4
# - violencia_directa_1997.mp4
# - violencia_directa_248.mp4
# - violencia_directa_1807.mp4
# - violencia_directa_1469.mp4
# - violencia_directa_1418.mp4
# - violencia_directa_1977.mp4
# - violencia_directa_1035.mp4
# - violencia_directa_889.mp4
# - violencia_directa_577.mp4
# - violencia_directa_1208.mp4
# - violencia_directa_667.mp4
# - violencia_directa_419.mp4
# - violencia_directa_1086.mp4
# - violencia_directa_1505.mp4
# - violencia_directa_1285.mp4
# - violencia_directa_143.mp4
# - violencia_directa_187.mp4
# - violencia_directa_1124.mp4
# - violencia_directa_1230.mp4
# - violencia_directa_1753.mp4
# - violencia_directa_418.mp4
# - violencia_directa_092.mp4
# - violencia_directa_690.mp4
# - violencia_directa_1304.mp4
# - violencia_directa_1332.mp4
# - violencia_directa_181.mp4
# - violencia_directa_1094.mp4
# - violencia_directa_1527.mp4
# - violencia_directa_1453.mp4
# - violencia_directa_216.mp4
# - violencia_directa_1244.mp4
# - violencia_directa_465.mp4
# - violencia_directa_1316.mp4
# - violencia_directa_117.mp4
# - violencia_directa_906.mp4
# - violencia_directa_1237.mp4
# - violencia_directa_1917.mp4
# - violencia_directa_567.mp4
# - violencia_directa_1918.mp4
# - violencia_directa_090.mp4
# - violencia_directa_057.mp4
# - violencia_directa_063.mp4
# - violencia_directa_531.mp4
# - violencia_directa_1122.mp4
# - violencia_directa_366.mp4
# - violencia_directa_704.mp4
# - violencia_directa_163.mp4
# - violencia_directa_1173.mp4
# - violencia_directa_476.mp4
# - violencia_directa_1905.mp4
# - violencia_directa_1221.mp4
# - violencia_directa_1687.mp4
# - violencia_directa_1883.mp4
# - violencia_directa_1077.mp4
# - violencia_directa_1864.mp4
# - violencia_directa_368.mp4
# - violencia_directa_1856.mp4
# - violencia_directa_923.mp4
# - violencia_directa_151.mp4
# - violencia_directa_1767.mp4
# - violencia_directa_1470.mp4
# - violencia_directa_131.mp4
# - violencia_directa_293.mp4
# - violencia_directa_380.mp4
# - violencia_directa_815.mp4
# - violencia_directa_1409.mp4
# - violencia_directa_367.mp4
# - violencia_directa_1257.mp4
# - violencia_directa_586.mp4
# - violencia_directa_483.mp4
# - violencia_directa_180.mp4
# - violencia_directa_513.mp4
# - violencia_directa_1668.mp4
# - violencia_directa_1234.mp4
# - violencia_directa_1084.mp4
# - violencia_directa_509.mp4
# - violencia_directa_1085.mp4
# - violencia_directa_1893.mp4
# - violencia_directa_370.mp4
# - violencia_directa_682.mp4
# - violencia_directa_719.mp4
# - violencia_directa_355.mp4
# - violencia_directa_1989.mp4
# - violencia_directa_1105.mp4
# - violencia_directa_1019.mp4
# - violencia_directa_561.mp4
# - violencia_directa_671.mp4
# - violencia_directa_1645.mp4
# - violencia_directa_1899.mp4
# - violencia_directa_861.mp4
# - violencia_directa_916.mp4
# - violencia_directa_1491.mp4
# - violencia_directa_1095.mp4
# - violencia_directa_978.mp4
# - violencia_directa_1846.mp4
# - violencia_directa_471.mp4
# - violencia_directa_1151.mp4
# - violencia_directa_605.mp4
# - violencia_directa_739.mp4
# - violencia_directa_1915.mp4
# - violencia_directa_061.mp4
# - violencia_directa_1450.mp4
# - violencia_directa_1199.mp4
# - violencia_directa_045.mp4
# - violencia_directa_1096.mp4
# - violencia_directa_1795.mp4
# - violencia_directa_1411.mp4
# - violencia_directa_1706.mp4
# - violencia_directa_174.mp4
# - violencia_directa_1677.mp4
# - violencia_directa_1984.mp4
# - violencia_directa_1948.mp4
# - violencia_directa_1757.mp4
# - violencia_directa_1331.mp4
# - violencia_directa_321.mp4
# - violencia_directa_1895.mp4
# - violencia_directa_806.mp4
# - violencia_directa_007.mp4
# - violencia_directa_663.mp4
# - violencia_directa_1717.mp4
# - violencia_directa_709.mp4
# - violencia_directa_1379.mp4
# - violencia_directa_915.mp4
# - violencia_directa_1008.mp4
# - violencia_directa_1534.mp4
# - violencia_directa_515.mp4
# - violencia_directa_1461.mp4
# - violencia_directa_240.mp4
# - violencia_directa_107.mp4
# - violencia_directa_099.mp4
# - violencia_directa_1794.mp4
# - violencia_directa_1012.mp4
# - violencia_directa_700.mp4
# - violencia_directa_177.mp4
# - violencia_directa_1106.mp4
# - violencia_directa_1670.mp4
# - violencia_directa_537.mp4
# - violencia_directa_1496.mp4
# - violencia_directa_1093.mp4
# - violencia_directa_617.mp4
# - violencia_directa_1456.mp4
# - violencia_directa_1882.mp4
# - violencia_directa_1923.mp4
# - violencia_directa_1350.mp4
# - violencia_directa_1978.mp4
# - violencia_directa_256.mp4
# - violencia_directa_076.mp4
# - violencia_directa_1256.mp4
# - violencia_directa_1821.mp4
# - violencia_directa_1916.mp4
# - violencia_directa_1824.mp4
# - violencia_directa_1678.mp4
# - violencia_directa_047.mp4
# - violencia_directa_336.mp4
# - violencia_directa_1802.mp4
# - violencia_directa_641.mp4
# - violencia_directa_507.mp4
# - violencia_directa_1359.mp4
# - violencia_directa_118.mp4
# - violencia_directa_645.mp4
# - violencia_directa_706.mp4
# - violencia_directa_231.mp4
# - violencia_directa_1874.mp4
# - violencia_directa_883.mp4
# - violencia_directa_1307.mp4
# - violencia_directa_809.mp4
# - violencia_directa_574.mp4
# - violencia_directa_1625.mp4
# - violencia_directa_885.mp4
# - violencia_directa_146.mp4
# - violencia_directa_443.mp4
# - violencia_directa_1481.mp4
# - violencia_directa_1286.mp4
# - violencia_directa_518.mp4
# - violencia_directa_850.mp4
# - violencia_directa_817.mp4
# - violencia_directa_1248.mp4
# - violencia_directa_935.mp4
# - violencia_directa_974.mp4
# - violencia_directa_1598.mp4
# - violencia_directa_1433.mp4
# - violencia_directa_868.mp4
# - violencia_directa_853.mp4
# - violencia_directa_585.mp4
# - violencia_directa_1974.mp4
# - violencia_directa_1728.mp4
# - violencia_directa_1992.mp4
# - violencia_directa_723.mp4
# - violencia_directa_953.mp4
# - violencia_directa_770.mp4
# - violencia_directa_612.mp4
# - violencia_directa_466.mp4
# - violencia_directa_1610.mp4
# - violencia_directa_278.mp4
# - violencia_directa_1522.mp4
# - violencia_directa_999.mp4
# - violencia_directa_1017.mp4
# - violencia_directa_019.mp4
# - violencia_directa_100.mp4
# - violencia_directa_818.mp4
# - violencia_directa_913.mp4
# - violencia_directa_1739.mp4
# - violencia_directa_103.mp4
# - violencia_directa_275.mp4
# - violencia_directa_1697.mp4
# - violencia_directa_816.mp4
# - violencia_directa_944.mp4
# - violencia_directa_1523.mp4
# - violencia_directa_980.mp4
# - violencia_directa_707.mp4
# - violencia_directa_1725.mp4
# - violencia_directa_300.mp4
# - violencia_directa_1266.mp4
# - violencia_directa_1601.mp4
# - violencia_directa_385.mp4
# - violencia_directa_111.mp4
# - violencia_directa_1865.mp4
# - violencia_directa_1597.mp4
# - violencia_directa_1609.mp4
# - violencia_directa_435.mp4
# - violencia_directa_571.mp4
# - violencia_directa_657.mp4
# - violencia_directa_1969.mp4
# - violencia_directa_1001.mp4
# - violencia_directa_1142.mp4
# - violencia_directa_1749.mp4
# - violencia_directa_218.mp4
# - violencia_directa_1568.mp4
# - violencia_directa_844.mp4
# - violencia_directa_810.mp4
# - violencia_directa_912.mp4
# - violencia_directa_1803.mp4
# - violencia_directa_453.mp4
# - violencia_directa_1235.mp4
# - violencia_directa_951.mp4
# - violencia_directa_730.mp4
# - violencia_directa_930.mp4
# - violencia_directa_067.mp4
# - violencia_directa_1178.mp4
# - violencia_directa_575.mp4
# - violencia_directa_1867.mp4
# - violencia_directa_1189.mp4
# - violencia_directa_119.mp4
# - violencia_directa_157.mp4
# - violencia_directa_109.mp4
# - violencia_directa_1101.mp4
# - violencia_directa_1202.mp4
# - violencia_directa_065.mp4
# - violencia_directa_1238.mp4
# - violencia_directa_743.mp4
# - violencia_directa_1634.mp4
# - violencia_directa_1816.mp4
# - violencia_directa_016.mp4
# - violencia_directa_1154.mp4
# - violencia_directa_437.mp4
# - violencia_directa_1198.mp4
# - violencia_directa_268.mp4
# - violencia_directa_686.mp4
# - violencia_directa_1130.mp4
# - violencia_directa_933.mp4
# - violencia_directa_043.mp4
# - violencia_directa_517.mp4
# - violencia_directa_1475.mp4
# - violencia_directa_1563.mp4
# - violencia_directa_1926.mp4
# - violencia_directa_1135.mp4
# - violencia_directa_294.mp4
# - violencia_directa_1839.mp4
# - violencia_directa_1386.mp4
# - violencia_directa_620.mp4
# - violencia_directa_457.mp4
# - violencia_directa_539.mp4
# - violencia_directa_1445.mp4
# - violencia_directa_1410.mp4
# - violencia_directa_729.mp4
# - violencia_directa_1638.mp4
# - violencia_directa_1457.mp4
# - violencia_directa_021.mp4
# - violencia_directa_158.mp4
# - violencia_directa_2000.mp4
# - violencia_directa_1153.mp4
# - violencia_directa_202.mp4
# - violencia_directa_1555.mp4
# - violencia_directa_1200.mp4
# - violencia_directa_836.mp4
# - violencia_directa_114.mp4
# - violencia_directa_1066.mp4
# - violencia_directa_468.mp4
# - violencia_directa_1674.mp4
# - violencia_directa_1780.mp4
# - violencia_directa_137.mp4
# - violencia_directa_1233.mp4
# - violencia_directa_1183.mp4
# - violencia_directa_1016.mp4
# - violencia_directa_1399.mp4
# - violencia_directa_028.mp4
# - violencia_directa_1406.mp4
# - violencia_directa_1781.mp4
# - violencia_directa_316.mp4
# - violencia_directa_800.mp4
# - violencia_directa_1577.mp4
# - violencia_directa_1419.mp4
# - violencia_directa_1561.mp4
# - violencia_directa_1247.mp4
# - violencia_directa_1171.mp4
# - violencia_directa_793.mp4
# - violencia_directa_1828.mp4
# - violencia_directa_332.mp4
# - violencia_directa_1371.mp4
# - violencia_directa_708.mp4
# - violencia_directa_1443.mp4
# - violencia_directa_1499.mp4
# - violencia_directa_223.mp4
# - violencia_directa_766.mp4
# - violencia_directa_1217.mp4
# - violencia_directa_480.mp4
# - violencia_directa_442.mp4
# - violencia_directa_484.mp4
# - violencia_directa_1878.mp4
# - violencia_directa_227.mp4
# - violencia_directa_859.mp4
# - violencia_directa_1340.mp4
# - violencia_directa_313.mp4
# - violencia_directa_1947.mp4
# - violencia_directa_854.mp4
# - violencia_directa_857.mp4
# - violencia_directa_1335.mp4
# - violencia_directa_626.mp4
# - violencia_directa_427.mp4
# - violencia_directa_879.mp4
# - violencia_directa_1451.mp4
# - violencia_directa_1783.mp4
# - violencia_directa_634.mp4
# - violencia_directa_1068.mp4
# - violencia_directa_1891.mp4
# - violencia_directa_255.mp4
# - violencia_directa_156.mp4
# - violencia_directa_1797.mp4
# - violencia_directa_1966.mp4
# - violencia_directa_747.mp4
# - violencia_directa_1166.mp4
# - violencia_directa_717.mp4
# - violencia_directa_1912.mp4
# - violencia_directa_1390.mp4
# - violencia_directa_1259.mp4
# - violencia_directa_568.mp4
# - violencia_directa_1437.mp4
# - violencia_directa_1140.mp4
# - violencia_directa_753.mp4
# - violencia_directa_1346.mp4
# - violencia_directa_779.mp4
# - violencia_directa_1531.mp4
# - violencia_directa_994.mp4
# - violencia_directa_685.mp4
# - violencia_directa_1965.mp4
# - violencia_directa_901.mp4
# - violencia_directa_1282.mp4
# - violencia_directa_1479.mp4
# - violencia_directa_377.mp4
# - violencia_directa_199.mp4
# - violencia_directa_529.mp4
# - violencia_directa_1177.mp4
# - violencia_directa_330.mp4
# - violencia_directa_1735.mp4
# - violencia_directa_1195.mp4
# - violencia_directa_673.mp4
# - violencia_directa_421.mp4
# - violencia_directa_039.mp4
# - violencia_directa_604.mp4
# - violencia_directa_1884.mp4
# - violencia_directa_1970.mp4
# - violencia_directa_1249.mp4
# - violencia_directa_1476.mp4
# - violencia_directa_534.mp4
# - violencia_directa_1819.mp4
# - violencia_directa_068.mp4
# - violencia_directa_195.mp4
# - violencia_directa_1512.mp4
# - violencia_directa_1072.mp4
# - violencia_directa_126.mp4
# - violencia_directa_1713.mp4
# - violencia_directa_440.mp4
# - violencia_directa_351.mp4
# - violencia_directa_1439.mp4
# - violencia_directa_1973.mp4
# - violencia_directa_018.mp4
# - violencia_directa_034.mp4
# - violencia_directa_304.mp4
# - violencia_directa_095.mp4
# - violencia_directa_1773.mp4
# - violencia_directa_1424.mp4
# - violencia_directa_566.mp4
# - violencia_directa_1023.mp4
# - violencia_directa_924.mp4
# - violencia_directa_1026.mp4
# - violencia_directa_1426.mp4
# - violencia_directa_388.mp4
# - violencia_directa_139.mp4
# - violencia_directa_1619.mp4
# - violencia_directa_1392.mp4
# - violencia_directa_079.mp4
# - violencia_directa_053.mp4
# - violencia_directa_161.mp4
# - violencia_directa_064.mp4
# - violencia_directa_441.mp4
# - violencia_directa_1365.mp4
# - violencia_directa_1879.mp4
# - violencia_directa_362.mp4
# - violencia_directa_208.mp4
# - violencia_directa_1509.mp4
# - violencia_directa_1161.mp4
# - violencia_directa_055.mp4
# - violencia_directa_243.mp4
# - violencia_directa_1334.mp4
# - violencia_directa_914.mp4
# - violencia_directa_1232.mp4
# - violencia_directa_171.mp4
# - violencia_directa_688.mp4
# - violencia_directa_1698.mp4
# - violencia_directa_595.mp4
# - violencia_directa_306.mp4
# - violencia_directa_445.mp4
# - violencia_directa_1906.mp4
# - violencia_directa_272.mp4
# - violencia_directa_1459.mp4
# - violencia_directa_1288.mp4
# - violencia_directa_054.mp4
# - violencia_directa_1138.mp4
# - violencia_directa_136.mp4
# - violencia_directa_1022.mp4
# - violencia_directa_1002.mp4
# - violencia_directa_350.mp4
# - violencia_directa_1600.mp4
# - violencia_directa_624.mp4
# - violencia_directa_305.mp4
# - violencia_directa_241.mp4
# - violencia_directa_722.mp4
# - violencia_directa_1582.mp4
# - violencia_directa_1341.mp4
# - violencia_directa_1322.mp4
# - violencia_directa_1109.mp4
# - violencia_directa_307.mp4
# - violencia_directa_1689.mp4
# - violencia_directa_553.mp4
# - violencia_directa_1253.mp4
# - violencia_directa_225.mp4
# - violencia_directa_261.mp4
# - violencia_directa_1212.mp4
# - violencia_directa_1982.mp4
# - violencia_directa_977.mp4
# - violencia_directa_1074.mp4
# - violencia_directa_470.mp4
# - violencia_directa_823.mp4
# - violencia_directa_237.mp4
# - violencia_directa_422.mp4
# - violencia_directa_1427.mp4
# - violencia_directa_391.mp4
# - violencia_directa_175.mp4
# - violencia_directa_524.mp4
# - violencia_directa_405.mp4
# - violencia_directa_897.mp4
# - violencia_directa_744.mp4
# - violencia_directa_1950.mp4
# - violencia_directa_467.mp4
# - violencia_directa_152.mp4
# - violencia_directa_1667.mp4
# - violencia_directa_1684.mp4
# - violencia_directa_971.mp4
# - violencia_directa_1057.mp4
# - violencia_directa_401.mp4
# - violencia_directa_786.mp4
# - violencia_directa_1832.mp4
# - violencia_directa_084.mp4
# - violencia_directa_193.mp4
# - violencia_directa_1092.mp4
# - violencia_directa_302.mp4
# - violencia_directa_013.mp4
# - violencia_directa_1929.mp4
# - violencia_directa_1344.mp4
# - violencia_directa_1526.mp4
# - violencia_directa_184.mp4
# - violencia_directa_1182.mp4
# - violencia_directa_1963.mp4
# - violencia_directa_1987.mp4
# - violencia_directa_864.mp4
# - violencia_directa_239.mp4
# ...
# - no_violencia_1485_horizontal_flip.mp4
# - no_violencia_1481_horizontal_flip.mp4
# - no_violencia_1482_horizontal_flip.mp4
# - no_violencia_1484_horizontal_flip.mp4
# - no_violencia_1486_horizontal_flip.mp4
# - no_violencia_1493_horizontal_flip.mp4
# - no_violencia_1490_horizontal_flip.mp4
# - no_violencia_1495_horizontal_flip.mp4
# - no_violencia_1491_horizontal_flip.mp4
# - no_violencia_1487_horizontal_flip.mp4
# - no_violencia_1488_horizontal_flip.mp4
# - no_violencia_1496_horizontal_flip.mp4
# - no_violencia_1492_horizontal_flip.mp4
# - no_violencia_1489_horizontal_flip.mp4
# - no_violencia_1494_horizontal_flip.mp4
# - no_violencia_1506_horizontal_flip.mp4
# - no_violencia_1497_horizontal_flip.mp4
# - no_violencia_1502_horizontal_flip.mp4
# - no_violencia_1498_horizontal_flip.mp4
# - no_violencia_1501_horizontal_flip.mp4
# - no_violencia_1507_horizontal_flip.mp4
# - no_violencia_1499_horizontal_flip.mp4
# - no_violencia_1500_horizontal_flip.mp4
# - no_violencia_1504_horizontal_flip.mp4
# - no_violencia_1505_horizontal_flip.mp4
# - no_violencia_1503_horizontal_flip.mp4
# - no_violencia_1508_horizontal_flip.mp4
# - no_violencia_1509_horizontal_flip.mp4
# - no_violencia_1512_horizontal_flip.mp4
# - no_violencia_1510_horizontal_flip.mp4
# - no_violencia_1513_horizontal_flip.mp4
# - no_violencia_1511_horizontal_flip.mp4
# - no_violencia_1514_horizontal_flip.mp4
# - no_violencia_1515_horizontal_flip.mp4
# - no_violencia_1519_horizontal_flip.mp4
# - no_violencia_1516_horizontal_flip.mp4
# - no_violencia_1520_horizontal_flip.mp4
# - no_violencia_1522_horizontal_flip.mp4
# - no_violencia_1518_horizontal_flip.mp4
# - no_violencia_1521_horizontal_flip.mp4
# - no_violencia_1523_horizontal_flip.mp4
# - no_violencia_1527_horizontal_flip.mp4
# - no_violencia_1528_horizontal_flip.mp4
# - no_violencia_1524_horizontal_flip.mp4
# - no_violencia_1525_horizontal_flip.mp4
# - no_violencia_1526_horizontal_flip.mp4
# - no_violencia_1531_horizontal_flip.mp4
# - no_violencia_1530_horizontal_flip.mp4
# - no_violencia_1529_horizontal_flip.mp4
# - no_violencia_1538_horizontal_flip.mp4
# - no_violencia_1535_horizontal_flip.mp4
# - no_violencia_1537_horizontal_flip.mp4
# - no_violencia_1532_horizontal_flip.mp4
# - no_violencia_1533_horizontal_flip.mp4
# - no_violencia_1534_horizontal_flip.mp4
# - no_violencia_1536_horizontal_flip.mp4
# - no_violencia_1541_horizontal_flip.mp4
# - no_violencia_1539_horizontal_flip.mp4
# - no_violencia_1543_horizontal_flip.mp4
# - no_violencia_1540_horizontal_flip.mp4
# - no_violencia_1542_horizontal_flip.mp4
# - no_violencia_1546_horizontal_flip.mp4
# - no_violencia_1549_horizontal_flip.mp4
# - no_violencia_1548_horizontal_flip.mp4
# - no_violencia_1550_horizontal_flip.mp4
# - no_violencia_1547_horizontal_flip.mp4
# - no_violencia_1545_horizontal_flip.mp4
# - no_violencia_1544_horizontal_flip.mp4
# --------------------
# test/violence: 400 videos
# Videos in test/violence:
# - violencia_directa_2551.mp4
# - violencia_directa_2693.mp4
# - violencia_directa_2638.mp4
# - violencia_directa_2791.mp4
# - violencia_directa_2561.mp4
# - violencia_directa_2744.mp4
# - violencia_directa_2670.mp4
# - violencia_directa_2664.mp4
# - violencia_directa_2598.mp4
# - violencia_directa_2623.mp4
# - violencia_directa_2641.mp4
# - violencia_directa_2649.mp4
# - violencia_directa_2747.mp4
# - violencia_directa_2509.mp4
# - violencia_directa_2659.mp4
# - violencia_directa_2559.mp4
# - violencia_directa_2618.mp4
# - violencia_directa_2557.mp4
# - violencia_directa_2602.mp4
# - violencia_directa_2572.mp4
# - violencia_directa_2691.mp4
# - violencia_directa_2516.mp4
# - violencia_directa_2550.mp4
# - violencia_directa_2575.mp4
# - violencia_directa_2580.mp4
# - violencia_directa_2501.mp4
# - violencia_directa_2540.mp4
# - violencia_directa_2587.mp4
# - violencia_directa_2788.mp4
# - violencia_directa_2683.mp4
# - violencia_directa_2581.mp4
# - violencia_directa_2595.mp4
# - violencia_directa_2505.mp4
# - violencia_directa_2628.mp4
# - violencia_directa_2534.mp4
# - violencia_directa_2545.mp4
# - violencia_directa_2573.mp4
# - violencia_directa_2756.mp4
# - violencia_directa_2552.mp4
# - violencia_directa_2541.mp4
# - violencia_directa_2766.mp4
# - violencia_directa_2784.mp4
# - violencia_directa_2750.mp4
# - violencia_directa_2608.mp4
# - violencia_directa_2569.mp4
# - violencia_directa_2776.mp4
# - violencia_directa_2522.mp4
# - violencia_directa_2627.mp4
# - violencia_directa_2726.mp4
# - violencia_directa_2690.mp4
# - violencia_directa_2706.mp4
# - violencia_directa_2778.mp4
# - violencia_directa_2582.mp4
# - violencia_directa_2560.mp4
# - violencia_directa_2790.mp4
# - violencia_directa_2761.mp4
# - violencia_directa_2754.mp4
# - violencia_directa_2660.mp4
# - violencia_directa_2546.mp4
# - violencia_directa_2673.mp4
# - violencia_directa_2549.mp4
# - violencia_directa_2719.mp4
# - violencia_directa_2526.mp4
# - violencia_directa_2730.mp4
# - violencia_directa_2769.mp4
# - violencia_directa_2795.mp4
# - violencia_directa_2599.mp4
# - violencia_directa_2715.mp4
# - violencia_directa_2547.mp4
# - violencia_directa_2556.mp4
# - violencia_directa_2702.mp4
# - violencia_directa_2518.mp4
# - violencia_directa_2760.mp4
# - violencia_directa_2594.mp4
# - violencia_directa_2708.mp4
# - violencia_directa_2643.mp4
# - violencia_directa_2577.mp4
# - violencia_directa_2616.mp4
# - violencia_directa_2718.mp4
# - violencia_directa_2755.mp4
# - violencia_directa_2542.mp4
# - violencia_directa_2679.mp4
# - violencia_directa_2751.mp4
# - violencia_directa_2530.mp4
# - violencia_directa_2503.mp4
# - violencia_directa_2717.mp4
# - violencia_directa_2625.mp4
# - violencia_directa_2613.mp4
# - violencia_directa_2626.mp4
# - violencia_directa_2576.mp4
# - violencia_directa_2681.mp4
# - violencia_directa_2729.mp4
# - violencia_directa_2579.mp4
# - violencia_directa_2514.mp4
# - violencia_directa_2782.mp4
# - violencia_directa_2763.mp4
# - violencia_directa_2675.mp4
# - violencia_directa_2647.mp4
# - violencia_directa_2558.mp4
# - violencia_directa_2742.mp4
# - violencia_directa_2703.mp4
# - violencia_directa_2711.mp4
# - violencia_directa_2677.mp4
# - violencia_directa_2669.mp4
# - violencia_directa_2684.mp4
# - violencia_directa_2654.mp4
# - violencia_directa_2781.mp4
# - violencia_directa_2607.mp4
# - violencia_directa_2676.mp4
# - violencia_directa_2520.mp4
# - violencia_directa_2596.mp4
# - violencia_directa_2655.mp4
# - violencia_directa_2600.mp4
# - violencia_directa_2765.mp4
# - violencia_directa_2736.mp4
# - violencia_directa_2619.mp4
# - violencia_directa_2723.mp4
# - violencia_directa_2502.mp4
# - violencia_directa_2767.mp4
# - violencia_directa_2652.mp4
# - violencia_directa_2710.mp4
# - violencia_directa_2774.mp4
# - violencia_directa_2720.mp4
# - violencia_directa_2732.mp4
# - violencia_directa_2787.mp4
# - violencia_directa_2511.mp4
# - violencia_directa_2707.mp4
# - violencia_directa_2656.mp4
# - violencia_directa_2567.mp4
# - violencia_directa_2593.mp4
# - violencia_directa_2734.mp4
# - violencia_directa_2741.mp4
# - violencia_directa_2631.mp4
# - violencia_directa_2566.mp4
# - violencia_directa_2515.mp4
# - violencia_directa_2709.mp4
# - violencia_directa_2507.mp4
# - violencia_directa_2793.mp4
# - violencia_directa_2636.mp4
# - violencia_directa_2674.mp4
# - violencia_directa_2757.mp4
# - violencia_directa_2764.mp4
# - violencia_directa_2553.mp4
# - violencia_directa_2783.mp4
# - violencia_directa_2517.mp4
# - violencia_directa_2621.mp4
# - violencia_directa_2644.mp4
# - violencia_directa_2696.mp4
# - violencia_directa_2620.mp4
# - violencia_directa_2797.mp4
# - violencia_directa_2728.mp4
# - violencia_directa_2800.mp4
# - violencia_directa_2589.mp4
# - violencia_directa_2586.mp4
# - violencia_directa_2748.mp4
# - violencia_directa_2780.mp4
# - violencia_directa_2771.mp4
# - violencia_directa_2646.mp4
# - violencia_directa_2639.mp4
# - violencia_directa_2792.mp4
# - violencia_directa_2629.mp4
# - violencia_directa_2648.mp4
# - violencia_directa_2571.mp4
# - violencia_directa_2605.mp4
# - violencia_directa_2667.mp4
# - violencia_directa_2671.mp4
# - violencia_directa_2504.mp4
# - violencia_directa_2666.mp4
# - violencia_directa_2612.mp4
# - violencia_directa_2506.mp4
# - violencia_directa_2701.mp4
# - violencia_directa_2527.mp4
# - violencia_directa_2592.mp4
# - violencia_directa_2624.mp4
# - violencia_directa_2799.mp4
# - violencia_directa_2738.mp4
# - violencia_directa_2510.mp4
# - violencia_directa_2529.mp4
# - violencia_directa_2508.mp4
# - violencia_directa_2653.mp4
# - violencia_directa_2704.mp4
# - violencia_directa_2672.mp4
# - violencia_directa_2622.mp4
# - violencia_directa_2768.mp4
# - violencia_directa_2733.mp4
# - violencia_directa_2663.mp4
# - violencia_directa_2640.mp4
# - violencia_directa_2562.mp4
# - violencia_directa_2779.mp4
# - violencia_directa_2604.mp4
# - violencia_directa_2606.mp4
# - violencia_directa_2601.mp4
# - violencia_directa_2539.mp4
# - violencia_directa_2716.mp4
# - violencia_directa_2777.mp4
# - violencia_directa_2565.mp4
# - violencia_directa_2564.mp4
# - violencia_directa_2512.mp4
# - violencia_directa_2590.mp4
# - violencia_directa_2584.mp4
# - violencia_directa_2528.mp4
# - violencia_directa_2713.mp4
# - violencia_directa_2630.mp4
# - violencia_directa_2615.mp4
# - violencia_directa_2609.mp4
# - violencia_directa_2722.mp4
# - violencia_directa_2610.mp4
# - violencia_directa_2714.mp4
# - violencia_directa_2695.mp4
# - violencia_directa_2665.mp4
# - violencia_directa_2680.mp4
# - violencia_directa_2699.mp4
# - violencia_directa_2737.mp4
# - violencia_directa_2759.mp4
# - violencia_directa_2588.mp4
# - violencia_directa_2642.mp4
# - violencia_directa_2743.mp4
# - violencia_directa_2531.mp4
# - violencia_directa_2591.mp4
# - violencia_directa_2570.mp4
# - violencia_directa_2662.mp4
# - violencia_directa_2773.mp4
# - violencia_directa_2658.mp4
# - violencia_directa_2770.mp4
# - violencia_directa_2698.mp4
# - violencia_directa_2603.mp4
# - violencia_directa_2700.mp4
# - violencia_directa_2634.mp4
# - violencia_directa_2568.mp4
# - violencia_directa_2521.mp4
# - violencia_directa_2519.mp4
# - violencia_directa_2548.mp4
# - violencia_directa_2721.mp4
# - violencia_directa_2645.mp4
# - violencia_directa_2740.mp4
# - violencia_directa_2753.mp4
# - violencia_directa_2563.mp4
# - violencia_directa_2536.mp4
# - violencia_directa_2794.mp4
# - violencia_directa_2535.mp4
# - violencia_directa_2772.mp4
# - violencia_directa_2633.mp4
# - violencia_directa_2657.mp4
# - violencia_directa_2798.mp4
# - violencia_directa_2537.mp4
# - violencia_directa_2554.mp4
# - violencia_directa_2532.mp4
# - violencia_directa_2731.mp4
# - violencia_directa_2678.mp4
# - violencia_directa_2525.mp4
# - violencia_directa_2796.mp4
# - violencia_directa_2686.mp4
# - violencia_directa_2687.mp4
# - violencia_directa_2635.mp4
# - violencia_directa_2745.mp4
# - violencia_directa_2617.mp4
# - violencia_directa_2762.mp4
# - violencia_directa_2685.mp4
# - violencia_directa_2758.mp4
# - violencia_directa_2523.mp4
# - violencia_directa_2544.mp4
# - violencia_directa_2712.mp4
# - violencia_directa_2583.mp4
# - violencia_directa_2524.mp4
# - violencia_directa_2614.mp4
# - violencia_directa_2538.mp4
# - violencia_directa_2735.mp4
# - violencia_directa_2689.mp4
# - violencia_directa_2694.mp4
# - violencia_directa_2578.mp4
# - violencia_directa_2746.mp4
# - violencia_directa_2533.mp4
# - violencia_directa_2651.mp4
# - violencia_directa_2650.mp4
# - violencia_directa_2752.mp4
# - violencia_directa_2513.mp4
# - violencia_directa_2749.mp4
# - violencia_directa_2785.mp4
# - violencia_directa_2688.mp4
# - violencia_directa_2725.mp4
# - violencia_directa_2705.mp4
# - violencia_directa_2697.mp4
# - violencia_directa_2637.mp4
# - violencia_directa_2585.mp4
# - violencia_directa_2543.mp4
# - violencia_directa_2739.mp4
# - violencia_directa_2724.mp4
# - violencia_directa_2727.mp4
# - violencia_directa_2611.mp4
# - violencia_directa_2555.mp4
# - violencia_directa_2597.mp4
# - violencia_directa_2692.mp4
# - violencia_directa_2789.mp4
# - violencia_directa_2775.mp4
# - violencia_directa_2661.mp4
# - violencia_directa_2574.mp4
# - violencia_directa_2632.mp4
# - violencia_directa_2682.mp4
# - violencia_directa_2668.mp4
# - violencia_directa_271_horizontal_flip.mp4
# - violencia_directa_421_horizontal_flip.mp4
# - violencia_directa_427_horizontal_flip.mp4
# - violencia_directa_422_horizontal_flip.mp4
# - violencia_directa_426_horizontal_flip.mp4
# - violencia_directa_424_horizontal_flip.mp4
# - violencia_directa_429_horizontal_flip.mp4
# - violencia_directa_430_horizontal_flip.mp4
# - violencia_directa_431_horizontal_flip.mp4
# - violencia_directa_432_horizontal_flip.mp4
# - violencia_directa_428_horizontal_flip.mp4
# - violencia_directa_433_horizontal_flip.mp4
# - violencia_directa_434_horizontal_flip.mp4
# - violencia_directa_435_horizontal_flip.mp4
# - violencia_directa_437_horizontal_flip.mp4
# - violencia_directa_436_horizontal_flip.mp4
# - violencia_directa_441_horizontal_flip.mp4
# - violencia_directa_440_horizontal_flip.mp4
# - violencia_directa_442_horizontal_flip.mp4
# - violencia_directa_438_horizontal_flip.mp4
# - violencia_directa_439_horizontal_flip.mp4
# - violencia_directa_445_horizontal_flip.mp4
# - violencia_directa_446_horizontal_flip.mp4
# - violencia_directa_444_horizontal_flip.mp4
# - violencia_directa_447_horizontal_flip.mp4
# - violencia_directa_448_horizontal_flip.mp4
# - violencia_directa_451_horizontal_flip.mp4
# - violencia_directa_449_horizontal_flip.mp4
# - violencia_directa_450_horizontal_flip.mp4
# - violencia_directa_454_horizontal_flip.mp4
# - violencia_directa_456_horizontal_flip.mp4
# - violencia_directa_453_horizontal_flip.mp4
# - violencia_directa_458_horizontal_flip.mp4
# - violencia_directa_457_horizontal_flip.mp4
# - violencia_directa_452_horizontal_flip.mp4
# - violencia_directa_455_horizontal_flip.mp4
# - violencia_directa_464_horizontal_flip.mp4
# - violencia_directa_460_horizontal_flip.mp4
# - violencia_directa_459_horizontal_flip.mp4
# - violencia_directa_463_horizontal_flip.mp4
# - violencia_directa_461_horizontal_flip.mp4
# - violencia_directa_468_horizontal_flip.mp4
# - violencia_directa_465_horizontal_flip.mp4
# - violencia_directa_467_horizontal_flip.mp4
# - violencia_directa_462_horizontal_flip.mp4
# - violencia_directa_466_horizontal_flip.mp4
# - violencia_directa_471_horizontal_flip.mp4
# - violencia_directa_470_horizontal_flip.mp4
# - violencia_directa_472_horizontal_flip.mp4
# - violencia_directa_469_horizontal_flip.mp4
# - violencia_directa_473_horizontal_flip.mp4
# - violencia_directa_479_horizontal_flip.mp4
# - violencia_directa_475_horizontal_flip.mp4
# - violencia_directa_478_horizontal_flip.mp4
# - violencia_directa_476_horizontal_flip.mp4
# - violencia_directa_474_horizontal_flip.mp4
# - violencia_directa_477_horizontal_flip.mp4
# - violencia_directa_480_horizontal_flip.mp4
# - violencia_directa_485_horizontal_flip.mp4
# - violencia_directa_484_horizontal_flip.mp4
# - violencia_directa_482_horizontal_flip.mp4
# - violencia_directa_483_horizontal_flip.mp4
# - violencia_directa_481_horizontal_flip.mp4
# - violencia_directa_489_horizontal_flip.mp4
# - violencia_directa_486_horizontal_flip.mp4
# - violencia_directa_488_horizontal_flip.mp4
# - violencia_directa_490_horizontal_flip.mp4
# - violencia_directa_487_horizontal_flip.mp4
# - violencia_directa_495_horizontal_flip.mp4
# - violencia_directa_492_horizontal_flip.mp4
# - violencia_directa_491_horizontal_flip.mp4
# - violencia_directa_493_horizontal_flip.mp4
# - violencia_directa_494_horizontal_flip.mp4
# - violencia_directa_496_horizontal_flip.mp4
# - violencia_directa_499_horizontal_flip.mp4
# - violencia_directa_500_horizontal_flip.mp4
# - violencia_directa_498_horizontal_flip.mp4
# - violencia_directa_497_horizontal_flip.mp4
# - violencia_directa_504_horizontal_flip.mp4
# - violencia_directa_501_horizontal_flip.mp4
# - violencia_directa_502_horizontal_flip.mp4
# - violencia_directa_503_horizontal_flip.mp4
# - violencia_directa_509_horizontal_flip.mp4
# - violencia_directa_510_horizontal_flip.mp4
# - violencia_directa_512_horizontal_flip.mp4
# - violencia_directa_505_horizontal_flip.mp4
# - violencia_directa_511_horizontal_flip.mp4
# - violencia_directa_506_horizontal_flip.mp4
# - violencia_directa_507_horizontal_flip.mp4
# - violencia_directa_508_horizontal_flip.mp4
# - violencia_directa_517_horizontal_flip.mp4
# - violencia_directa_518_horizontal_flip.mp4
# - violencia_directa_515_horizontal_flip.mp4
# - violencia_directa_514_horizontal_flip.mp4
# - violencia_directa_513_horizontal_flip.mp4
# - violencia_directa_516_horizontal_flip.mp4
# - violencia_directa_519_horizontal_flip.mp4
# - violencia_directa_521_horizontal_flip.mp4
# - violencia_directa_523_horizontal_flip.mp4
# - violencia_directa_522_horizontal_flip.mp4
# - violencia_directa_520_horizontal_flip.mp4
# --------------------
# Total de videos validados: 10300

# %%
# --- Sección 5: Definir Dataset Personalizado ---
class ViolenceDataset(Dataset):
    def __init__(self, root_dir, split, processor, num_frames=NUM_FRAMES):
        self.root_dir = os.path.join(root_dir, split)
        self.processor = processor
        self.num_frames = num_frames
        self.videos = []
        self.labels = []
        self.durations = []
        self.resolutions = []

        for label in LABELS:
            label_dir = os.path.join(self.root_dir, label)
            for video_file in os.listdir(label_dir):
                if video_file.endswith(".mp4"):
                    video_path = os.path.join(label_dir, video_file)
                    cap = cv2.VideoCapture(video_path)
                    if not cap.isOpened():
                        logger.warning(f"Omitiendo video corrupto: {video_path}")
                        continue
                    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
                    fps = cap.get(cv2.CAP_PROP_FPS) or FPS
                    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                    if frame_count < 1 or width == 0 or height == 0:
                        logger.warning(f"Omitiendo video inválido: {video_path}")
                        cap.release()
                        continue
                    duration = frame_count / fps
                    cap.release()

                    self.videos.append(video_path)
                    self.labels.append(LABELS.index(label))
                    self.durations.append(duration)
                    self.resolutions.append((width, height))

        logger.info(f"{split} dataset cargado con {len(self.videos)} videos")
        if len(self.videos) == 0:
            logger.error(f"No se cargaron videos en {split}. Verifica el directorio.")
            raise ValueError(f"No se encontraron videos válidos en {split}")

    def __len__(self):
        return len(self.videos)

    def __getitem__(self, idx):
        try:
            video_path = self.videos[idx]
            label = self.labels[idx]

            cap = cv2.VideoCapture(video_path)
            frames = []
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frames.append(frame)
            cap.release()

            if len(frames) == 0:
                logger.error(f"Video sin frames: {video_path}")
                raise ValueError(f"No se pudieron leer frames de {video_path}")

            if len(frames) < self.num_frames:
                frames = frames + [frames[-1]] * (self.num_frames - len(frames))
            else:
                indices = np.linspace(0, len(frames) - 1, self.num_frames).astype(int)
                frames = [frames[i] for i in indices]

            inputs = self.processor(frames, return_tensors="pt")
            inputs = {k: v.squeeze(0) for k, v in inputs.items()}

            return inputs, torch.tensor(label, dtype=torch.long), self.durations[idx]
        except Exception as e:
            logger.error(f"Error al procesar video {video_path}: {e}")
            raise

# --- Sección 6: Cargar Dataset y DataLoaders ---
train_dataset = ViolenceDataset(DATASET_PATH, "train", processor)
val_dataset = ViolenceDataset(DATASET_PATH, "val", processor)
test_dataset = ViolenceDataset(DATASET_PATH, "test", processor)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,  # Reducido a 0 para estabilidad en Colab
    pin_memory=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %%
# --- Sección 7: Funciones de Evaluación y Visualización ---
def compute_metrics(labels, preds, probs):
    if len(labels) == 0 or len(preds) == 0:
        logger.error("No se recolectaron etiquetas o predicciones. Verifica los datos.")
        return {
            "confusion_matrix": np.zeros((NUM_CLASSES, NUM_CLASSES)),
            "accuracy": 0.0,
            "precision": 0.0,
            "recall": 0.0,
            "specificity": 0.0,
            "tpr": 0.0,
            "fpr": 0.0,
            "f1_score": 0.0,
            "fpr_roc": [0],
            "tpr_roc": [0],
            "auc": 0.0
        }

    cm = confusion_matrix(labels, preds)
    acc = accuracy_score(labels, preds)
    prec = precision_score(labels, preds, average='binary', zero_division=0)
    rec = recall_score(labels, preds, average='binary', zero_division=0)
    f1 = f1_score(labels, preds, average='binary', zero_division=0)
    spec = cm[0, 0] / (cm[0, 0] + cm[0, 1]) if (cm[0, 0] + cm[0, 1]) > 0 else 0
    tpr = rec
    fpr = cm[0, 1] / (cm[0, 1] + cm[0, 0]) if (cm[0, 1] + cm[0, 0]) > 0 else 0

    fpr_roc, tpr_roc, _ = roc_curve(labels, probs, drop_intermediate=False)
    auc_score = auc(fpr_roc, tpr_roc)

    return {
        "confusion_matrix": cm,
        "accuracy": acc,
        "precision": prec,
        "recall": rec,
        "specificity": spec,
        "tpr": tpr,
        "fpr": fpr,
        "f1_score": f1,
        "fpr_roc": fpr_roc,
        "tpr_roc": tpr_roc,
        "auc": auc_score
    }

def plot_metrics(metrics, phase, epoch, save_path):
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 4, 1)
    sns.heatmap(metrics["confusion_matrix"], annot=True, fmt="d", cmap="Blues")
    plt.title(f"Matriz de Confusión - {phase} (Época {epoch})")
    plt.xlabel("Predicho")
    plt.ylabel("Real")

    plt.subplot(1, 4, 2)
    plt.plot(metrics["fpr_roc"], metrics["tpr_roc"], label=f"AUC = {metrics['auc']:.2f}")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.title(f"Curva ROC - {phase} (Época {epoch})")
    plt.legend()

    plt.subplot(1, 4, 3)
    metrics_text = (f"Exactitud: {metrics['accuracy']:.3f}\n"
                    f"Precisión: {metrics['precision']:.3f}\n"
                    f"Sensibilidad: {metrics['recall']:.3f}\n"
                    f"Especificidad: {metrics['specificity']:.3f}\n"
                    f"F1-Score: {metrics['f1_score']:.3f}\n"
                    f"AUC: {metrics['auc']:.3f}")
    plt.text(0.1, 0.5, metrics_text, fontsize=12)
    plt.axis('off')
    plt.title(f"Métricas - {phase} (Época {epoch})")

    plt.subplot(1, 4, 4)
    plt.bar(["F1-Score"], [metrics["f1_score"]], color='skyblue')
    plt.ylim(0, 1)
    plt.title(f"F1-Score - {phase} (Época {epoch})")

    plt.tight_layout()
    plt.savefig(os.path.join(save_path, f"metrics_{phase}_epoch_{epoch}.png"))
    plt.close()
    wandb.log({f"{phase}_metrics_epoch_{epoch}": wandb.Image(os.path.join(save_path, f"metrics_{phase}_epoch_{epoch}.png"))})

def plot_learning_curves(history, phase, save_path):
    plt.figure(figsize=(15, 4))

    plt.subplot(1, 3, 1)
    plt.plot(history["train_loss"], label="Train Loss")
    plt.plot(history["val_loss"], label="Val Loss")
    plt.xlabel("Época")
    plt.ylabel("Pérdida")
    plt.title(f"Curva de Pérdida - {phase}")
    plt.legend()

    plt.subplot(1, 3, 2)
    plt.plot(history["train_acc"], label="Train Acc")
    plt.plot(history["val_acc"], label="Val Acc")
    plt.xlabel("Época")
    plt.ylabel("Exactitud")
    plt.title(f"Curva de Exactitud - {phase}")
    plt.legend()

    plt.subplot(1, 3, 3)
    plt.plot(history["val_f1"], label="Val F1")
    plt.xlabel("Época")
    plt.ylabel("F1-Score")
    plt.title(f"Curva de F1-Score - {phase}")
    plt.legend()

    plt.tight_layout()
    plt.savefig(os.path.join(save_path, f"learning_curves_{phase}.png"))
    plt.close()
    wandb.log({f"learning_curves_{phase}": wandb.Image(os.path.join(save_path, f"learning_curves_{phase}.png"))})

def plot_probability_histogram(labels, probs, phase, save_path):
    plt.figure(figsize=(8, 6))
    for label in range(NUM_CLASSES):
        mask = np.array(labels) == label
        plt.hist(np.array(probs)[mask], bins=20, alpha=0.5, label=LABELS[label])
    plt.xlabel("Probabilidad de Violencia")
    plt.ylabel("Frecuencia")
    plt.title(f"Histograma de Probabilidades - {phase}")
    plt.legend()
    plt.savefig(os.path.join(save_path, f"prob_histogram_{phase}.png"))
    plt.close()
    wandb.log({f"prob_histogram_{phase}": wandb.Image(os.path.join(save_path, f"prob_histogram_{phase}.png"))})

def plot_prob_vs_duration(durations, probs, labels, phase, save_path):
    plt.figure(figsize=(8, 6))
    for label in range(NUM_CLASSES):
        mask = np.array(labels) == label
        plt.scatter(np.array(durations)[mask], np.array(probs)[mask], alpha=0.5, label=LABELS[label])
    plt.xlabel("Duración del Video (segundos)")
    plt.ylabel("Probabilidad de Violencia")
    plt.title(f"Probabilidad vs. Duración - {phase}")
    plt.legend()
    plt.savefig(os.path.join(save_path, f"prob_vs_duration_{phase}.png"))
    plt.close()
    wandb.log({f"prob_vs_duration_{phase}": wandb.Image(os.path.join(save_path, f"prob_vs_duration_{phase}.png"))})

def plot_f1_vs_duration(durations, f1_scores, phase, save_path):
    plt.figure(figsize=(8, 6))
    plt.scatter(durations, f1_scores, alpha=0.5)
    plt.xlabel("Duración del Video (segundos)")
    plt.ylabel("F1-Score")
    plt.title(f"F1-Score vs. Duración - {phase}")
    plt.savefig(os.path.join(save_path, f"f1_vs_duration_{phase}.png"))
    plt.close()
    wandb.log({f"f1_vs_duration_{phase}": wandb.Image(os.path.join(save_path, f"f1_vs_duration_{phase}.png"))})

def plot_error_rate_vs_duration(durations, correct, phase, save_path):
    plt.figure(figsize=(8, 6))
    plt.scatter(durations, [1 - c for c in correct], alpha=0.5)
    plt.xlabel("Duración del Video (segundos)")
    plt.ylabel("Tasa de Error (0=Correcto, 1=Incorrecto)")
    plt.title(f"Tasa de Error vs. Duración - {phase}")
    plt.savefig(os.path.join(save_path, f"error_rate_vs_duration_{phase}.png"))
    plt.close()
    wandb.log({f"error_rate_vs_duration_{phase}": wandb.Image(os.path.join(save_path, f"error_rate_vs_duration_{phase}.png"))})

# %%
# --- Sección 8: Funciones de Entrenamiento ---
def train_epoch(model, loader, optimizer, criterion, scaler, device, accumulation_steps):
    model.train()
    total_loss = 0
    all_preds = []
    all_labels = []
    all_probs = []
    failed_batches = 0
    optimizer.zero_grad()

    for i, (inputs, labels, _) in enumerate(tqdm(loader, desc="Entrenando")):
        try:
            inputs = {k: v.to(device) for k, v in inputs.items()}
            labels = labels.to(device)

            logger.debug(f"Batch {i}: Input shape: {inputs['pixel_values'].shape}, Labels shape: {labels.shape}")

            with autocast():
                outputs = model(**inputs)
                loss = criterion(outputs.logits, labels) / accumulation_steps

            scaler.scale(loss).backward()

            if (i + 1) % accumulation_steps == 0:
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()

            total_loss += loss.item() * accumulation_steps
            preds = torch.argmax(outputs.logits, dim=1)
            probs = torch.softmax(outputs.logits, dim=1)[:, 1]

            all_preds.extend(preds.detach().cpu().numpy())
            all_labels.extend(labels.detach().cpu().numpy())
            all_probs.extend(probs.detach().cpu().numpy())

            torch.cuda.empty_cache()
        except Exception as e:
            logger.error(f"Error en batch {i}: {e}")
            failed_batches += 1
            continue

    if failed_batches == len(loader):
        logger.error("Todos los lotes fallaron. Verifica los datos o la configuración del modelo.")
        raise RuntimeError("No se procesó ningún lote correctamente")

    print(f"Lotes procesados: {len(loader) - failed_batches}/{len(loader)}, Lotes fallidos: {failed_batches}")

    avg_loss = total_loss / (len(loader) - failed_batches) if len(loader) > failed_batches else 0
    metrics = compute_metrics(all_labels, all_preds, all_probs)
    return avg_loss, metrics, all_labels, all_probs

def evaluate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_preds = []
    all_labels = []
    all_probs = []
    inference_times = []
    failed_batches = 0
    all_durations = []

    with torch.no_grad():
        for i, (inputs, labels, durations) in enumerate(tqdm(loader, desc="Evaluando")):
            try:
                start_time = time.time()
                inputs = {k: v.to(device) for k, v in inputs.items()}
                labels = labels.to(device)

                logger.debug(f"Batch {i}: Input shape: {inputs['pixel_values'].shape}, Labels shape: {labels.shape}")

                with autocast():
                    outputs = model(**inputs)
                    loss = criterion(outputs.logits, labels)

                inference_times.append(time.time() - start_time)
                total_loss += loss.item()
                preds = torch.argmax(outputs.logits, dim=1)
                probs = torch.softmax(outputs.logits, dim=1)[:, 1]

                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
                all_probs.extend(probs.cpu().numpy())
                all_durations.extend(durations)

                torch.cuda.empty_cache()
            except Exception as e:
                logger.error(f"Error en batch {i}: {e}")
                failed_batches += 1
                continue

    if failed_batches == len(loader):
        logger.error("Todos los lotes fallaron. Verifica los datos o la configuración del modelo.")
        raise RuntimeError("No se procesó ningún lote correctamente")

    print(f"Lotes procesados: {len(loader) - failed_batches}/{len(loader)}, Lotes fallidos: {failed_batches}")

    avg_loss = total_loss / (len(loader) - failed_batches) if len(loader) > failed_batches else 0
    metrics = compute_metrics(all_labels, all_preds, all_probs)
    avg_inference_time = np.mean(inference_times) if inference_times else 0
    return avg_loss, metrics, all_labels, all_probs, avg_inference_time, all_durations

# %% [markdown]
# # ENTRENAMIENTO CON TRANSFER LEARNING

# %%
# --- Sección 9: Transfer Learning ---
logger.info("Iniciando Transfer Learning")
print("Iniciando Transfer Learning")
model = TimesformerForVideoClassification.from_pretrained(
    MODEL_ID,
    num_labels=NUM_CLASSES,
    ignore_mismatched_sizes=True
)

for name, param in model.named_parameters():
    if "timesformer" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

model = model.to(device)
try:
    model = torch.compile(model)
    logger.info("Modelo compilado con torch.compile")
    print("Modelo compilado con torch.compile")
except Exception as e:
    logger.warning(f"torch.compile no soportado: {e}")
    print(f"torch.compile no soportado: {e}")

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE_TL, weight_decay=WEIGHT_DECAY)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)
scaler = GradScaler()

history_tl = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": [], "val_f1": []}
best_val_loss = float("inf")
early_stop_counter = 0

for epoch in range(NUM_EPOCHS_TL):
    start_time = time.time()

    train_loss, train_metrics, train_labels, train_probs = train_epoch(
        model, train_loader, optimizer, criterion, scaler, device, ACCUMULATION_STEPS
    )
    val_loss, val_metrics, val_labels, val_probs, val_inference_time, val_durations = evaluate_epoch(
        model, val_loader, criterion, device
    )

    history_tl["train_loss"].append(train_loss)
    history_tl["val_loss"].append(val_loss)
    history_tl["train_acc"].append(train_metrics["accuracy"])
    history_tl["val_acc"].append(val_metrics["accuracy"])
    history_tl["val_f1"].append(val_metrics["f1_score"])

    scheduler.step(val_loss)

    checkpoint = {
        "epoch": epoch,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "scheduler_state_dict": scheduler.state_dict(),
        "scaler_state_dict": scaler.state_dict(),
        "val_loss": val_loss,
        "val_metrics": val_metrics
    }
    checkpoint_path = os.path.join(CHECKPOINT_PATH, f"checkpoint_tl_epoch_{epoch}_{TIMESTAMP}.pt")
    torch.save(checkpoint, checkpoint_path)
    logger.info(f"Checkpoint guardado: {checkpoint_path}")
    print(f"Checkpoint guardado: {checkpoint_path}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_path = os.path.join(CHECKPOINT_PATH, f"best_model_tl_{TIMESTAMP}.pt")
        torch.save(model.state_dict(), best_model_path)
        logger.info(f"Mejor modelo guardado: {best_model_path}")
        print(f"Mejor modelo guardado: {best_model_path}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1

    logger.info(f"Época {epoch+1}/{NUM_EPOCHS_TL}")
    print(f"Época {epoch+1}/{NUM_EPOCHS_TL}")
    logger.info(f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    print(f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    logger.info(f"Train Acc: {train_metrics['accuracy']:.3f}, Val Acc: {val_metrics['accuracy']:.3f}")
    print(f"Train Acc: {train_metrics['accuracy']:.3f}, Val Acc: {val_metrics['accuracy']:.3f}")
    logger.info(f"Val F1-Score: {val_metrics['f1_score']:.3f}")
    print(f"Val F1-Score: {val_metrics['f1_score']:.3f}")
    logger.info(f"Tiempo: {time.time() - start_time:.2f} segundos")
    print(f"Tiempo: {time.time() - start_time:.2f} segundos")
    wandb.log({
        "epoch": epoch,
        "train_loss": train_loss,
        "val_loss": val_loss,
        "train_acc": train_metrics["accuracy"],
        "val_acc": val_metrics["accuracy"],
        "val_f1": val_metrics["f1_score"],
        "val_inference_time": val_inference_time
    })

    plot_metrics(val_metrics, "Validación TL", epoch, CHECKPOINT_PATH)
    plot_probability_histogram(val_labels, val_probs, f"Validación TL Epoch {epoch}", CHECKPOINT_PATH)
    plot_prob_vs_duration(val_durations, val_probs, val_labels, f"Validación TL Epoch {epoch}", CHECKPOINT_PATH)

    if early_stop_counter >= PATIENCE:
        logger.info("Early Stopping activado")
        print("Early Stopping activado")
        break

plot_learning_curves(history_tl, "Transfer Learning", CHECKPOINT_PATH)
# Out:
# Iniciando Transfer Learning
# Some weights of TimesformerForVideoClassification were not initialized from the model checkpoint at facebook/timesformer-base-finetuned-k400 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([400, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([400]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Modelo compilado con torch.compile
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_0_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 1/20
# Train Loss: 0.3305, Val Loss: 0.2104
# Train Acc: 0.870, Val Acc: 0.931
# Val F1-Score: 0.930
# Tiempo: 943.01 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_1_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 2/20
# Train Loss: 0.1934, Val Loss: 0.1649
# Train Acc: 0.931, Val Acc: 0.947
# Val F1-Score: 0.947
# Tiempo: 870.31 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_2_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 3/20
# Train Loss: 0.1612, Val Loss: 0.1457
# Train Acc: 0.941, Val Acc: 0.953
# Val F1-Score: 0.953
# Tiempo: 869.37 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_3_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 4/20
# Train Loss: 0.1430, Val Loss: 0.1338
# Train Acc: 0.948, Val Acc: 0.959
# Val F1-Score: 0.959
# Tiempo: 895.66 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_4_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 5/20
# Train Loss: 0.1305, Val Loss: 0.1268
# Train Acc: 0.953, Val Acc: 0.959
# Val F1-Score: 0.959
# Tiempo: 874.99 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_5_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 6/20
# Train Loss: 0.1214, Val Loss: 0.1194
# Train Acc: 0.957, Val Acc: 0.962
# Val F1-Score: 0.962
# Tiempo: 871.27 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_6_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 7/20
# Train Loss: 0.1138, Val Loss: 0.1175
# Train Acc: 0.962, Val Acc: 0.962
# Val F1-Score: 0.961
# Tiempo: 874.44 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_7_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 8/20
# Train Loss: 0.1084, Val Loss: 0.1117
# Train Acc: 0.963, Val Acc: 0.966
# Val F1-Score: 0.966
# Tiempo: 857.88 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_8_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 9/20
# Train Loss: 0.1033, Val Loss: 0.1088
# Train Acc: 0.966, Val Acc: 0.965
# Val F1-Score: 0.965
# Tiempo: 858.21 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_9_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 10/20
# Train Loss: 0.0989, Val Loss: 0.1054
# Train Acc: 0.968, Val Acc: 0.963
# Val F1-Score: 0.963
# Tiempo: 858.55 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_10_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 11/20
# Train Loss: 0.0954, Val Loss: 0.1035
# Train Acc: 0.969, Val Acc: 0.966
# Val F1-Score: 0.966
# Tiempo: 873.17 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_11_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 12/20
# Train Loss: 0.0920, Val Loss: 0.1024
# Train Acc: 0.969, Val Acc: 0.965
# Val F1-Score: 0.965
# Tiempo: 870.40 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_12_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 13/20
# Train Loss: 0.0893, Val Loss: 0.0989
# Train Acc: 0.970, Val Acc: 0.964
# Val F1-Score: 0.964
# Tiempo: 869.14 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_13_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 14/20
# Train Loss: 0.0868, Val Loss: 0.0971
# Train Acc: 0.970, Val Acc: 0.965
# Val F1-Score: 0.965
# Tiempo: 868.59 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_14_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 15/20
# Train Loss: 0.0842, Val Loss: 0.0957
# Train Acc: 0.973, Val Acc: 0.966
# Val F1-Score: 0.966
# Tiempo: 862.20 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_15_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 16/20
# Train Loss: 0.0820, Val Loss: 0.0950
# Train Acc: 0.973, Val Acc: 0.965
# Val F1-Score: 0.965
# Tiempo: 856.71 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_16_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 17/20
# Train Loss: 0.0800, Val Loss: 0.0929
# Train Acc: 0.974, Val Acc: 0.967
# Val F1-Score: 0.967
# Tiempo: 860.10 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]
# Lotes procesados: 4000/4000, Lotes fallidos: 0
# Evaluando:   0%|          | 0/750 [00:00<?, ?it/s]
# Lotes procesados: 750/750, Lotes fallidos: 0
# Checkpoint guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/checkpoint_tl_epoch_17_20250518_044626.pt
# Mejor modelo guardado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Época 18/20
# Train Loss: 0.0782, Val Loss: 0.0923
# Train Acc: 0.975, Val Acc: 0.967
# Val F1-Score: 0.967
# Tiempo: 863.04 segundos
# Entrenando:   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
# !pip install wandb albumentations retrying

# %%
# --- Sección 10: Fine-Tuning ---
import albumentations as A
from albumentations.pytorch import ToTensorV2
import numpy as np
import torch
from torch.cuda.amp import autocast
from sklearn.metrics import accuracy_score, f1_score
from tqdm import tqdm

logger.info("Iniciando Fine-Tuning")
print("Iniciando Fine-Tuning")

# Validar dataset antes de Fine-Tuning
problematic_videos = validate_dataset(DATASET_PATH)
if problematic_videos:
    logger.warning(f"Se detectaron {len(problematic_videos)} videos problemáticos. Revisa el log y corrige antes de continuar.")
    print(f"Se detectaron {len(problematic_videos)} videos problemáticos. Revisa el log y corrige antes de continuar.")
    raise ValueError("Corrige los videos problemáticos antes de continuar con Fine-Tuning.")

# Función para corregir el prefijo '_orig_mod.' en el state_dict
def fix_state_dict(state_dict):
    new_state_dict = {}
    for key, value in state_dict.items():
        new_key = key.replace("_orig_mod.", "")  # Eliminar el prefijo
        new_state_dict[new_key] = value
    return new_state_dict

# Implementación corregida de evaluate_epoch
def evaluate_epoch(model, data_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    all_labels = []
    all_probs = []
    inference_times = []
    durations = []
    with torch.no_grad():
        for inputs, labels, duration in tqdm(data_loader, desc="Evaluando"):
            start_time = time.time()
            inputs = {k: v.to(device) for k, v in inputs.items()}
            labels = labels.to(device)
            with autocast():
                outputs = model(**inputs).logits
                loss = criterion(outputs, labels)
            running_loss += loss.item()
            # Aplicar softmax para obtener probabilidades de ambas clases
            probs = torch.softmax(outputs, dim=1).cpu().numpy()  # Forma: (batch_size, 2)
            all_probs.append(probs)
            all_labels.append(labels.cpu().numpy())
            inference_times.append(time.time() - start_time)
            durations.append(duration.numpy() if isinstance(duration, torch.Tensor) else duration)
    all_probs = np.vstack(all_probs)  # Concatenar: (n_samples, 2)
    all_labels = np.concatenate(all_labels)
    durations = np.concatenate(durations)
    avg_loss = running_loss / len(data_loader)
    metrics = {
        "accuracy": accuracy_score(all_labels, np.argmax(all_probs, axis=1)),
        "f1_score": f1_score(all_labels, np.argmax(all_probs, axis=1), average='weighted')
    }
    logger.info(f"Forma de all_probs en evaluate_epoch: {all_probs.shape}")
    print(f"Forma de all_probs en evaluate_epoch: {all_probs.shape}")
    return avg_loss, metrics, all_labels, all_probs, np.mean(inference_times), durations

# Inicializar el modelo
model = TimesformerForVideoClassification.from_pretrained(
    MODEL_ID,
    num_labels=NUM_CLASSES,
    ignore_mismatched_sizes=True
)

# Cargar mejor modelo de Transfer Learning
TIMESTAMP = "20250518_044626"
best_model_path = os.path.join(CHECKPOINT_PATH, f"best_model_tl_{TIMESTAMP}.pt")
if not os.path.exists(best_model_path):
    logger.error(f"No se encontró el mejor modelo TL: {best_model_path}")
    raise FileNotFoundError(f"No se encontró {best_model_path}")
try:
    state_dict = torch.load(best_model_path, map_location=device)
    state_dict = fix_state_dict(state_dict)
    model.load_state_dict(state_dict, strict=True)
    logger.info(f"Mejor modelo TL cargado: {best_model_path}")
    print(f"Mejor modelo TL cargado: {best_model_path}")
except Exception as e:
    logger.error(f"Error al cargar el state_dict: {e}")
    raise RuntimeError(f"Error al cargar el state_dict: {e}")

# Descongelar capas superiores
trainable_params = 0
total_params = 0
for name, param in model.named_parameters():
    if any(layer in name for layer in ["timesformer.encoder.layer.9", "timesformer.encoder.layer.10", "timesformer.encoder.layer.11", "classifier"]):
        param.requires_grad = True
        trainable_params += param.numel()
    else:
        param.requires_grad = False
    total_params += param.numel()
logger.info(f"Parámetros entrenables: {trainable_params} ({trainable_params/total_params*100:.2f}% del total)")
print(f"Parámetros entrenables: {trainable_params} ({trainable_params/total_params*100:.2f}% del total)")

# Aumentar dropout en el clasificador
model.classifier.dropout = torch.nn.Dropout(p=0.5)
logger.info("Dropout del clasificador aumentado a 0.5")
print("Dropout del clasificador aumentado a 0.5")

# Configuración
LEARNING_RATE_FT = 1e-5
WEIGHT_DECAY = 1e-2
NUM_EPOCHS_FT = 12

model = model.to(device)
try:
    model = torch.compile(model)
    logger.info("Modelo compilado con torch.compile")
    print("Modelo compilado con torch.compile")
except Exception as e:
    logger.warning(f"torch.compile no soportado: {e}")
    print(f"torch.compile no soportado: {e}")

# Definir optimizador, criterio y escalador
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=LEARNING_RATE_FT,
    weight_decay=WEIGHT_DECAY
)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)
scaler = GradScaler()

# Aumento de datos
augmentation = A.Compose([
    A.Rotate(limit=10, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.RandomCrop(height=IMG_SIZE, width=IMG_SIZE, p=0.3),
    A.Resize(height=IMG_SIZE, width=IMG_SIZE),
    ToTensorV2()
])

# Actualizar ViolenceDataset con aumento de datos
class ViolenceDatasetAugmented(ViolenceDataset):
    def __getitem__(self, idx):
        try:
            video_path = self.videos[idx]
            label = self.labels[idx]
            cap = cv2.VideoCapture(video_path)
            frames = []
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frames.append(frame)
            cap.release()
            if len(frames) == 0:
                logger.error(f"Video sin frames: {video_path}")
                raise ValueError(f"No se pudieron leer frames de {video_path}")
            if len(frames) < self.num_frames:
                frames = frames + [frames[-1]] * (self.num_frames - len(frames))
            else:
                indices = np.linspace(0, len(frames) - 1, self.num_frames).astype(int)
                frames = [frames[i] for i in indices]
            augmented_frames = []
            for frame in frames:
                augmented = augmentation(image=frame)
                augmented_frames.append(augmented["image"].permute(1, 2, 0).numpy())
            inputs = self.processor(augmented_frames, return_tensors="pt")
            inputs = {k: v.squeeze(0) for k, v in inputs.items()}
            return inputs, torch.tensor(label, dtype=torch.long), self.durations[idx]
        except Exception as e:
            logger.error(f"Error al procesar video {video_path}: {e}")
            raise

# Actualizar datasets
train_dataset = ViolenceDatasetAugmented(DATASET_PATH, "train", processor)
val_dataset = ViolenceDataset(DATASET_PATH, "val", processor)
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# Función para analizar errores
def analyze_errors(labels, preds, probs, videos, phase, epoch, save_path):
    errors = [(i, labels[i], preds[i], probs[i], videos[i]) for i in range(len(labels)) if labels[i] != preds[i]]
    logger.info(f"Número de errores en {phase} (Época {epoch}): {len(errors)}")
    print(f"Número de errores en {phase} (Época {epoch}): {len(errors)}")
    false_positives = [(i, prob, video) for i, true, pred, prob, video in errors if true == 0 and pred == 1]
    false_negatives = [(i, prob, video) for i, true, pred, prob, video in errors if true == 1 and pred == 0]
    logger.info(f"Falsos Positivos: {len(false_positives)}")
    print(f"Falsos Positivos: {len(false_positives)}")
    logger.info(f"Falsos Negativos: {len(false_negatives)}")
    print(f"Falsos Negativos: {len(false_negatives)}")
    for idx, prob, video_path in false_positives[:3]:
        logger.info(f"Falso Positivo - Índice: {idx}, Video: {video_path}, Probabilidad: {prob:.3f}")
        print(f"Falso Positivo - Índice: {idx}, Video: {video_path}, Probabilidad: {prob:.3f}")
    for idx, prob, video_path in false_negatives[:3]:
        logger.info(f"Falso Negativo - Índice: {idx}, Video: {video_path}, Probabilidad: {prob:.3f}")
        print(f"Falso Negativo - Índice: {idx}, Video: {video_path}, Probabilidad: {prob:.3f}")
    for idx, true, pred, prob, video_path in errors[:3]:
        cap = cv2.VideoCapture(video_path)
        frames = []
        while cap.isOpened() and len(frames) < 4:
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)
        cap.release()
        plt.figure(figsize=(12, 3))
        for i, frame in enumerate(frames):
            plt.subplot(1, 4, i+1)
            plt.imshow(frame)
            plt.axis('off')
            plt.title(f"Frame {i+1}")
        plt.suptitle(f"Error: Real={LABELS[true]}, Pred={LABELS[pred]}, Prob={prob:.3f}")
        plt.savefig(os.path.join(save_path, f"error_{phase}_epoch_{epoch}_{idx}.png"))
        plt.close()
        wandb.log({f"error_{phase}_epoch_{epoch}_{idx}": wandb.Image(os.path.join(save_path, f"error_{phase}_epoch_{epoch}_{idx}.png"))})
    return len(false_positives), len(false_negatives)

# Entrenamiento
history_ft = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": [], "val_f1": [], "fp": [], "fn": []}
best_val_loss = float("inf")
early_stop_counter = 0

for epoch in range(NUM_EPOCHS_FT):
    start_time = time.time()
    train_loss, train_metrics, train_labels, train_probs = train_epoch(
        model, train_loader, optimizer, criterion, scaler, device, ACCUMULATION_STEPS
    )
    val_loss, val_metrics, val_labels, val_probs, val_inference_time, val_durations = evaluate_epoch(
        model, val_loader, criterion, device
    )
    # Depurar val_probs
    logger.info(f"Tipo de val_probs: {type(val_probs)}")
    print(f"Tipo de val_probs: {type(val_probs)}")
    if isinstance(val_probs, list):
        val_probs = np.vstack([p.cpu().numpy() if isinstance(p, torch.Tensor) else p for p in val_probs])
    elif isinstance(val_probs, torch.Tensor):
        val_probs = val_probs.cpu().numpy()
    else:
        logger.error(f"Tipo inesperado de val_probs: {type(val_probs)}")
        raise ValueError(f"Tipo inesperado de val_probs: {type(val_probs)}")
    logger.info(f"Forma de val_probs: {val_probs.shape}")
    print(f"Forma de val_probs: {val_probs.shape}")
    logger.info(f"Primeras filas de val_probs: {val_probs[:5]}")
    print(f"Primeras filas de val_probs: {val_probs[:5]}")

    # Manejar val_probs con una sola columna
    if val_probs.ndim == 2 and val_probs.shape[1] == 2:
        val_probs_positive = val_probs[:, 1]  # Probabilidad de la clase "violence"
    elif val_probs.ndim == 2 and val_probs.shape[1] == 1:
        logger.warning("val_probs tiene una sola columna. Asumiendo probabilidades de la clase positiva.")
        val_probs_positive = val_probs[:, 0]
        # Construir array con ambas clases
        val_probs = np.hstack([1 - val_probs, val_probs])  # [P(no_violence), P(violence)]
    else:
        logger.error(f"Forma inesperada de val_probs: {val_probs.shape}")
        raise ValueError(f"Forma inesperada de val_probs: {val_probs.shape}")

    val_preds = (val_probs_positive > 0.5).astype(int)
    fp, fn = analyze_errors(
        val_labels, val_preds, val_probs_positive,
        [val_dataset.videos[i] for i in range(len(val_labels))], "Validación FT", epoch, CHECKPOINT_PATH
    )
    history_ft["train_loss"].append(train_loss)
    history_ft["val_loss"].append(val_loss)
    history_ft["train_acc"].append(train_metrics["accuracy"])
    history_ft["val_acc"].append(val_metrics["accuracy"])
    history_ft["val_f1"].append(val_metrics["f1_score"])
    history_ft["fp"].append(fp)
    history_ft["fn"].append(fn)
    scheduler.step(val_loss)
    checkpoint = {
        "epoch": epoch,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "scheduler_state_dict": scheduler.state_dict(),
        "scaler_state_dict": scaler.state_dict(),
        "val_loss": val_loss,
        "val_metrics": val_metrics
    }
    checkpoint_path = os.path.join(CHECKPOINT_PATH, f"checkpoint_ft_epoch_{epoch}_{TIMESTAMP}.pt")
    torch.save(checkpoint, checkpoint_path)
    logger.info(f"Checkpoint guardado: {checkpoint_path}")
    print(f"Checkpoint guardado: {checkpoint_path}")
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_path = os.path.join(CHECKPOINT_PATH, f"best_model_ft_{TIMESTAMP}.pt")
        torch.save(model.state_dict(), best_model_path)
        logger.info(f"Mejor modelo guardado: {best_model_path}")
        print(f"Mejor modelo guardado: {best_model_path}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
    logger.info(f"Época {epoch+1}/{NUM_EPOCHS_FT}")
    print(f"Época {epoch+1}/{NUM_EPOCHS_FT}")
    logger.info(f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    print(f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    logger.info(f"Train Acc: {train_metrics['accuracy']:.3f}, Val Acc: {val_metrics['accuracy']:.3f}")
    print(f"Train Acc: {train_metrics['accuracy']:.3f}, Val Acc: {val_metrics['accuracy']:.3f}")
    logger.info(f"Val F1-Score: {val_metrics['f1_score']:.3f}")
    print(f"Val F1-Score: {val_metrics['f1_score']:.3f}")
    logger.info(f"Tiempo: {time.time() - start_time:.2f} segundos")
    print(f"Tiempo: {time.time() - start_time:.2f} segundos")
    logger.info(f"Tiempo de inferencia promedio (validación): {val_inference_time:.4f} segundos")
    print(f"Tiempo de inferencia promedio (validación): {val_inference_time:.4f} segundos")
    wandb.log({
        "epoch": epoch,
        "train_loss": train_loss,
        "val_loss": val_loss,
        "train_acc": train_metrics["accuracy"],
        "val_acc": val_metrics["accuracy"],
        "val_f1": val_metrics["f1_score"],
        "val_inference_time": val_inference_time,
        "false_positives": fp,
        "false_negatives": fn
    })
    plot_metrics(val_metrics, "Validación FT", epoch, CHECKPOINT_PATH)
    plot_probability_histogram(val_labels, val_probs_positive, f"Validación FT Epoch {epoch}", CHECKPOINT_PATH)
    plot_prob_vs_duration(val_durations, val_probs_positive, val_labels, f"Validación FT Epoch {epoch}", CHECKPOINT_PATH)
    if early_stop_counter >= PATIENCE:
        logger.info("Early Stopping activado")
        print("Early Stopping activado")
        break

plot_learning_curves(history_ft, "Fine-Tuning", CHECKPOINT_PATH)
# Out:
# Iniciando Fine-Tuning
# train/no_violence: 4000 videos
# train/violence: 4000 videos
# val/no_violence: 750 videos
# val/violence: 750 videos
# test/no_violence: 400 videos
# test/violence: 400 videos
# Total de videos validados: 10300
# Distribución de clases: {'no_violence': 5150, 'violence': 5150}
# Videos problemáticos detectados: 0
# Some weights of TimesformerForVideoClassification were not initialized from the model checkpoint at facebook/timesformer-base-finetuned-k400 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([400, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([400]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Mejor modelo TL cargado: /content/drive/MyDrive/Modelo-Violencia/timesformer_checkpoints/best_model_tl_20250518_044626.pt
# Parámetros entrenables: 30128642 (24.85% del total)
# Dropout del clasificador aumentado a 0.5
# Modelo compilado con torch.compile
# Entrenando:  16%|█▋        | 655/4000 [02:31<10:55,  5.10it/s]

# %%
# --- Sección 11: Evaluación en Conjunto de Prueba ---
logger.info("Evaluando modelo final en conjunto de prueba")
print("Evaluando modelo final en conjunto de prueba")
best_model_path = os.path.join(CHECKPOINT_PATH, f"best_model_ft_{TIMESTAMP}.pt")
if not os.path.exists(best_model_path):
    logger.error(f"No se encontró el mejor modelo FT: {best_model_path}")
    raise FileNotFoundError(f"No se encontró {best_model_path}")
try:
    state_dict = torch.load(best_model_path, map_location=device)
    state_dict = fix_state_dict(state_dict)
    model.load_state_dict(state_dict, strict=True)
    logger.info(f"Mejor modelo FT cargado: {best_model_path}")
    print(f"Mejor modelo FT cargado: {best_model_path}")
except Exception as e:
    logger.error(f"Error al cargar el state_dict: {e}")
    raise RuntimeError(f"Error al cargar el state_dict: {e}")

test_dataset = ViolenceDataset(DATASET_PATH, "test", processor)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)
test_loss, test_metrics, test_labels, test_probs, test_inference_time, test_durations = evaluate_epoch(
    model, test_loader, criterion, device
)
# Procesar test_probs
if isinstance(test_probs, list):
    test_probs = np.vstack([p.cpu().numpy() if isinstance(p, torch.Tensor) else p for p in test_probs])
elif isinstance(test_probs, torch.Tensor):
    test_probs = test_probs.cpu().numpy()
logger.info(f"Forma de test_probs: {test_probs.shape}")
print(f"Forma de test_probs: {test_probs.shape}")
if test_probs.ndim == 2 and test_probs.shape[1] == 2:
    test_probs_positive = test_probs[:, 1]
elif test_probs.ndim == 2 and test_probs.shape[1] == 1:
    logger.warning("test_probs tiene una sola columna. Asumiendo probabilidades de la clase positiva.")
    test_probs_positive = test_probs[:, 0]
    test_probs = np.hstack([1 - test_probs, test_probs])
else:
    logger.error(f"Forma inesperada de test_probs: {test_probs.shape}")
    raise ValueError(f"Forma inesperada de test_probs: {test_probs.shape}")

test_preds = (test_probs_positive > 0.5).astype(int)
fp, fn = analyze_errors(
    test_labels, test_preds, test_probs_positive,
    [test_dataset.videos[i] for i in range(len(test_labels))], "Prueba", "Final", CHECKPOINT_PATH
)

logger.info("Resultados en conjunto de prueba:")
print("Resultados en conjunto de prueba:")
logger.info(f"Pérdida: {test_loss:.4f}")
print(f"Pérdida: {test_loss:.4f}")
logger.info(f"Exactitud: {test_metrics['accuracy']:.3f}")
print(f"Exactitud: {test_metrics['accuracy']:.3f}")
logger.info(f"F1-Score: {test_metrics['f1_score']:.3f}")
print(f"F1-Score: {test_metrics['f1_score']:.3f}")
logger.info(f"Tiempo de inferencia promedio: {test_inference_time:.4f} segundos")
print(f"Tiempo de inferencia promedio: {test_inference_time:.4f} segundos")
logger.info(f"Falsos Positivos: {fp}")
print(f"Falsos Positivos: {fp}")
logger.info(f"Falsos Negativos: {fn}")
print(f"Falsos Negativos: {fn}")

plot_metrics(test_metrics, "Prueba", "Final", CHECKPOINT_PATH)
plot_probability_histogram(test_labels, test_probs_positive, "Prueba Final", CHECKPOINT_PATH)
plot_prob_vs_duration(test_durations, test_probs_positive, test_labels, "Prueba Final", CHECKPOINT_PATH)

from sklearn.metrics import classification_report
report = classification_report(test_labels, test_preds, target_names=LABELS)
print("\nInforme de Clasificación:")
print(report)
wandb.log({"test_classification_report": wandb.Html(report)})

# %%
# --- Sección 11: Evaluación en Conjunto de Prueba ---
logger.info("Evaluando modelo final en conjunto de prueba")
print("Evaluando modelo final en conjunto de prueba")
best_model_path = os.path.join(CHECKPOINT_PATH, f"best_model_ft_{TIMESTAMP}.pt")
model.load_state_dict(torch.load(best_model_path))
logger.info(f"Mejor modelo FT cargado: {best_model_path}")
print(f"Mejor modelo FT cargado: {best_model_path}")

test_loss, test_metrics, test_labels, test_probs, test_inference_time, test_durations = evaluate_epoch(
    model, test_loader, criterion, device
)
test_preds = np.argmax(test_probs, axis=1) if test_probs.ndim > 1 else (test_probs > 0.5).astype(int)
fp, fn = analyze_errors(test_labels, test_preds, test_probs[:, 1] if test_probs.ndim > 1 else test_probs,
                       [test_dataset.videos[i] for i in range(len(test_labels))], "Prueba", "Final", CHECKPOINT_PATH)

logger.info("Resultados en conjunto de prueba:")
print("Resultados en conjunto de prueba:")
logger.info(f"Pérdida: {test_loss:.4f}")
print(f"Pérdida: {test_loss:.4f}")
logger.info(f"Exactitud: {test_metrics['accuracy']:.3f}")
print(f"Exactitud: {test_metrics['accuracy']:.3f}")
logger.info(f"Precisión: {test_metrics['precision']:.3f}")
print(f"Precisión: {test_metrics['precision']:.3f}")
logger.info(f"Sensibilidad: {test_metrics['recall']:.3f}")
print(f"Sensibilidad: {test_metrics['recall']:.3f}")
logger.info(f"Especificidad: {test_metrics['specificity']:.3f}")
print(f"Especificidad: {test_metrics['specificity']:.3f}")
logger.info(f"F1-Score: {test_metrics['f1_score']:.3f}")
print(f"F1-Score: {test_metrics['f1_score']:.3f}")
logger.info(f"AUC: {test_metrics['auc']:.3f}")
print(f"AUC: {test_metrics['auc']:.3f}")
logger.info(f"Tiempo de inferencia promedio: {test_inference_time:.4f} segundos")
print(f"Tiempo de inferencia promedio: {test_inference_time:.4f} segundos")
logger.info(f"Falsos Positivos: {fp}")
print(f"Falsos Positivos: {fp}")
logger.info(f"Falsos Negativos: {fn}")
print(f"Falsos Negativos: {fn}")

plot_metrics(test_metrics, "Prueba", "Final", CHECKPOINT_PATH)
plot_probability_histogram(test_labels, test_probs[:, 1] if test_probs.ndim > 1 else test_probs,
                         "Prueba Final", CHECKPOINT_PATH)
plot_prob_vs_duration(test_durations, test_probs[:, 1] if test_probs.ndim > 1 else test_probs,
                     test_labels, "Prueba Final", CHECKPOINT_PATH)

print("\nInforme de Clasificación:")
report = classification_report(test_labels, test_preds, target_names=LABELS)
print(report)
wandb.log({"test_classification_report": wandb.Html(report)})

# --- Sección 12: Cuantización Dinámica ---
logger.info("Aplicando cuantización dinámica para optimizar latencia")
print("Aplicando cuantización dinámica para optimizar latencia")
quantized_model = torch.quantization.quantize_dynamic(
    model.cpu(), {torch.nn.Linear}, dtype=torch.qint8
)
quantized_model_path = os.path.join(CHECKPOINT_PATH, f"quantized_model_ft_{TIMESTAMP}.pt")
torch.save(quantized_model.state_dict(), quantized_model_path)
logger.info(f"Modelo cuantizado guardado: {quantized_model_path}")
print(f"Modelo cuantizado guardado: {quantized_model_path}")

# Verificar latencia del modelo cuantizado
quantized_model = quantized_model.to(device)
quantized_model.eval()
test_inference_times = []
with torch.no_grad():
    for inputs, _, _ in tqdm(test_loader, desc="Evaluando modelo cuantizado"):
        start_time = time.time()
        inputs = {k: v.to(device) for k, v in inputs.items()}
        with autocast():
            _ = quantized_model(**inputs)
        test_inference_times.append(time.time() - start_time)
avg_quantized_inference_time = np.mean(test_inference_times)
logger.info(f"Tiempo de inferencia promedio (cuantizado): {avg_quantized_inference_time:.4f} segundos")
print(f"Tiempo de inferencia promedio (cuantizado): {avg_quantized_inference_time:.4f} segundos")
wandb.log({"quantized_inference_time": avg_quantized_inference_time})

if avg_quantized_inference_time > 0.2:
    logger.warning("Latencia cuantizada aún alta para tiempo real. Considerar optimización adicional.")
    print("Latencia cuantizada aún alta para tiempo real. Considerar optimización adicional.")

# %%
# --- Sección 9: Evaluación Final en Conjunto de Prueba ---
logger.info("Evaluando modelo final en conjunto de prueba")
best_model_path = os.path.join(CHECKPOINT_PATH, f"best_model_ft_{TIMESTAMP}.pt")
model.load_state_dict(torch.load(best_model_path))
logger.info(f"Mejor modelo FT cargado: {best_model_path}")

test_loss, test_metrics, test_labels, test_probs, test_inference_time = evaluate_epoch(
    model, test_loader, criterion, device
)

logger.info("Resultados en conjunto de prueba:")
logger.info(f"Pérdida: {test_loss:.4f}")
logger.info(f"Exactitud: {test_metrics['accuracy']:.3f}")
logger.info(f"Precisión: {test_metrics['precision']:.3f}")
logger.info(f"Sensibilidad: {test_metrics['recall']:.3f}")
logger.info(f"Especificidad: {test_metrics['specificity']:.3f}")
logger.info(f"F1-Score: {test_metrics['f1_score']:.3f}")
logger.info(f"AUC: {test_metrics['auc']:.3f}")
logger.info(f"Tiempo de inferencia promedio: {test_inference_time:.4f} segundos")

plot_metrics(test_metrics, "Prueba", "Final", CHECKPOINT_PATH)
plot_probability_histogram(test_labels, test_probs, "Prueba Final", CHECKPOINT_PATH)

# Informe detallado
print("\nInforme de Clasificación:")
print(classification_report(test_labels, test_metrics["confusion_matrix"].argmax(axis=1), target_names=LABELS))
wandb.log({"test_classification_report": wandb.Html(classification_report(test_labels, test_metrics["confusion_matrix"].argmax(axis=1), target_names=LABELS, output_dict=True))})

# %%
# --- Sección 10: Análisis Detallado ---
# Análisis de Errores
errors = [(i, test_labels[i], test_metrics["confusion_matrix"].argmax(axis=1)[i], test_probs[i], test_dataset.videos[i]) for i in range(len(test_labels)) if test_labels[i] != test_metrics["confusion_matrix"].argmax(axis=1)[i]]
logger.info(f"Número de errores: {len(errors)}")
for idx, true, pred, prob, video_path in errors[:5]:
    logger.info(f"Índice: {idx}, Video: {video_path}, Real: {LABELS[true]}, Predicho: {LABELS[pred]}, Probabilidad: {prob:.3f}")

    # Visualizar frames de error
    cap = cv2.VideoCapture(video_path)
    frames = []
    while cap.isOpened() and len(frames) < 4:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frames.append(frame)
    cap.release()

    plt.figure(figsize=(12, 3))
    for i, frame in enumerate(frames):
        plt.subplot(1, 4, i+1)
        plt.imshow(frame)
        plt.axis('off')
        plt.title(f"Frame {i+1}")
    plt.suptitle(f"Error: Real={LABELS[true]}, Pred={LABELS[pred]}")
    plt.savefig(os.path.join(CHECKPOINT_PATH, f"error_{idx}.png"))
    plt.show()
    wandb.log({f"error_{idx}": wandb.Image(os.path.join(CHECKPOINT_PATH, f"error_{idx}.png"))})

# Análisis de Duración de Videos vs. Rendimiento
correct = [1 if test_labels[i] == test_metrics["confusion_matrix"].argmax(axis=1)[i] else 0 for i in range(len(test_labels))]
plt.figure(figsize=(8, 6))
plt.scatter(test_dataset.durations, correct, alpha=0.5)
plt.xlabel("Duración del Video (segundos)")
plt.ylabel("Correcto (1) / Incorrecto (0)")
plt.title("Duración de Videos vs. Rendimiento")
plt.savefig(os.path.join(CHECKPOINT_PATH, "duration_vs_performance.png"))
plt.show()
wandb.log({"duration_vs_performance": wandb.Image(os.path.join(CHECKPOINT_PATH, "duration_vs_performance.png"))})

# Análisis de Sesgo de Clases
class_counts = np.bincount(test_labels)
logger.info(f"Distribución de clases en prueba: {dict(zip(LABELS, class_counts))}")
if abs(class_counts[0] - class_counts[1]) / sum(class_counts) > 0.2:
    logger.warning("Posible desbalance de clases detectado")

# Comparación de Modelos
logger.info("Comparación de Modelos:")
logger.info(f"Mejor Exactitud TL (Validación): {max(history_tl['val_acc']):.3f}")
logger.info(f"Mejor F1 TL (Validación): {max(history_tl['val_f1']):.3f}")
logger.info(f"Mejor Exactitud FT (Validación): {max(history_ft['val_acc']):.3f}")
logger.info(f"Mejor F1 FT (Validación): {max(history_ft['val_f1']):.3f}")
logger.info(f"Exactitud Final (Prueba): {test_metrics['accuracy']:.3f}")
logger.info(f"F1-Score Final (Prueba): {test_metrics['f1_score']:.3f}")

# Análisis de Latencia
logger.info(f"Latencia promedio de inferencia (prueba): {test_inference_time:.4f} segundos")
if test_inference_time > 0.2:
    logger.warning("Latencia alta para tiempo real. Considerar optimización adicional.")

# %%
# --- Sección 11: Exportación del Modelo ---
logger.info("Exportando modelo final")
# Guardar en formato PyTorch
final_model_path = os.path.join(CHECKPOINT_PATH, f"final_model_{TIMESTAMP}.pt")
torch.save(model.state_dict(), final_model_path)
logger.info(f"Modelo PyTorch guardado: {final_model_path}")

# Validar carga del modelo
try:
    model.load_state_dict(torch.load(final_model_path))
    logger.info("Modelo PyTorch cargado correctamente para validación")
except Exception as e:
    logger.error(f"Error al cargar modelo PyTorch: {e}")
    raise

# Exportar a ONNX
model.eval()
dummy_input = torch.randn(1, NUM_FRAMES, 3, IMG_SIZE, IMG_SIZE).to(device)
onnx_path = os.path.join(CHECKPOINT_PATH, f"final_model_{TIMESTAMP}.onnx")
try:
    torch.onnx.export(
        model,
        dummy_input,
        onnx_path,
        export_params=True,
        opset_version=12,
        do_constant_folding=True,
        input_names=["input"],
        output_names=["output"],
        dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}}
    )
    logger.info(f"Modelo exportado a ONNX: {onnx_path}")

    # Validar modelo ONNX
    ort_session = ort.InferenceSession(onnx_path)
    ort_inputs = {ort_session.get_inputs()[0].name: dummy_input.cpu().numpy()}
    ort_outs = ort_session.run(None, ort_inputs)
    logger.info("Modelo ONNX validado correctamente")
except Exception as e:
    logger.error(f"Error al exportar o validar ONNX: {e}")
    raise

# %%
# --- Sección 12: Prueba de Inferencia ---
logger.info("Realizando prueba de inferencia con modelo final")
test_video = test_dataset.videos[0]
cap = cv2.VideoCapture(test_video)
frames = []
while cap.isOpened() and len(frames) < NUM_FRAMES:
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frames.append(frame)
cap.release()

if len(frames) < NUM_FRAMES:
    frames = frames + [frames[-1]] * (NUM_FRAMES - len(frames))
inputs = processor(frames, return_tensors="pt")
inputs = {k: v.to(device) for k, v in inputs.items()}

model.eval()
with torch.no_grad():
    outputs = model(**inputs)
    probs = torch.softmax(outputs.logits, dim=1)
    pred = torch.argmax(probs, dim=1).item()
    prob_violence = probs[0, 1].item()

logger.info(f"Prueba de inferencia: Video={test_video}, Predicción={LABELS[pred]}, Probabilidad de Violencia={prob_violence:.3f}")

# %%
# --- Sección 13: Conclusiones ---
logger.info("Entrenamiento completado")
logger.info(f"Mejor modelo TL: {os.path.join(CHECKPOINT_PATH, f'best_model_tl_{TIMESTAMP}.pt')}")
logger.info(f"Mejor modelo FT: {os.path.join(CHECKPOINT_PATH, f'best_model_ft_{TIMESTAMP}.pt')}")
logger.info(f"Modelo final para despliegue: {final_model_path} y {onnx_path}")
logger.info("Revisar WandB y Google Drive para análisis detallado")

wandb.finish()
